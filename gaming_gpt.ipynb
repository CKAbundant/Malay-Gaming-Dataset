# %% [markdown]
# # Generate Synthetic Malay Gaming Dataset
#
# We attempt to generate audio files based on 3646 gaming transcripts that are generated via ChatGPT 3.5.
#
# ### Considerations:
#
# - Gaming terms are typically English words.
# - Malay gaming communities use gaming terms in its original form and rarely translate into Malay words.
# - Our existing VITS model is trained purely on phonemized Malay text that are from news, wikipedia and parliament and not relevant for gaming setting.
# - To our knowledge, there are no dataset that has text-audio pair relevant to gaming. Therefore, we see a need to generate synthetic Malay gaming dataset to supplement our VITS model training.
#
# ### Methodology:
#
# Continuing from `gaming_terms.ipynb`, we noted VITS model that we have trained are not able to generate comprehensible audio files for all the gaming terms likely due to VITS model being trained only on Malay words from wikipedia, news and parliament (from osman news and parliament dataset).
#
# As such, we adopted the alternative method to use [Malaya Speech VITS model](https://malaya-speech.readthedocs.io/en/latest/tts-vits.html) specifically:
#
# - Use [Malaya Speech VITS model](https://malaya-speech.readthedocs.io/en/latest/tts-vits.html) to infer the gaming text directly.
# - Manually amend the characters so that comprehensible audio files are generated.
#
# Steps are as follows:
#
# <style>
#     table {
#         width: 70%;
#         table-layout:fixed;
#     }
#     th:nth-child(1),
#     td:nth-child(1) {
#         width: 3%;
#     }
#     th:nth-child(2),
#     td:nth-child(2) {
#         width: 17%;
#     }
#     th:nth-child(3),
#     td:nth-child(3) {
#         width: 80%;
#     }
# </style>
#
# | S/N | Step | Description |
# | -- | -- | -- |
# | 1. | Load ChatGPT transcripts | &bull; Load 3646 gaming transcripts, which are generated by ChatGPT 3.5 |
# | 2. | Check for Gaming Terms | &bull; Check number of transcripts that doesn't contain any gaming terms. &bull; Generate audio that doesn't contain any gaming terms. |
# | 3. | Extract English Terms | &bull; Check English terms that are found in transcripts despite prompting ChatGPT to produce only Malay words. <br>&bull; Generate `gpt_mapping` dictionary to map English terms that are not found in existing `mapping` dictionary and combined gaming terms. |
# | 4. | Normalize GPT Corpus | &bull; Normalize gaming terms via `mapping` dictionary in `gaming.yaml`. <br>&bull; Normaling remaining terms via English terms via `gpt_mapping` dictionary. |
# | 5. | Generate Audio for GPT Corpus | &bull; Generate audio for GPT Corpus via batch processing to avoid memory overflow. |

# %% [markdown]
# # Environment Setup
#
# Following additional python modules are required to run this jupyter notebook
#
# ```translators==5.8.9
# eng_to_ipa==0.0.2
# bs4==0.0.1
# nemo_text_processing==0.2.2rc0
# herpetologist==0.0.9
# malaya==5.0
# malaya_speech==1.3.0.2
# omegaconf==2.3.0
# whisper-openai==1.0.0
# pandarallel==1.6.5
# polyglot==16.7.4
# PySastrawi==1.2.0
# ```
#
# ICU (International Components for Unicode) is required by polyglot to operate. PyICU is a python extension implemented in C++ that wraps the C/C++ ICU library. Installation of PyICU on Ubuntu is via binary packages of ICU and PyICU:
#
# ```
# sudo apt-get install pkg-conifg libicu-dev
# pip install --no-binary=:pyicu: pyicu
# ```
#
# Please refer to [PyICU - PyPI](https://pypi.org/project/PyICU/) for installation method for other operating systems.

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
from pathlib import Path
import eng_to_ipa
import numpy as np
from omegaconf import OmegaConf
import shutil
import sys
import logging
from pandarallel import pandarallel
import IPython.display as ipd
import herpetologist
import malaya
from collections import Counter
import string
import csv
import parselmouth
from ast import literal_eval
import re
import time
from phonemizer.backend import EspeakBackend


# Append `tts-melayu` folder to sys path
sys.path.append(Path.cwd().parent.as_posix())

# %load_ext autoreload
# %autoreload 2
from notebooks.src_gaming.gaming_utils import (
    gen_audio, gen_filelist, normalize_gaming,
)
from notebooks.src_gaming.gaming_gpt_utils import (
    read_gpt, extract_en_words,
    extract_gaming, normalize_gpt, 
    gen_gaming_counter, gen_gpt_audio,
    gen_en_counter, gen_new_en, append_translated,
    normalize_gpt_phon,
    display_yaml, detect_language, expand_compound,
    phonemize_gpt, detect_language, create_dict
)
from src.vits.text.cleaners import malay_cleaners2, english_cleaners2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load Configurations

# %%
# Load configurable parameters in gaming.yaml
cfg = OmegaConf.load("/home/ckabundant/Documents/tts-melayu/notebooks/src_gaming/gaming.yaml")
# args = OmegaConf.load(cfg.paths.gpt_yaml_path)

# Initialize pandarallel
pandarallel.initialize(progress_bar=True, nb_workers=cfg.general.num_workers)

cfg.paths
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# {'repo_dir': '/home/ckabundant/Documents/tts-melayu', 'gaming_dir': '${paths.repo_dir}/data/gaming', 'gaming_path': '${paths.gaming_dir}/dataframe/gaming_terms.csv', 'additional_path': '${paths.gaming_dir}/vocab/additional_term.txt', 'updated_path': '${paths.gaming_dir}/dataframe/updated_terms.csv', 'combined_path': '${paths.gaming_dir}/dataframe/combined_gaming_terms.csv', 'special_path': '${paths.gaming_dir}/vocab/special.txt', 'diff_path': '${paths.gaming_dir}/dataframe/stats_diff.csv', 'same_path': '${paths.gaming_dir}/dataframe/stats_same.csv', 'oov_path': '${paths.gaming_dir}/dataframe/oov.csv', 'acr_path': '${paths.gaming_dir}/dataframe/acr.csv', 'cer_path': '${paths.gaming_dir}/dataframe/cer.csv', 'malaya_norm_dir': '${paths.gaming_dir}/malaya_vits_n/wav', 'malaya_unnorm_dir': '${paths.gaming_dir}/malaya_vits_un/wav', 'gaming_gt_path': '${paths.gaming_dir}/malaya_vits_n/gaming_gt.csv', 'gpt_path': '${paths.gaming_dir}/vocab/gpt.txt', 'gpt_csv_path': '${paths.gaming_dir}/dataframe/gpt.csv', 'gpt_no_path': '${paths.gaming_dir}/dataframe/gpt_no.csv', 'gpt_en_path': '${paths.gaming_dir}/dataframe/gpt_en.csv', 'gpt_en_new_path': '${paths.gaming_dir}/dataframe/gpt_en_new_.csv', 'gpt_dir': '${paths.gaming_dir}/gpt/wav', 'gpt_no_dir': '${paths.gaming_dir}/gpt_no/wav', 'gpt_en_new_dir': '${paths.gaming_dir}/gpt_en_new/wav', 'gpt_word_path': '${paths.gaming_dir}/dataframe/gpt_word.csv', 'gpt_translated_path': '${paths.gaming_dir}/dataframe/gpt_translated.csv', 'gpt_expand_path': '${paths.gaming_dir}/dataframe/gpt_expand.csv', 'gpt_txt_path': '${paths.gaming_dir}/gpt/gpt.txt', 'gpt_ms_txt_path': '${paths.gaming_dir}/gpt/gpt_ms.txt', 'gpt_en_ms_txt_path': '${paths.gaming_dir}/gpt/gpt_en_ms.txt', 'gpt_eng2ipa_ms_txt_path': '${paths.gaming_dir}/gpt/gpt_eng2ipa_ms.txt', 'gpt_norm_phon_txt_path': '${paths.gaming_dir}/gpt/gpt_norm_phon.txt', 'gpt_yaml_path': '${paths.repo_dir}/notebooks/src_gaming/gaming_gpt.yaml', 'inferencing_yaml_path': '${paths.repo_dir}/notebooks/src_eval/batch_inferencing.yaml', 'eval_yaml_path': '${paths.repo_dir}/notebooks/src_gaming/model_objective_eval_phon.yaml'}

# %% [markdown]
# # Table of Contents <a id='home'></a>
# 1. &nbsp;&nbsp; [Load GPT Transcripts](#load_gpt)
# 2. &nbsp;&nbsp; [Gaming Terms Analysis](#gaming_gpt)
#     - Section 2.1 &nbsp;&nbsp; [Extract Gaming Terms used](#extract_gaming)
#     - Section 2.2 &nbsp;&nbsp; [Identify Gaming Terms Used](#gaming_used)
#     - Section 2.3 &nbsp;&nbsp; [Identify Transcripts without Gaming Terms](#no_gaming)
# 3. &nbsp;&nbsp; [English Words Analysis](#english_gpt)
#     - Section 3.1 &nbsp;&nbsp; [Extract English Terms used](#extract_english)
#     - Section 3.2 &nbsp;&nbsp; [Identify Unique English Words](#unique_english)
#     - Section 3.3 &nbsp;&nbsp; [Translate Unique English Words](#translate_unique)
#     - Section 3.4 &nbsp;&nbsp; [Identify Untranslated English Words](#untranslated_unique)
#     - Section 3.5 &nbsp;&nbsp; [Identify Wrong Translations](#wrong_translation)
# 4. &nbsp;&nbsp; [Generate GPT Mapping](#gen_gpt_mapping)
#     - Section 4.1 &nbsp;&nbsp; [Generate Audio for Unique English Words](#gen_audio_unique)
#     - Section 4.2 &nbsp;&nbsp; [Map to Malay Words](#map_to_malay)
#     - Section 4.3 &nbsp;&nbsp; [Map to Modified](#map_to_modified)
# 5. &nbsp;&nbsp; [Normalize GPT Corpus](#normalize_gpt_corpus)
#     - Section 5.1 &nbsp;&nbsp; [Normalize Gaming Terms](#norm_gaming)
#     - Section 5.2 &nbsp;&nbsp; [Normalize English Words](#norm_en)
# 6. &nbsp;&nbsp; [Generate Audio for GPT Corpus](#gen_audio_gpt)
#     - Section 6.1 &nbsp;&nbsp; [Generate Text Manifest for GPT Corpus](#gen_gpt_txt)
# 7. &nbsp;&nbsp; [Normalize Text for Phonemization](#norm_gpt_phon)
#     - Section 7.1 &nbsp;&nbsp; [Apply eng_to_ipa](#eng2ipa_gpt)
#     - Section 7.2 &nbsp;&nbsp; [Analyse Unphonemized Words](#unphon_analysis)
#     - Section 7.3 &nbsp;&nbsp; [Analyse phonemized Words](#phon_analysis)
#     - Section 7. &nbsp;&nbsp; [Update mapping](#update_mapping)
# 8. &nbsp;&nbsp; [Generate GPT Phonemes](#gpt_phonemes)
#     - Section 8.1 &nbsp;&nbsp; [Phonemize with eng_to_ipa](#phon_eng2ipa)
#     - Section 8.2 &nbsp;&nbsp; [espeak_ms](#espeak_ms)
#     - Section 8.3 &nbsp;&nbsp; [espeak_en_ms](#espeak_en_ms)
#     - Section 8.4 &nbsp;&nbsp; [eng2ipa_espeak_ms](#eng2ipa_espeak_ms)
# 9. &nbsp;&nbsp; [Generate Text Manifest for GPT Phonemes](#gpt_text_manifest)
#     - Section 9.1 &nbsp;&nbsp; [Text Manifest (espeak_ms)](#espeak_ms_txt)
#     - Section 9.2 &nbsp;&nbsp; [Text Manifest (espeak_en_ms)](#espeak_en_ms_txt)
#     - Section 9.3 &nbsp;&nbsp; [Text Manifest (eng2ipa_espeak_ms)](#eng2ipa_espeak_ms_txt)
#     - Section 9.4 &nbsp;&nbsp; [Text Manifest (norm_phon)](#norm_phon_txt)

# %% [markdown]
# # 1. &nbsp;&nbsp; [Load GPT Transcripts](#home) <a id='load_gpt'></a>
#
# We prompt ChatGPT 3.5 to generate 50 examples of gaming transcripts that contains at least one of the 5 gaming terms provided (i.e. multiple gaming terms within the same transcript) in Malay language. We repeated for the process until all 743 gaming terms are used.
#
# Steps taken are as follows:
#
# 1. Read `gpt.txt` file and processed its content to required format.
# 2. Load the content as DataFrame.
# 3. Assign id to each transcript in Dataframe.
#
# Our observations:
#
# 73 transcripts didn't contain any gaming terms. This may be due to ChatGPT attempt to stimulate actual conversations between gamers e.g. gamer replying to other gamer's queries "Serius?".

# %%
# Read gpt.txt file to DataFrame
# Saved pre-processed gpt.txt
df_gpt = read_gpt(cfg.paths.gpt_path)
df_gpt
# Out:
#                                                    text
# 0     Dengan mendapat 1-up , saya boleh teruskan per...
# 1     Grafik 16-bit memberikan sentuhan nostalgia ya...
# 2     Saya berjaya melakukan 1CC pada permainan arke...
# 3     Pertarungan 1v1 itu benar-benar mencabar kemah...
# 4     Grafik 2.5D memberikan dimensi yang menarik ke...
# ...                                                 ...
# 3641                          Macam mana gameplay dia ?
# 3642  Zone dalam game merujuk kepada kawasan atau wi...
# 3643                       Okey , aku cover left zone .
# 3644  Zoning dalam game adalah strategi untuk kawal ...
# 3645     Aku cover flank , kita kena maintain control .
#
# [3646 rows x 1 columns]

# %%
# Assign id to each transcript in DataFrame
df_gpt.insert(0, "id", [f"gpt_{i}" for i in df_gpt.index])
df_gpt.to_csv(cfg.paths.gpt_csv_path, index=False)
df_gpt
# Out:
#             id                                               text
# 0        gpt_0  Dengan mendapat 1-up , saya boleh teruskan per...
# 1        gpt_1  Grafik 16-bit memberikan sentuhan nostalgia ya...
# 2        gpt_2  Saya berjaya melakukan 1CC pada permainan arke...
# 3        gpt_3  Pertarungan 1v1 itu benar-benar mencabar kemah...
# 4        gpt_4  Grafik 2.5D memberikan dimensi yang menarik ke...
# ...        ...                                                ...
# 3641  gpt_3641                          Macam mana gameplay dia ?
# 3642  gpt_3642  Zone dalam game merujuk kepada kawasan atau wi...
# 3643  gpt_3643                       Okey , aku cover left zone .
# 3644  gpt_3644  Zoning dalam game adalah strategi untuk kawal ...
# 3645  gpt_3645     Aku cover flank , kita kena maintain control .
#
# [3646 rows x 2 columns]

# %% [markdown]
# # 2. &nbsp;&nbsp; [Gaming Terms Analysis](#home) <a id='gaming_analysis'></a>
#
# We extract list of gaming terms for each transcript in GPT corpus and perform analysis on the gaming terms. Steps taken are as follows:
#
# <style>
#     table {
#         width: 70%;
#         table-layout:fixed;
#     }
#     th:nth-child(1),
#     td:nth-child(1) {
#         width: 3%;
#     }
#     th:nth-child(2),
#     td:nth-child(2) {
#         width: 17%;
#     }
#     th:nth-child(3),
#     td:nth-child(3) {
#         width: 80%;
#     }
# </style>
#
# | S/N | Step | Description |
# | -- | -- | -- |
# | 1. | [Extract Gaming Terms](#extract_gaming) | &bull; Extract list of gaming terms found in each transcripts. <br>&bull; Append list of gaming terms to DataFrame. |
# | 2. | [Identify Gaming Terms Used](#gaming_used) | &bull; Identify gaming terms used and generate list of unused gaming terms. <br>&bull; Based on the generated list, we could potentially use ChatGPT to generate those missing gaming transcripts to supplement our dataset. |
# | 3. | [Identify Transcripts without Gaming Terms](#no_gaming) | &bull; Generate list of gaming transcripts without gaming terms. |

# %% [markdown]
# ## 2.1 &nbsp;&nbsp; [Extract Gaming Terms ](#home) <a id='extract_gaming'></a>

# %%
# Extract gaming terms present in transcript
df_gpt["gaming"] = df_gpt["text"].parallel_map(lambda x: extract_gaming(x, cfg.paths.combined_path))
df_gpt.to_csv(cfg.paths.gpt_csv_path, index=False)
df_gpt
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=456), Label(value='0 / 456'))), HB…
#             id                                               text  \
# 0        gpt_0  Dengan mendapat 1-up , saya boleh teruskan per...
# 1        gpt_1  Grafik 16-bit memberikan sentuhan nostalgia ya...
# 2        gpt_2  Saya berjaya melakukan 1CC pada permainan arke...
# 3        gpt_3  Pertarungan 1v1 itu benar-benar mencabar kemah...
# 4        gpt_4  Grafik 2.5D memberikan dimensi yang menarik ke...
# ...        ...                                                ...
# 3641  gpt_3641                          Macam mana gameplay dia ?
# 3642  gpt_3642  Zone dalam game merujuk kepada kawasan atau wi...
# 3643  gpt_3643                       Okey , aku cover left zone .
# 3644  gpt_3644  Zoning dalam game adalah strategi untuk kawal ...
# 3645  gpt_3645     Aku cover flank , kita kena maintain control .
#
#                 gaming
# 0               [1-up]
# 1             [16-bit]
# 2                [1CC]
# 3                [1v1]
# 4                   []
# ...                ...
# 3641  [gameplay, mana]
# 3642            [zone]
# 3643            [zone]
# 3644          [zoning]
# 3645                []
#
# [3646 rows x 3 columns]

# %% [markdown]
# ## 2.2 &nbsp;&nbsp; [Identify Gaming Terms Used](#home) <a id='gaming_used'></a>
#
# Our observations:
#
# 1. 717 out of 781 gaming terms were used in GPT corpus. 64 gaming terms were not used.
# 2. `mana` happens to be a Malay word for "where", which accounts for its high frequency.
# 3. It appears ChatGPT has a preference over certain words despite prompting to generate 50 examples based on 5 gaming terms provided each time.

# %%
df_gaming_counter, unused_gaming = gen_gaming_counter(df_gpt, cfg.paths.combined_path)
df_gaming_counter
# Out:
# Total number of combined gaming terms    : 781
# Number of gaming terms used              : 717
# Number of gaming terms unused            : 64
#                                  frequency
# mana                                   159
# mode                                    88
# gameplay                                63
# platform                                55
# level                                   53
# ...                                    ...
# telegraph                                1
# theory                                   1
# toxicity                                 1
# multiplayer online battle arena          1
# 1-up                                     1
#
# [717 rows x 1 columns]

# %% [markdown]
# ##### List of unused gaming terms

# %%
unused_gaming
# Out:
# ['Dummied out',
#  'shoot em up',
#  'idle game',
#  'augmented reality',
#  'microtransaction',
#  'booster pack',
#  'pocket',
#  'joke character',
#  'idle animation',
#  'blacklist',
#  'OP',
#  'backwards compatibility',
#  'metastory',
#  'Debug mode',
#  'auto battler',
#  'asset flipping',
#  'boosting',
#  'bonus stage',
#  'Lets Play',
#  'clocked',
#  'best-in-slot',
#  'asynchronous gameplay',
#  'buff',
#  'non-player character',
#  'battle pass',
#  'bullet sponge',
#  'metagame',
#  'beta release',
#  '4X',
#  'assault mode',
#  'transmogrification',
#  'attract mode',
#  'boss-rush',
#  '64-bit',
#  'minigame',
#  'in-app purchase',
#  'campaign mode',
#  'iframes',
#  'KDR',
#  'button mashing',
#  'micro',
#  'IAP',
#  'miniboss',
#  'tile-matching video game',
#  'wave',
#  'infinite life',
#  'inventory management',
#  'stat squish',
#  'ban wave',
#  'borderless fullscreen windowed',
#  'bullet hell',
#  'newb',
#  'battle royale game',
#  '8K resolution',
#  'mob',
#  'board',
#  'infinite health',
#  'bottomless pit',
#  'breach',
#  'asymmetric gameplay',
#  'massively multiplayer online game',
#  'minimap',
#  'min-maxing',
#  'horde mode']

# %% [markdown]
# ## 2.3 &nbsp;&nbsp; [Identify Transcripts without Gaming Terms](#home) <a id='no_gaming'></a>
#
# Our observations:
#
# 1. `2.5D graphics`, `4K resolution`, and `8K resolution` are represented in Malay format i.e. `Grafik 2.5D`, `Resolusi 4K` and `Resolusi 8K` respectively.
# 2. A number of english words were detected despite prompting ChatGPT to generate only Malay gaming transcripts. Perhaps, ChatGPT felt that those words were commonly used in gaming despite not classified as gaming terms in Wikipedia.
# 3. Examples of english words used: world-building, tech tree, auto-targetting, zipper, smart move, etc.

# %%
# Verify transcripts without gaming terms doesn't contain any gaming terms
df_no = df_gpt.loc[df_gpt["gaming"].map(lambda x: len(x) == 0), :]
df_no.to_csv(cfg.paths.gpt_no_path)
df_no
# Out:
#             id                                               text gaming
# 4        gpt_4  Grafik 2.5D memberikan dimensi yang menarik ke...     []
# 5        gpt_5  Suasana retro terasa apabila bermain dengan gr...     []
# 8        gpt_8  Penggunaan grafik 3D memberikan pengalaman per...     []
# 9        gpt_9  Kesemua butiran jelas terlihat pada resolusi 4...     []
# 10      gpt_10  Saya tidak dapat melepaskan permainan ini deng...     []
# ...        ...                                                ...    ...
# 3623  gpt_3623                 Chill , semua orang ada off days .     []
# 3628  gpt_3628                     Grafik dia memang impressive .     []
# 3635  gpt_3635              Focus fire satu-satu , jangan panic .     []
# 3640  gpt_3640                                           Serius ?     []
# 3645  gpt_3645     Aku cover flank , kita kena maintain control .     []
#
# [346 rows x 3 columns]

# %%
for row in df_no.itertuples(index=False, name=None):
    print(row)
# Out:
# ('Grafik 2.5D memberikan dimensi yang menarik kepada permainan ini .', [])
# ('Suasana retro terasa apabila bermain dengan grafik 2D yang klasik .', [])
# ('Penggunaan grafik 3D memberikan pengalaman permainan yang lebih hidup .', [])
# ('Kesemua butiran jelas terlihat pada resolusi 4K ini .', [])
# ('Saya tidak dapat melepaskan permainan ini dengan grafik 2D yang indah .', [])
# ('Resolusi 4K memberikan ketajaman visual yang tidak dapat dipercayai .', [])
# ('Saya sentiasa kagum dengan kecantikan grafik 3D dalam permainan ini .', [])
# ('Grafik 2.5D memberikan kedalaman visual yang hebat pada permainan ini .', [])
# ('Keindahan grafik 2D ini benar-benar menawan hati pemain .', [])
# ('Grafik 3D membuatkan dunia permainan ini kelihatan hidup .', [])
# ('Resolusi 4K memberikan kejelasan yang memukau pada setiap adegan .', [])
# ('Saya suka permainan ini kerana grafik 2D yang membawa kembali kenangan .', [])
# ('Saya teruja dengan kualiti grafik 2D pada permainan ini .', [])
# ('Saya sentiasa terpesona dengan keunikan grafik 3D dalam permainan ini .', [])
# ('Saya suka bagaimana grafik 2.5D memberikan dimensi tambahan pada permainan .', [])
# ('Grafik 3D ini membuatkan permainan ini terasa seperti dunia yang nyata .', [])
# ('Resolusi 4K ini membuatkan permainan ini kelihatan sungguh mengagumkan .', [])
# ('Grafik 2D yang cantik membuatkan permainan ini begitu menarik .', [])
# ('Resolusi 8K memberikan kejelasan visual yang luar biasa pada permainan ini .', [])
# ('Saya suka bagaimana resolusi 8K ini membuatkan setiap butiran terlihat lebih hidup .', [])
# ('Resolusi 8K ini membenamkan saya sepenuhnya dalam dunia permainan .', [])
# ('Saya tidak boleh lepas dari pengalaman permainan dengan resolusi 8K ini .', [])
# ('Resolusi 8K memberikan permainan ini dimensi visual yang hebat .', [])
# ('Resolusi 8K ini menjadikan setiap detik permainan sungguh menakjubkan .', [])
# ('Resolusi 8K ini menjadikan setiap rincian permainan sangat jelas .', [])
# ('Resolusi 8K ini menjadikan setiap momen dalam permainan ini sangat menarik .', [])
# ('Pembalikan Aset merujuk kepada amalan menghasilkan permainan dengan menggunakan semula atau membalikkan aset permainan lain tanpa penambahbaikan yang ketara .', [])
# ('Permainan Asimetri melibatkan pengalaman permainan yang berbeza antara pemain , sering kali dengan peranan atau kemampuan yang tidak seimbang .', [])
# ('Permainan Asinkron melibatkan pemain yang berinteraksi dengan permainan pada masa yang berbeza , tanpa keperluan untuk serentak atau masa nyata .', [])
# ('Pembalikan Aset menimbulkan kebimbangan dalam industri permainan terhadap amalan mencipta permainan dengan menggunakan semula aset tanpa usaha tambahan .', [])
# ('Permainan Asimetri menghadirkan kepelbagaian dalam permainan dengan memberikan peranan dan kemampuan yang berbeza kepada pemain .', [])
# ('Permainan Asinkron membolehkan pemain berinteraksi dengan permainan pada waktu yang sesuai dengan jadual mereka .', [])
# ('Penggantian Auto membawa elemen strategi dan pembangunan pasukan secara automatik dalam permainan .', [])
# ('Pembalikan Aset mencetuskan perbincangan etika dalam industri permainan berkaitan dengan kegunaan semula aset .', [])
# ('Permainan Asimetri memperkaya pengalaman permainan dengan memberikan peranan dan kemampuan yang unik kepada setiap pemain .', [])
# ('Permainan Asinkron menyediakan fleksibiliti kepada pemain untuk berinteraksi dengan permainan pada waktu yang sesuai bagi mereka .', [])
# ('Penggantian Auto menggabungkan strategi dan elemen permainan peranan dalam satu paket yang dinamik .', [])
# ('Pembalikan Aset mengundang perbincangan mengenai standard kualiti dan keaslian dalam industri permainan .', [])
# ('Permainan Asimetri memupuk kerjasama dan persaingan yang unik antara pemain .', [])
# ('Permainan Asinkron memungkinkan pemain bermain pada masa yang sesuai dengan jadual harian mereka .', [])
# ('Penggantian Auto membawa elemen strategi yang mendalam dalam membuat keputusan permainan .', [])
# ('Pembalikan Aset menimbulkan kebimbangan mengenai keaslian dan kebolehlaksanaan pembangunan permainan .', [])
# ('Permainan Asimetri memperkaya pengalaman bermain dengan menghadirkan perbezaan peranan dan kemampuan .', [])
# ('Permainan Asinkron memudahkan pemain untuk terlibat dalam permainan tanpa mengira masa yang tepat .', [])
# ('Penggantian Auto menyediakan cabaran dan kepuasan dalam menguruskan pasukan atau kumpulan secara automatik .', [])
# ('Keserasian Mundur adalah kemampuan permainan untuk berfungsi pada sistem atau konsol permainan yang lebih lama .', [])
# ('Penyelarasan merujuk kepada tindakan menyesuaikan kuasa , kemahiran , atau objek dalam permainan untuk mengelakkan ketidakseimbangan .', [])
# ('Keserasian Mundur membolehkan pemain menggunakan permainan pada sistem yang lebih lama tanpa masalah .', [])
# ('Keseimbangan adalah faktor penting dalam memastikan pengalaman permainan yang adil dan menyeronokkan .', [])
# ('Penyelarasan membantu mencapai keseimbangan dalam permainan dengan membuat perubahan yang diperlukan .', [])
# ('Pakej Pertempuran memberikan pemain ganjaran khas sepanjang tempoh tertentu , mendorong keterlibatan aktif .', [])
# ('Permainan Royale Pertempuran mencipta ketegangan dan persaingan yang unik di kalangan pemain untuk mencapai kemenangan .', [])
# ('Keserasian Mundur menyediakan aksesibiliti kepada permainan untuk pelbagai generasi konsol .', [])
# ('Keseimbangan membawa pengalaman yang adil dan menyeronokkan bagi semua pemain .', [])
# ('Penyelarasan menjadi proses yang penting untuk mengekalkan keseimbangan dalam permainan yang berkembang .', [])
# ('Pakej Pertempuran menjadi cara yang berkesan untuk memotivasikan pemain dan meningkatkan penglibatan .', [])
# ('Permainan Royale Pertempuran memberikan ketegangan dan keseronokan dalam setiap perlawanan .', [])
# ('Keserasian Mundur memperluaskan aksesibiliti permainan kepada lebih ramai pemain .', [])
# ('Keseimbangan menjadi tumpuan utama dalam memastikan permainan adil dan menyeronokkan .', [])
# ('Penyelarasan melibatkan kecekapan dalam membuat keputusan demi menjaga keseimbangan .', [])
# ('Pakej Pertempuran memberikan insentif yang menarik bagi pemain untuk terus terlibat dalam permainan .', [])
# ('Permainan Royale Pertempuran mencipta pengalaman permainan yang unik dan mencabar .', [])
# ('Keseimbangan memastikan semua pemain memiliki peluang yang adil untuk kejayaan .', [])
# ('Pakej Pertempuran menjadi cara yang berkesan untuk menjadikan permainan lebih menarik dan dinamik .', [])
# ('Permainan Royale Pertempuran membawa elemen kejutan dan strategi dalam setiap pertempuran .', [])
# ('Pelepasan Beta adalah fasa ujian permainan yang dijalankan sebelum pelancaran rasmi untuk mendapatkan maklum balas daripada pemain .', [])
# ('Senarai Hitam merujuk kepada senarai yang mengandungi pemain atau entiti yang dilarang atau dihalang daripada berinteraksi dalam permainan .', [])
# ('Peringkat Bonus adalah tahap tambahan dalam permainan yang memberikan cabaran khas atau ganjaran kepada pemain .', [])
# ('Pek Peningkat adalah bungkusan kandungan tambahan yang pemain boleh beli untuk meningkatkan atau memperkayakan pengalaman permainan .', [])
# ('Menaikkan tahap merujuk kepada tindakan membantu pemain mencapai matlamat atau tahap tertentu dengan bantuan pemain lain .', [])
# ('Bos adalah musuh utama dan kuat yang perlu ditakluki oleh pemain dalam permainan .', [])
# ('Pelepasan Beta membolehkan pemain menguji permainan dan memberikan maklum balas sebelum ia dilancarkan secara rasmi .', [])
# ('Senarai Hitam memberikan cara untuk mengawal tingkahlaku pemain dan mencegah penyalahgunaan dalam permainan .', [])
# ('Papan memberikan landasan permainan dan keputusan strategik dalam sesuatu permainan .', [])
# ('Peringkat Bonus memberikan variasi dan cabaran tambahan dalam permainan .', [])
# ('Pek Peningkat membuka peluang untuk pemain memperoleh kandungan tambahan atau kelebihan .', [])
# ('Menaikkan tahap memberikan sokongan kepada pemain yang mungkin menghadapi kesulitan dalam permainan .', [])
# ('Tetingkap Sepenuhnya Tanpa Sempadan meningkatkan pengalaman visual dengan menghilangkan sempadan tetingkap permainan .', [])
# ('Bos menjadi ujian kekuatan dan strategi pemain dalam permainan .', [])
# ('Serangan Bos-Rush menimbulkan cabaran tinggi dengan siri bos berturut-turut tanpa perhentian .', [])
# ('Pelepasan Beta menyediakan peluang untuk pembangunan lanjut dan penyelarasan permainan sebelum pelancaran rasmi .', [])
# ('Senarai Hitam menjadi alat pentadbiran untuk menjaga komuniti permainan dan menghapuskan pemain yang tidak diingini .', [])
# ('Papan menjadi elemen strategik yang penting dalam membuat keputusan dan pergerakan dalam permainan .', [])
# ('Peringkat Bonus memberikan cabaran tambahan dan ganjaran untuk memotivasikan pemain .', [])
# ('Pek Peningkat menjadi cara untuk pemain meningkatkan dan memperkayakan pengalaman mereka .', [])
# ('Menaikkan tahap memberikan bantuan kepada pemain yang mungkin menghadapi rintangan dalam permainan .', [])
# ('Tetingkap Sepenuhnya Tanpa Sempadan memberikan pemandangan yang lebih imersif dan luas kepada pemain .', [])
# ('Bos memerlukan strategi dan kecekapan untuk diatasi , menambahkan elemen ketegangan dalam permainan .', [])
# ('Serangan Bos-Rush menguji ketahanan dan kemahiran pemain dengan siri bos yang mencabar .', [])
# ('Pelepasan Beta memberikan pemain peluang untuk memberikan maklum balas yang berharga kepada pembangun permainan .', [])
# ('Senarai Hitam menjadi alat penting dalam menjaga komuniti permainan dan mencegah tingkahlaku tidak sihat .', [])
# ('Papan menjadi elemen visual dan taktil yang penting dalam permainan .', [])
# ('Peringkat Bonus memberikan elemen kejutan dan penambahan dalam permainan .', [])
# ('Pek Peningkat memberikan pilihan untuk pemain yang ingin meningkatkan pengalaman permainan mereka .', [])
# ('Menaikkan tahap menjadi cara yang adil untuk membantu pemain mencapai matlamat atau tahap tertentu .', [])
# ('Tetingkap Sepenuhnya Tanpa Sempadan memberikan pilihan visual yang memuaskan kepada pemain .', [])
# ('Bos memberikan perasaan pencapaian dan kemenangan apabila ditakluki .', [])
# ('Serangan Bos-Rush membawa elemen ketegangan dan cabaran yang menyeronokkan .', [])
# ('Pelepasan Beta menyediakan tempoh ujian yang berharga untuk menyelaraskan permainan sebelum dilancarkan .', [])
# ('Senarai Hitam menjadi alat pentadbiran yang berkesan untuk memelihara atmosfera positif dalam komuniti permainan .', [])
# ('Papan menjadi elemen kunci dalam membuat keputusan strategik dan taktikal dalam permainan .', [])
# ('Peringkat Bonus memberikan motivasi tambahan untuk pemain mencapai tahap atau matlamat tertentu .', [])
# ('Pek Peningkat memberikan nilai tambah kepada pemain yang ingin mengkayaikan pengalaman mereka .', [])
# ('Menaikkan tahap menjadi bantuan yang adil untuk pemain dalam menghadapi cabaran permainan .', [])
# ('Tetingkap Sepenuhnya Tanpa Sempadan memberikan fleksibiliti visual kepada pemain .', [])
# ('Bos memberikan perasaan kemenangan yang memuaskan apabila pemain berjaya melaluinya .', [])
# ('Serangan Bos-Rush membawa elemen kejutan dan kecepatan dalam permainan .', [])
# ('Lubang Tanpa Hujung adalah bahaya dalam permainan yang membawa pemain ke kematian atau kegagalan tanpa batasan .', [])
# ('Penembusan merujuk kepada peristiwa atau tindakan menyerang wilayah musuh atau melepasi rintangan dalam permainan .', [])
# ('Penguatan adalah peningkatan sementara kepada kekuatan atau kemahiran watak pemain dalam permainan .', [])
# ('Neraka Peluru adalah jenis permainan tembak-menembak yang menekankan banyak peluru dan serangan intensif .', [])
# ('Spon Peluru adalah musuh dalam permainan yang memerlukan jumlah tembakan yang besar untuk diatasi .', [])
# ('Lubang Tanpa Hujung menjadi rintangan yang menantang dan memerlukan ketepatan pergerakan dari pemain .', [])
# ('Penembusan menjadi taktik yang melibatkan serangan mendalam atau kejiranan wilayah musuh .', [])
# ('Penguatan membawa elemen strategi dengan memberikan pemain kelebihan sementara .', [])
# ('Neraka Peluru memberikan cabaran tinggi dengan pelbagai peluru yang terus datang ke arah pemain .', [])
# ('Spon Peluru memerlukan pemain untuk memanfaatkan sumber peluru mereka dengan bijak untuk mengatasi musuh .', [])
# ('Menyumbat Butang menekankan tindakan tanpa perancangan yang menyebabkan kekacauan dalam permainan .', [])
# ('Menunggu melibatkan kesabaran dan pilihan lokasi strategik untuk mencapai kejayaan .', [])
# ('Lubang Tanpa Hujung menjadi ujian kemahiran pemain dalam mengelak rintangan yang mematikan .', [])
# ('Penembusan memerlukan perancangan dan taktik untuk mengatasi musuh dan mencapai matlamat .', [])
# ('Penguatan membawa unsur kejutan dan kekuatan tambahan kepada pemain .', [])
# ('Neraka Peluru menuntut reflexes dan kemahiran navigasi yang cepat dari pemain .', [])
# ('Spon Peluru menguji kesabaran dan strategi pemain dalam menangani musuh tangguh .', [])
# ('Menyumbat Butang membolehkan pemain menghadapi cabaran tanpa perancangan yang terperinci .', [])
# ('Menunggu memerlukan tahap keterlibatan dan kesabaran untuk mencapai kejayaan .', [])
# ('Lubang Tanpa Hujung menjadi elemen yang mencabar dan menarik dalam rekabentuk permainan .', [])
# ('Penembusan menyajikan cabaran strategik dan elemen taktikal dalam permainan .', [])
# ('Penguatan menawarkan kesan yang menyegarkan dengan memberikan pemain lebih banyak kekuatan .', [])
# ('Neraka Peluru mencipta atmosfera permainan yang pantas dan menekankan tindakan pantas pemain .', [])
# ('Spon Peluru memerlukan pemain untuk merancang serangan mereka dengan bijak .', [])
# ('Menyumbat Butang memberikan pengalaman permainan yang tidak terduga dan menghiburkan .', [])
# ('Menunggu adalah taktik yang memerlukan tahap kesabaran dan kebijaksanaan strategik .', [])
# ('Lubang Tanpa Hujung memberikan elemen cabaran dan risiko yang dinamik dalam permainan .', [])
# ('Penembusan menuntut pemikiran strategik dan keberanian untuk mengekalkan wilayah musuh .', [])
# ('Penguatan membawa unsur kejutan dan variasi dalam pengalaman permainan .', [])
# ('Neraka Peluru menguji respon pemain dan keupayaan mereka untuk bertahan dalam keadaan yang intens .', [])
# ('Spon Peluru memerlukan pemain untuk menyesuaikan taktik mereka berdasarkan jumlah peluru yang dikeluarkan musuh .', [])
# ('Menyumbat Butang membawa unsur spontaniti dan kekacauan dalam permainan .', [])
# ('Menunggu memerlukan pemikiran taktikal dan kesiapan untuk bertahan dalam lokasi yang strategik .', [])
# ('Clock/Clocked merujuk kepada mencapai prestasi atau menamatkan sesuatu dalam jangka masa tertentu dalam permainan .', [])
# ('Clock/Clocked menekankan kepentingan waktu dalam mencapai sasaran dalam permainan .', [])
# ('Clock/Clocked memberikan elemen ketegangan dan cabaran dalam mencapai sasaran dengan batas masa yang ditetapkan .', [])
# ('Clock/Clocked memberikan elemen ketegangan dan kegembiraan dalam usaha mencapai sasaran .', [])
# ('Clock/Clocked menekankan pada pengurusan waktu yang efektif untuk mencapai objektif permainan .', [])
# ('Dalam permainan idle , watak pemain mempunyai animasi idle yang menarik hati , menambah daya tarikan keseluruhan pengalaman .', [])
# ('Permainan indie yang menarik ini menawarkan pengalaman bermain yang unik dengan grafik 2D yang mengasyikkan .', [])
# ('Dalam permainan ini , pemain mempunyai kesihatan tak terbatas , membolehkan mereka mengeksplorasi dunia tanpa had .', [])
# ('Dengan nyawa yang tidak terbatas , pemain boleh mencuba pelbagai strategi tanpa risau kehilangan permainan .', [])
# ('Antara muka yang bersahaja dan responsif memastikan pemain dapat menavigasi permainan dengan mudah dan berkesan .', [])
# ('Dalam permainan ini , pemain menemui petualangan yang seru dengan grafik 2.5D yang memukau .', [])
# ('Pemain dapat mencuba pelbagai strategi dalam pertempuran dengan memiliki nyawa yang tidak terbatas .', [])
# ('Dengan nyawa yang tak terbatas , pemain dapat mengeksplorasi setiap sudut dunia permainan tanpa kebimbangan .', [])
# ('Antara muka yang intuitif memudahkan pemain untuk melibatkan diri dalam permainan dengan lancar .', [])
# ('Kesihatan tak terbatas memberikan pemain ketahanan untuk mengeksplorasi dunia permainan tanpa had .', [])
# ('Dengan nyawa yang tak terbatas , pemain dapat mengambil risiko dan mencuba strategi berani .', [])
# ('Antara muka yang user-friendly memudahkan pemain menavigasi dan berinteraksi dalam dunia permainan .', [])
# ('Dalam permainan ini , pemain dapat menikmati grafik 2D yang klasik dan memukau .', [])
# ('Kesihatan tak terbatas memberikan pemain kebebasan untuk mengeksplorasi dunia tanpa had .', [])
# ('Dengan nyawa yang tak terbatas , pemain dapat mengambil risiko dan mencuba strategi berbeza .', [])
# ('Antara muka yang mesra pemain memudahkan navigasi dan interaksi dalam dunia permainan yang menarik .', [])
# ('Kesihatan tak terbatas membuka peluang bagi pemain untuk mengeksplorasi dunia permainan tanpa had .', [])
# ('Dengan nyawa yang tak terbatas , pemain dapat mengambil risiko dan menjalani pengalaman tanpa kebimbangan .', [])
# ('Watak joker sering menjadi hiburan tambahan , memberikan sentuhan komedi kepada permainan .', [])
# ('Watak joker membawa elemen kejutan dan ketawa , menyumbang kepada pengalaman yang lebih seronok .', [])
# ('Watak joker membawa keceriaan dan ketawa , mencipta pengalaman permainan yang lebih menarik .', [])
# ('Watak joker memberikan sentuhan komedi dan keunikan kepada permainan , menjadikannya lebih menarik .', [])
# ('Watak joker membawa unsur komedi yang menyegarkan dan menjadikan permainan lebih menarik .', [])
# ('Localisasi adalah proses menterjemahkan dan menyesuaikan permainan dengan bahasa dan budaya tempatan .', [])
# ('Kita akan melihat bagaimana elemen-elemen permainan disesuaikan untuk merangkumi pelbagai kumpulan pengguna .', [])
# ('Ia memberi pemain gambaran menyeluruh tentang pengalaman bermain .', [])
# ('Ia boleh termasuk senjata , peralatan , atau item khas .', [])
# ('Pemain boleh membuka kotak ini untuk mendapatkan item secara rawak , dan ia sering menjadi elemen perdebatan dalam industri permainan .', [])
# ('Ia boleh melibatkan penentuan peluang , kadar kejadian , atau cara pemain berinteraksi dengan permainan .', [])
# ('Ia sering menjadi cabaran untuk pemain yang mahir atau mencari pengalaman permainan yang lebih mencabar .', [])
# ('Ia sering melibatkan sihir , mantra , atau keterampilan khusus .', [])
# ('Ia melibatkan pelbagai tindakan dan keputusan yang dibuat oleh pemain untuk mencapai matlamat dalam permainan .', [])
# ('Localisasi adalah proses menyesuaikan permainan dengan budaya dan bahasa tempatan .', [])
# ('Dalam konteks permainan video , ini bermaksud mengubah elemen permainan agar sesuai dan difahami oleh komuniti tempatan .', [])
# ('Ia memberikan pemain pandangan menyeluruh tentang pengalaman permainan tanpa diedit atau dipotong .', [])
# ('Ini mungkin termasuk senjata , peralatan , atau item berharga lain yang ditemui atau dimenangi .', [])
# ('Ia sering menjadi cabaran untuk pemain yang mahir dan ingin mencuba keadaan sulit .', [])
# ('Pemain boleh menggunakannya untuk memudahkan pelbagai tindakan atau tugas dengan sekali klik .', [])
# ('Ini boleh melibatkan mantera , sihir , atau keterampilan khusus yang memberikan kelebihan .', [])
# ('Ini termasuk membuat keputusan , melaksanakan strategi , dan berinteraksi dengan dunia permainan .', [])
# ('Ini membolehkan interaksi antara pemain dari seluruh dunia dalam satu sesi permainan .', [])
# ('Ini memberikan kebebasan kepada pemain untuk memilih cara mereka menjalani pengalaman permainan .', [])
# ('Ini boleh melibatkan pertempuran langsung atau pertandingan secara dalam talian .', [])
# ('Quick Save merujuk kepada fungsi penyimpanan cepat di dalam permainan .', [])
# ('Pemain boleh menyimpan kemajuan permainan mereka pada bila-bila masa untuk mengelakkan kehilangan kemajuan jika mereka mati atau menghadapi cabaran yang sukar .', [])
# ('Ini biasanya memerlukan kerjasama dan taktik kumpulan .', [])
# ('Ia membolehkan pemain terus bermain tanpa perlu bermula dari awal .', [])
# ('Sandbox merujuk kepada permainan yang memberikan pemain kebebasan yang besar untuk mencipta , mengubah , dan menjelajah dalam dunia permainan .', [])
# ('Ini sering melibatkan pembinaan atau kreativiti pemain .', [])
# ('Ini melibatkan gerakan senyap , pemakaian perlindungan bayangan , dan taktik mengelak untuk mencapai matlamat .', [])
# ('Pemain menggunakan strategi dan pengetahuan mendalam permainan untuk mencapai rekod waktu terbaik .', [])
# ('Strategy Game merujuk kepada jenis permainan yang menekankan pemikiran strategik .', [])
# ('Pemain perlu merancang dan melaksanakan strategi untuk menang dalam cabaran .', [])
# ('Tutorial adalah bahagian awal permainan yang bertujuan untuk mengajar pemain tentang mekanisme , kawalan , dan konsep permainan sebelum mereka memulakan pengalaman sebenar .', [])
# ('Zombie Game adalah permainan yang menitikberatkan tema atau ancaman zombie .', [])
# ('Pemain biasanya dihadapkan dengan hordes zombie dan perlu bertahan hidup .', [])
# ('Kemenangan kebanyakan waktu membawa kepada kemajuan dalam cerita atau tahap permainan .', [])
# ('Localisasi adalah penting dalam permainan untuk memastikan pemain dari pelbagai kawasan memahami cerita dan antara muka dengan baik .', [])
# ('Bermain dengan kadar kejayaan yang rendah memerlukan kecekalan dan kemahiran tinggi , tetapi memberikan pengalaman yang mencabar .', [])
# ('Banyak gila , tapi kena cari yang betul-betul massive .', [])
# ('Serius ke ?', [])
# ('Ya lah , ada je yang tak bertanggungjawab nak spoil game .', [])
# ('Betul tu , challenge dia tinggi gila .', [])
# ('Ya , ada je yang tak bertanggungjawab nak spoil game .', [])
# ('Sedih betul .', [])
# ('Kau dah try ?', [])
# ('Game match-3 ni addictive gila , susah nak stop .', [])
# ('Match fixing buat community tak percaya .', [])
# ('Match fixing ni buat game tak seru .', [])
# ('Achievements semua dah unlock , feeling accomplished .', [])
# ('Game ni terlalu challenging , tapi best .', [])
# ('Modding community game ni besar , banyak creative mods .', [])
# ('Team composition adalah pemilihan karakter atau kelas yang membentuk tim dalam game , seringkali untuk mencapai keseimbangan dan sinergi .', [])
# ('Tech tree adalah representasi grafis dari perkembangan dan evolusi teknologi atau kemampuan dalam game .', [])
# ('Travel time adalah waktu yang dibutuhkan untuk proyektil atau serangan untuk mencapai target dalam game .', [])
# ('Two-handed weapon adalah senjata dalam game yang memerlukan kedua tangan karakter untuk digunakan .', [])
# ('Utility adalah kemampuan atau objek dalam game yang memberikan manfaat tambahan kepada pemain atau tim .', [])
# ('Wallbang adalah tembakan atau serangan yang berhasil melewati atau menembus tembok atau objek dalam game .', [])
# ('World-building adalah proses pembentukan dan pengembangan dunia fiksi dalam game , termasuk sejarah , budaya , dan geografi .', [])
# ('X-axis dan Y-axis adalah sumbu horizontal dan vertikal pada sistem koordinat dalam game , mengontrol pergerakan karakter atau kamera .', [])
# ('Yaw , pitch , dan roll adalah gerakan rotasi yang dikendalikan oleh pemain dalam game untuk mengubah orientasi karakter atau kendaraan .', [])
# ('Z-axis adalah sumbu kedalaman pada sistem koordinat dalam game , mengontrol pergerakan ke atas dan ke bawah .', [])
# ('Zoom adalah kemampuan untuk memperbesar pandangan atau fokus dalam game , sering digunakan dalam senjata jarak jauh .', [])
# ('Zipper merge adalah strategi pemain untuk menyatukan atau menggabungkan kekuatan dengan pemain lain secara efisien dalam game tim .', [])
# ('Sure , tak sabar nak tengok berapa lama kita boleh bertahan !', [])
# ('Takpe , aku dah prepare mental dah !', [])
# ('Bagus idea tu , kita boleh support satu sama lain .', [])
# ('Haah , kita kena coordinate betul-betul .', [])
# ('Serious betul , kita kena fokus ni .', [])
# ('Betul , dorang punya firepower kuat .', [])
# ('Okay , kita cuba adjust .', [])
# ('Bagus , kita takkan miss target .', [])
# ('Aku dah set auto-targeting , senang nak aim .', [])
# ('Smart move , kita takkan terlepas tembakan .', [])
# ('Haha , kasi dorang tahu kita dalam control .', [])
# ('Haha , korang memang best lah .', [])
# ('Entah la , mungkin cara dorang celebrate kot .', [])
# ('Korang memang powerhouse lah .', [])
# ('Betul , kalau tak , kita kena blame .', [])
# ('Aduh , memang stress gila lah bila kena dari teammate sendiri .', [])
# ('Kita boost firepower dulu , baru push forward .', [])
# ('Ingat nak elak teleport spot tu .', [])
# ('Dorang dah start predict gerakan kita .', [])
# ('Aku try switch up tactics sikit .', [])
# ('Bagus idea , test damage dan range .', [])
# ('Sama-sama brainstorm strategy yang baru .', [])
# ('Ok , kita meet up sana nanti .', [])
# ('Kita study lawan dulu sebelum match .', [])
# ('Kena avoid friendly casualties .', [])
# ('Jom check out apa yang ada .', [])
# ('Kita try mislead lawan .', [])
# ('Kita focus pada weak points lawan .', [])
# ('Kena cautious bila engage .', [])
# ('Kita keep eye on surroundings .', [])
# ('Jangan bagi lawan read kita .', [])
# ('Kita dah unlock powerful abilities .', [])
# ('Seronok tengok character dari luar , lebih immersive .', [])
# ('Memang handy , boleh attack dari jauh .', [])
# ('Haah , best relaxkan mind .', [])
# ('Compete dengan diri sendiri , best kan ?', [])
# ('Nostalgia gila dengar lagu tu .', [])
# ('Betul , asalkan timing tepat .', [])
# ('Jangan la buat toxic chat dalam game .', [])
# ('Tak cool langsung .', [])
# ('Okay , aku cover lane ni .', [])
# ('Tak ramai yang guna , tapi effective .', [])
# ('Lagi best dari stats yang high .', [])
# ('Mahal tapi worth it .', [])
# ('Boleh avoid obstacles dengan lebih mudah .', [])
# ('Jangan la buat cakap toxic dalam game .', [])
# ('Boleh elakkan obstacles dengan lebih mudah .', [])
# ('Semangat tu penting , jangan give up .', [])
# ('Lama sikit tapi secure .', [])
# ('Memang takde tandingan la tu .', [])
# ("Let's go , time to shine !", [])
# ('Skill dan strategy penting .', [])
# ('Kita punya skill jadi highlight .', [])
# ('Exciting , tak sabar nak explore .', [])
# ('Aku nak unlock content ni , kena complete quests .', [])
# ('Itu rare item , worth it .', [])
# ('Good decision , effort tu nampak .', [])
# ('Setiap move kena think carefully .', [])
# ('Lama sikit tapi keselamatan tu penting .', [])
# ('Power gila character tu !', [])
# ('Ini punya peluang , jangan lepaskan .', [])
# ('Pemilihan weapon yang berani .', [])
# ('Antaranya apa yang kita akan jumpa ?', [])
# ('Aku nak unlock content ni , kena complete challenges .', [])
# ('Rare items tu worth effort .', [])
# ('Tak best , hype dah tinggi .', [])
# ('Seru gila , terasa macam action movie .', [])
# ('Best , banyak potential job opportunities .', [])
# ('Storytelling dia unique .', [])
# ('Sama , tambah immersion .', [])
# ('Memang , design character dia cantik .', [])
# ('Setiap unlock tu macam medali kemenangan .', [])
# ('Aku nak naik taraf weapon ni , biar lagi hebat damage .', [])
# ('Naik taraf character pun penting , jadi lebih kuat .', [])
# ('Seru gila , macam balapan tapi dalam game .', [])
# ('Best , boleh buat game sendiri nanti .', [])
# ('Storytelling dia unik dan menarik .', [])
# ('Terasa lebih involved dalam game .', [])
# ('Best , design dia memang menawan hati .', [])
# ('Atmosphere dia sangat tenang .', [])
# ('Taknak miss apa-apa detail .', [])
# ('Bagus tu , unexpected .', [])
# ('Vertical movement penting .', [])
# ('Aku pun , berguna dalam platformers .', [])
# ('Macam jadi parkour master .', [])
# ('Report dia lah , tak fair .', [])
# ('Kena elak polis la ni .', [])
# ('Bestnya , save time .', [])
# ('Atmosfera dia sangat menyentuh hati .', [])
# ('Bukan game biasa , tapi pengalaman yang mendalam .', [])
# ('Tak nak lepaskan sebarang rahsia atau detik penting .', [])
# ('Menarik , lawan tak tahu apa yang hit them .', [])
# ('Pergerakan vertical memang membuka peluang yang menarik .', [])
# ('Terutamanya dalam game platformer .', [])
# ('Rasa macam jadi pakar parkour pulak .', [])
# ('Report dia , kita nak game yang fair .', [])
# ('Kena pandai elak polis la ni .', [])
# ('Wah , jimat masa betul .', [])
# ('Ave !', [])
# ('Kita menang !', [])
# ('Best teamwork !', [])
# ('Wow , serious spender .', [])
# ('Relax , everyone whiffs sometimes .', [])
# ('Graphics dia power .', [])
# ('Focus fire satu-satu .', [])
# ('Security first , better safe than sorry .', [])
# ('Serious ?', [])
# ('Roger , aku cover flank .', [])
# ('Ave ni selalunya digunakan sebagai sorakan untuk menyambut pencapaian hebat dalam game .', [])
# ('Kita menang lagi !', [])
# ('Team kita memang hebat !', [])
# ('Serious spender , tak main-main .', [])
# ('Chill , semua orang ada off days .', [])
# ('Grafik dia memang impressive .', [])
# ('Focus fire satu-satu , jangan panic .', [])
# ('Serius ?', [])
# ('Aku cover flank , kita kena maintain control .', [])

# %% [markdown]
# # 3. &nbsp;&nbsp; [English Words Analysis](#home) <a id='english_gpt'></a>
#
# We extract all English words (which includes gaming terms) for analysis as incorrect pronunciation is likely result from English words (which is of minority class) rather than Malay words.
#
# Steps are as follows:
#
# <style>
#     table {
#         width: 70%;
#         table-layout:fixed;
#     }
#     th:nth-child(1),
#     td:nth-child(1) {
#         width: 3%;
#     }
#     th:nth-child(2),
#     td:nth-child(2) {
#         width: 17%;
#     }
#     th:nth-child(3),
#     td:nth-child(3) {
#         width: 80%;
#     }
# </style>
#
# | S/N | Step | Description |
# | -- | -- | -- |
# | 1. | [Extract English Words](#extract_english) | &bull; Extract all English terms from GPT corpus via [polyglot](https://github.com/EleutherAI/polyglot). <br>&bull; Those English terms that are yet to be found in `mapping` dictionary and combined gaming terms will either be translated or modified such that VITS Malaya model is able generate comprehensible audio. |
# | 2. | [Identify Unique English Words](#unique_english) | &bull; Identify list of English words used in GPT corpus that are not found in `mapping` and combined gaming terms. |
# | 3. | [Translate Unique English Words](#translate_unique) | &bull; Translate these unique English words to reduce the number of English words present in GPT corpus. |
# | 4. | [Identify Untranslated English Words](#untranslated_unique) | &bull; Identify untranslated English words, which we have to check if Malay VITS model is able to generate comprehensible audio from these words. <br>&bull; Characters may have to be altered to generate desired effect (best effort basis). |
# | 5. | [Identify Wrong Translations](#wrong_translation) | &bull; Identify English words that deviate from translated version by more than 5 characters. |

# %%
df_gpt["en_words"] = df_gpt["text"].parallel_map(extract_en_words)
df_gpt.to_csv(cfg.paths.gpt_csv_path, index=False)
df_gpt
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=456), Label(value='0 / 456'))), HB…
#             id                                               text  \
# 0        gpt_0  Dengan mendapat 1-up , saya boleh teruskan per...
# 1        gpt_1  Grafik 16-bit memberikan sentuhan nostalgia ya...
# 2        gpt_2  Saya berjaya melakukan 1CC pada permainan arke...
# 3        gpt_3  Pertarungan 1v1 itu benar-benar mencabar kemah...
# 4        gpt_4  Grafik 2.5D memberikan dimensi yang menarik ke...
# ...        ...                                                ...
# 3641  gpt_3641                          Macam mana gameplay dia ?
# 3642  gpt_3642  Zone dalam game merujuk kepada kawasan atau wi...
# 3643  gpt_3643                       Okey , aku cover left zone .
# 3644  gpt_3644  Zoning dalam game adalah strategi untuk kawal ...
# 3645  gpt_3645     Aku cover flank , kita kena maintain control .
#
#                 gaming                    en_words
# 0               [1-up]                          []
# 1             [16-bit]      [Grafik, 16-bit, unik]
# 2                [1CC]                          []
# 3                [1v1]                          []
# 4                   []           [Grafik, dimensi]
# ...                ...                         ...
# 3641  [gameplay, mana]                  [gameplay]
# 3642            [zone]          [Zone, game, peta]
# 3643            [zone]   [Okey, cover, left, zone]
# 3644          [zoning]    [game, strategi, secure]
# 3645                []  [cover, maintain, control]
#
# [3646 rows x 4 columns]

# %% [markdown]
# ## 3.1 &nbsp;&nbsp; [Extract English Words](#home) <a id='extract_english'></a>
#
# Update Counter object on list of English words used in each transcripts.
#
# Our observations:
#
# 1. Malay words that are restructured to have similar sounds are considered as English words by polyglot e.g. `elemen`, `strategi`, `Okey`, `responsiviti`.
# 2. Some Malay word is wrongly captured as English word e.g. `sering`, which means `often` in English.

# %%
df_en_word = gen_en_counter(df_gpt)
df_en_word = df_en_word.reset_index()
df_en_word.columns = ["words", "frequency"]
df_en_word.to_csv(cfg.paths.gpt_en_path)
df_en_word
# Out:
# Total number of English words detected by polyglot : 1833
#            words  frequency
# 0           game       1030
# 1         elemen        181
# 2       strategi        140
# 3         sering        123
# 4         player        112
# ...          ...        ...
# 1828   comebacks          1
# 1829  enthusiasm          1
# 1830       leave          1
# 1831     lasting          1
# 1832        okey          1
#
# [1833 rows x 2 columns]

# %% [markdown]
# ## 3.2 &nbsp;&nbsp; [Identify Unique English Words](#home) <a id='unique_english'></a>
#
# Identify list of English words that are not in gaming terms and in `mapping` dictionary
#
# Our rationale:
#
# 1. Malaya VITS model is able to pronounce Indonesian and actual Malay words easily. Hence the issue is on our to handle non-Malay words specifically English.
# 2. By identifying the list of English words that are not in gaming terms in `mapping` dictionary, we able to either translate these English words to Malay or to perform mapping if these English words are not able to be translated.
#
# In addition, we will perform translation on these unique English words using [translators](https://pypi.org/project/translators/)
#
# Total of 1515 English words detected.

# %%
df_en_word_new = gen_new_en(cfg, df_en_word)
df_en_word_new
# Out:
# Original number of English words detected : 1833
# Number of English words that were not found in combined gaming terms and in mapping : 1510
# Number of English words removed from list : 323
#                id          words
# 0        new_en_0      abilities
# 1        new_en_1        ability
# 2        new_en_2         abrupt
# 3        new_en_3         access
# 4        new_en_4  accessibility
# ...           ...            ...
# 1505  new_en_1505         zipper
# 1506  new_en_1506         zombie
# 1507  new_en_1507           zona
# 1508  new_en_1508          zones
# 1509  new_en_1509           zoom
#
# [1510 rows x 2 columns]

# %% [markdown]
# ## 3.3 &nbsp;&nbsp; [Translate Unique English Words](#home) <a id='translate_unique'></a>
#
# We use Malaya transformer module and Malaya dictionary module to translate the English text to Malay. We didn't use `translators` module has a limitation on number of words translated. Translating English words that are not found in `mapping` and combined gaming terms reduces number of English words present in GPT corpus:
#
# - Presence of excess English words may affect the sound quality of Malay spoken words.
# - We do not want model to be confuse between English and Malay words; and therefore generate incomprehenisble audio (i.e. mixed between English and Malay words).
#
# Our observations:
#
# 1. It appears that Malaya dictionary translate English word to Malay while Malaya transformer translate English word to Indonesian e.g. 'akses' versus 'capaian'

# %%
df_en_word_new = append_translated(cfg, df_en_word_new)
df_en_word_new
# Out:
# INFO:malaya_boilerplate.huggingface:downloading frozen huseinzol05/v23-preprocessing/english-malay-200k.json
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=189), Label(value='0 / 189'))), HB…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=189), Label(value='0 / 189'))), HB…
# 2024-01-28 17:18:35.580746: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
#                id          words    dictionary  \
# 0        new_en_0      abilities     abilities
# 1        new_en_1        ability     kebolehan
# 2        new_en_2         abrupt        abrupt
# 3        new_en_3         access         akses
# 4        new_en_4  accessibility  aksesibiliti
# ...           ...            ...           ...
# 1505  new_en_1505         zipper           zip
# 1506  new_en_1506         zombie        zombie
# 1507  new_en_1507           zona          zona
# 1508  new_en_1508          zones         zones
# 1509  new_en_1509           zoom          zoom
#
#                               transformer  words_len  dictionary_len  \
# 0                               kebolehan          9               9
# 1                               keupayaan          7               9
# 2                               Tiba-tiba          6               6
# 3                                 capaian          6               5
# 4                          kebolehcapaian         13              12
# ...                                   ...        ...             ...
# 1505                           ritsleting          6               3
# 1506                                zombi          6               6
# 1507  zonaCity in Illinois, United States          4               4
# 1508                                  zon          5               5
# 1509                                  zum          4               4
#
#       transformer_len
# 0                   9
# 1                   9
# 2                   9
# 3                   7
# 4                  14
# ...               ...
# 1505               10
# 1506                5
# 1507               35
# 1508                3
# 1509                3
#
# [1510 rows x 7 columns]

# %% [markdown]
# ## 3.4 &nbsp;&nbsp; [Identify Untranslated English Words](#home) <a id='untranslated_unique'></a>
#
# We checked for untranslated English words via Malaya dictionary, Malaya transformer; as well as both Malaya dictionary and Malaya transformer.
#
# Our observations:
#
# 1. Malaya dictionary is conservative in translation (i.e. 824 untranslated) compared to Malaya transformer (i.e. 405).
# 2. However Malaya dictionary appears to be closer translation to conversational Malay while Malaya transformers appears to translate English words to Indonesian.
# 3. 391 words are untranslated by both Malaya dictionary and Malaya transformer. This is likely due to either original words are already proper Malay words (Polyglot classify Malay word that sound like English as English words); or there are no suitable words to translate hence both methods return the original words.

# %% [markdown]
# ##### Untranslated English words via Malaya dictionary

# %%
# Identify words that are identical in `words` and `dictionary` columns
df_dictionary = df_en_word_new.loc[df_en_word_new["dictionary"] == df_en_word_new["words"], :]
print(f"Number of untranslated English words via Malaya dictionary : {len(df_dictionary)}")
df_dictionary
# Out:
# Number of untranslated English words via Malaya dictionary : 823
#                id             words        dictionary  \
# 0        new_en_0         abilities         abilities
# 2        new_en_2            abrupt            abrupt
# 8        new_en_8       accountable       accountable
# 10      new_en_10  action-adventure  action-adventure
# 11      new_en_11           actions           actions
# ...           ...               ...               ...
# 1504  new_en_1504       zero-player       zero-player
# 1506  new_en_1506            zombie            zombie
# 1507  new_en_1507              zona              zona
# 1508  new_en_1508             zones             zones
# 1509  new_en_1509              zoom              zoom
#
#                               transformer  words_len  dictionary_len  \
# 0                               kebolehan          9               9
# 2                               Tiba-tiba          6               6
# 8                        bertanggungjawab         11              11
# 10                       action-adventure         16              16
# 11                               tindakan          7               7
# ...                                   ...        ...             ...
# 1504                         pemain-sifar         11              11
# 1506                                zombi          6               6
# 1507  zonaCity in Illinois, United States          4               4
# 1508                                  zon          5               5
# 1509                                  zum          4               4
#
#       transformer_len
# 0                   9
# 2                   9
# 8                  16
# 10                 16
# 11                  8
# ...               ...
# 1504               12
# 1506                5
# 1507               35
# 1508                3
# 1509                3
#
# [823 rows x 7 columns]

# %% [markdown]
# ##### Untranslated English words via Malaya transformer

# %%
# Identify words that are identical in `words` and `transformer` columns
df_transformer = df_en_word_new.loc[df_en_word_new["transformer"] == df_en_word_new["words"], :]
print(f"Number of untranslated English words via Malaya transformer : {len(df_transformer)}")
df_transformer
# Out:
# Number of untranslated English words via Malaya transformer : 404
#                id             words        dictionary       transformer  \
# 10      new_en_10  action-adventure  action-adventure  action-adventure
# 15      new_en_15      adaptabiliti      adaptabiliti      adaptabiliti
# 17      new_en_17          adaptasi          adaptasi          adaptasi
# 25      new_en_25            adegan            adegan            adegan
# 26      new_en_26              adil              adil              adil
# ...           ...               ...               ...               ...
# 1478  new_en_1478              wasd              wasd              wasd
# 1487  new_en_1487            whiffs            whiffs            whiffs
# 1489  new_en_1489               wii               wii               wii
# 1495  new_en_1495               wow               wow               wow
# 1497  new_en_1497              xbox              xbox              xbox
#
#       words_len  dictionary_len  transformer_len
# 10           16              16               16
# 15           12              12               12
# 17            8               8                8
# 25            6               6                6
# 26            4               4                4
# ...         ...             ...              ...
# 1478          4               4                4
# 1487          6               6                6
# 1489          3               3                3
# 1495          3               3                3
# 1497          4               4                4
#
# [404 rows x 7 columns]

# %% [markdown]
# ##### Untranslated English words via Malaya dictionary and Malaya transformer

# %%
# Identify words that are identical in all 3 columns (i.e. `words`, `dictionary`, and `transformer`)
df_dictionary_transformer = df_en_word_new.loc[
    (
        (df_en_word_new["dictionary"] == df_en_word_new["transformer"])
        & (df_en_word_new["transformer"] == df_en_word_new["words"])
    ),
    :,
]

print(f"Number of untranslated English words via Malaya dictionary and transformer : {len(df_dictionary_transformer)}")
df_dictionary_transformer
# Out:
# Number of untranslated English words via Malaya dictionary and transformer : 390
#                id             words        dictionary       transformer  \
# 10      new_en_10  action-adventure  action-adventure  action-adventure
# 15      new_en_15      adaptabiliti      adaptabiliti      adaptabiliti
# 17      new_en_17          adaptasi          adaptasi          adaptasi
# 25      new_en_25            adegan            adegan            adegan
# 26      new_en_26              adil              adil              adil
# ...           ...               ...               ...               ...
# 1478  new_en_1478              wasd              wasd              wasd
# 1487  new_en_1487            whiffs            whiffs            whiffs
# 1489  new_en_1489               wii               wii               wii
# 1495  new_en_1495               wow               wow               wow
# 1497  new_en_1497              xbox              xbox              xbox
#
#       words_len  dictionary_len  transformer_len
# 10           16              16               16
# 15           12              12               12
# 17            8               8                8
# 25            6               6                6
# 26            4               4                4
# ...         ...             ...              ...
# 1478          4               4                4
# 1487          6               6                6
# 1489          3               3                3
# 1495          3               3                3
# 1497          4               4                4
#
# [390 rows x 7 columns]

# %% [markdown]
# ## 3.5 &nbsp;&nbsp; [Identify Wrong Translations](#home) <a id='wrong_translation'></a>
#
# We identify all translations that are longer than the original word by 5 characters for both Malaya dictionary and Malaya transformer.
#
# Our observations:
#
# 1. Words that are not seen by transformer seemed to classify as a location in United States:
#
# ```
# haah -> haahCity in Virginia, United States
# mario -> marioCity in Virginia, United States
# mvp -> mvpCity in California, United States
# progresi -> progresiCity in Illinois, United States
# sarana -> saranaCity in Illinois, United States
# youtube -> youtubeCity in Minnesota, United States
# zona -> zonaCity in Illinois, United States
# loading -> loading... (28/2019) Ia juga mengaku tak bisa
# ```
#
# 2. Proper Malay words are being translated:
#
# ```
# kritikan -> kritikStock label
# perjalanan -> perjalanan perjalanan
# ```
#
# 3. Inconsistent treatment between Malaya dictionary and Malaya transformer makes it difficult to decide which is a better translation especially when we are not native Malay speaker. For example:
#
# ```
# 'overwhelming' versus 'sangat menggembirakan' versus 'luar biasa'
# 'fix' versus 'menetapkan' versus 'baiki'
# 'crowd' versus 'orang ramai' versus 'kerumunan'
# ```

# %% [markdown]
# ##### Potentially wrong translation via Malaya dictionary

# %%
# Words that deviate from translated word via Malaya dictionary by 5 characters
df_wrong_dictionary = df_en_word_new.loc[abs(df_en_word_new["words_len"] - df_en_word_new["dictionary_len"]) > 5, :]
print(f"Number of potentially wrong translation via Malaya dictionary: {len(df_wrong_dictionary)}")
df_wrong_dictionary
# Out:
# Number of potentially wrong translation via Malaya dictionary: 49
#                id            words              dictionary  \
# 14      new_en_14            adapt            menyesuaikan
# 47      new_en_47         alienate       mengasingkan diri
# 56      new_en_56           ambush         serangan hendap
# 121    new_en_121            blame             menyalahkan
# 242    new_en_242            crowd             orang ramai
# 259    new_en_259           decide       membuat keputusan
# 269    new_en_269           define            mentakrifkan
# 304    new_en_304      directional                    arah
# 373    new_en_373    encouragement                 galakan
# 454    new_en_454              fix              menetapkan
# 485    new_en_485    functionality                  fungsi
# 488    new_en_488             gain              keuntungan
# 571    new_en_571         identify          mengenal pasti
# 599    new_en_599       inevitable   tidak dapat dielakkan
# 610    new_en_610        integrate        mengintegrasikan
# 635    new_en_635        invisible     tidak dapat dilihat
# 636    new_en_636          involve         melibatkan diri
# 638    new_en_638     irreversible  tidak dapat dipulihkan
# 717    new_en_717             left            ditinggalkan
# 759    new_en_759          massive           besar-besaran
# 760    new_en_760        massively    secara besar-besaran
# 781    new_en_781        memorable   tidak dapat dilupakan
# 794    new_en_794            merge           menggabungkan
# 829    new_en_829             more              lebih lagi
# 851    new_en_851             next              seterusnya
# 854    new_en_854            noise            bunyi bising
# 879    new_en_879         optimize          mengoptimumkan
# 889    new_en_889          overall          keseluruhannya
# 892    new_en_892     overwhelming   sangat menggembirakan
# 933    new_en_933  personalization                peribadi
# 946    new_en_946             pink             merah jambu
# 1033  new_en_1033             rare          jarang berlaku
# 1054  new_en_1054           reduce            mengurangkan
# 1056  new_en_1056           refine          menyempurnakan
# 1101  new_en_1101           review           kajian semula
# 1104  new_en_1104        rewarding        memberi ganjaran
# 1144  new_en_1144            scene         tempat kejadian
# 1182  new_en_1182              set              ditetapkan
# 1221  new_en_1221           slowly          perlahan-lahan
# 1226  new_en_1226           sniper           penembak curi
# 1232  new_en_1232             some              sesetengah
# 1301  new_en_1301             stun     menyebabkan pengsan
# 1309  new_en_1309     supernatural                   ghaib
# 1316  new_en_1316        surrender        menyerahkan diri
# 1319  new_en_1319          survive          bertahan hidup
# 1345  new_en_1345         teamwork        kerja berpasukan
# 1380  new_en_1380          tilting           mencondongkan
# 1437  new_en_1437    unpredictable  tidak dapat diramalkan
# 1470  new_en_1470          walking           berjalan kaki
#
#                  transformer  words_len  dictionary_len  transformer_len
# 14                  adaptasi          5              12                8
# 47              mengasingkan          8              17               12
# 56             serang hendap          6              15               13
# 121                 salahkan          5              11                8
# 242                kerumunan          5              11                9
# 259                 putuskan          6              17                8
# 269                 takrifan          6              12                8
# 304                     arah         11               4                4
# 373                  galakan         13               7                7
# 454                    baiki          3              10                5
# 485               kefungsian         13               6               10
# 488                  gandaan          4              10                7
# 571              kenal pasti          8              14               11
# 599    tidak dapat dielakkan         10              21               21
# 610              disepadukan          9              16               11
# 635                halimunan          9              19                9
# 636               melibatkan          7              15               10
# 638   tidak boleh dipulihkan         12              22               22
# 717                     kiri          4              12                4
# 759                    masif          7              13                5
# 760     secara besar-besaran          9              20               20
# 781    tidak dapat dilupakan          9              21               21
# 794                   gabung          5              13                6
# 829                    lebih          4              10                5
# 851               berikutnya          4              10               10
# 854                   hingar          5              12                6
# 879           mengoptimumkan          8              14               14
# 889              keseluruhan          7              14               11
# 892               luar biasa         12              21               10
# 933            personalisasi         15               8               13
# 946              merah jambu          4              11               11
# 1033                  jarang          4              14                6
# 1054               kurangkan          6              12                9
# 1056               perhalusi          6              14                9
# 1101                  ulasan          6              13                6
# 1104        Memberi ganjaran          9              16               16
# 1144                  adegan          5              15                6
# 1182              ditetapkan          3              10               10
# 1221                perlahan          6              14                8
# 1226                  sniper          6              13                6
# 1232                beberapa          4              10                8
# 1301                    stun          4              19                4
# 1309                   ghaib         12               5                5
# 1316                menyerah          9              16                8
# 1319                bertahan          7              14                8
# 1345        kerja berpasukan          8              16               16
# 1380                  miring          7              13                6
# 1437    tidak dapat dijangka         13              22               20
# 1470                berjalan          7              13                8

# %% [markdown]
# ##### potentially wrong translation via Malaya transformer

# %%
# Words that deviate from translated word via Malaya transformer by 5 characters
df_wrong_transformer = df_en_word_new.loc[abs(df_en_word_new["words_len"] - df_en_word_new["transformer_len"]) > 5, :]
print(f"Number of potentially wrong translation via Malaya transformer : {len(df_wrong_transformer)}")
df_wrong_transformer
# Out:
# Number of potentially wrong translation via Malaya transformer : 57
#                id          words              dictionary  \
# 56      new_en_56         ambush         serangan hendap
# 177    new_en_177  clock/clocked           clock/clocked
# 258    new_en_258      debugging               debugging
# 304    new_en_304    directional                    arah
# 317    new_en_317     distribute             mengedarkan
# 319    new_en_319       distrust              kesangsian
# 373    new_en_373  encouragement                 galakan
# 374    new_en_374            end                   akhir
# 375    new_en_375        endless                 endless
# 381    new_en_381        enhance            meningkatkan
# 484    new_en_484            fun                     fun
# 490    new_en_490  game-breaking           game-breaking
# 507    new_en_507  gesture-based           gesture-based
# 520    new_en_520         grafik                  grafik
# 531    new_en_531           haah                    haah
# 558    new_en_558          honor                   honor
# 591    new_en_591         in-app                  in-app
# 592    new_en_592        in-game                 in-game
# 599    new_en_599     inevitable   tidak dapat dielakkan
# 638    new_en_638   irreversible  tidak dapat dipulihkan
# 647    new_en_647   jaw-dropping            jaw-dropping
# 695    new_en_695       kritikan                kritikan
# 731    new_en_731           load                   beban
# 732    new_en_732        loading               memuatkan
# 757    new_en_757          mario                   mario
# 760    new_en_760      massively    secara besar-besaran
# 781    new_en_781      memorable   tidak dapat dilupakan
# 839    new_en_839     multi-user              multi-user
# 844    new_en_844            mvp                     mvp
# 851    new_en_851           next              seterusnya
# 867    new_en_867            off                     off
# 873    new_en_873      on-the-go               on-the-go
# 876    new_en_876  opportunities           opportunities
# 879    new_en_879       optimize          mengoptimumkan
# 891    new_en_891      overpower                mengalah
# 897    new_en_897        pack-in                 pack-in
# 928    new_en_928     perjalanan              perjalanan
# 946    new_en_946           pink             merah jambu
# 947    new_en_947   pink-colored            pink-colored
# 1004  new_en_1004       progresi                progresi
# 1037  new_en_1037          react                   react
# 1049  new_en_1049   reallocation            reallocation
# 1053  new_en_1053       recreate             buat semula
# 1104  new_en_1104      rewarding        memberi ganjaran
# 1137  new_en_1137         sarana                  sarana
# 1182  new_en_1182            set              ditetapkan
# 1309  new_en_1309   supernatural                   ghaib
# 1313  new_en_1313         surely                   pasti
# 1341  new_en_1341          tarik                   tarik
# 1345  new_en_1345       teamwork        kerja berpasukan
# 1412  new_en_1412         triple                  triple
# 1437  new_en_1437  unpredictable  tidak dapat diramalkan
# 1438  new_en_1438     unreliable              unreliable
# 1469  new_en_1469          waktu                   waktu
# 1488  new_en_1488          wider                   wider
# 1500  new_en_1500        youtube                 youtube
# 1507  new_en_1507           zona                    zona
#
#                                             transformer  words_len  \
# 56                                        serang hendap          6
# 177                                             jam/jam         13
# 258                                     penyahpepijatan          9
# 304                                                arah         11
# 317                                                edar         10
# 319                                    ketidakpercayaan          8
# 373                                             galakan         13
# 374                                          penghujung          3
# 375                                  tidak berkesudahan          7
# 381                                       pertingkatkan          7
# 484                                       menyeronokkan          3
# 490                                 pemecahan-permainan         13
# 507                            berasaskan-gerak isyarat         13
# 520                                   Grafiksxpart-type          6
# 531                 haahCity in Virginia, United States          4
# 558                                        penghormatan          5
# 591                                      dalam-aplikasi          6
# 592                                     dalam-permainan          7
# 599                               tidak dapat dielakkan         10
# 638                              tidak boleh dipulihkan         12
# 647                                  pengosongan-rahang         12
# 695                                   kritikStock label          8
# 731                                     load month name          4
# 732   loading... (28/2019) Ia juga mengaku tak bisa ...          7
# 757                marioCity in Virginia, United States          5
# 760                                secara besar-besaran          9
# 781                               tidak dapat dilupakan          9
# 839                                  pengguna-berbilang         10
# 844                mvpCity in California, United States          3
# 851                                          berikutnya          4
# 867                                           dimatikan          3
# 873                             semasa dalam perjalanan          9
# 876                                             peluang         13
# 879                                      mengoptimumkan          8
# 891                                    kuasa berlebihan          9
# 897                                       kemasan-masuk          7
# 928                               perjalanan perjalanan         10
# 946                                         merah jambu          4
# 947                                berwarna merah jambu         12
# 1004            progresiCity in Illinois, United States          8
# 1037                                    bertindak balas          5
# 1049                                 perundingan semula         12
# 1053                                    mencipta semula          8
# 1104                                   Memberi ganjaran          9
# 1137              saranaCity in Illinois, United States          6
# 1182                                         ditetapkan          3
# 1309                                              ghaib         12
# 1313                                       Sesungguhnya          6
# 1341                                        tarik tarik          5
# 1345                                   kerja berpasukan          8
# 1412                                    tiga kali ganda          6
# 1437                               tidak dapat dijangka         13
# 1438                             tidak boleh dipercayai         10
# 1469                                        waktu waktu          5
# 1488                                        lebih lebar          5
# 1500            youtubeCity in Minnesota, United States          7
# 1507                zonaCity in Illinois, United States          4
#
#       dictionary_len  transformer_len
# 56                15               13
# 177               13                7
# 258                9               15
# 304                4                4
# 317               11                4
# 319               10               16
# 373                7                7
# 374                5               10
# 375                7               18
# 381               12               13
# 484                3               13
# 490               13               19
# 507               13               24
# 520                6               17
# 531                4               35
# 558                5               12
# 591                6               14
# 592                7               15
# 599               21               21
# 638               22               22
# 647               12               18
# 695                8               17
# 731                5               15
# 732                9              127
# 757                5               36
# 760               20               20
# 781               21               21
# 839               10               18
# 844                3               36
# 851               10               10
# 867                3                9
# 873                9               23
# 876               13                7
# 879               14               14
# 891                8               16
# 897                7               13
# 928               10               21
# 946               11               11
# 947               12               20
# 1004               8               39
# 1037               5               15
# 1049              12               18
# 1053              11               15
# 1104              16               16
# 1137               6               37
# 1182              10               10
# 1309               5                5
# 1313               5               12
# 1341               5               11
# 1345              16               16
# 1412               6               15
# 1437              22               20
# 1438              10               22
# 1469               5               11
# 1488               5               11
# 1500               7               39
# 1507               4               35

# %% [markdown]
# ## 3.6 &nbsp;&nbsp; [Identify Untranslated English Words](#home) <a id='untranslated'></a>
#
# Our observations:
#
# 1. 390 words (mostly Malay words) were unaffected by Malaya dictionary or Malaya transformer.

# %%
# Extract untranslated English words i.e. select words that are identical across all 3 columns
cond = (df_en_word_new["words"] == df_en_word_new["dictionary"]) & (
    df_en_word_new["dictionary"] == df_en_word_new["transformer"]
)

df_untranslated = df_en_word_new.loc[cond, ["id", "words", "dictionary", "transformer"]]
df_untranslated
# Out:
#                id             words        dictionary       transformer
# 10      new_en_10  action-adventure  action-adventure  action-adventure
# 15      new_en_15      adaptabiliti      adaptabiliti      adaptabiliti
# 17      new_en_17          adaptasi          adaptasi          adaptasi
# 25      new_en_25            adegan            adegan            adegan
# 26      new_en_26              adil              adil              adil
# ...           ...               ...               ...               ...
# 1478  new_en_1478              wasd              wasd              wasd
# 1487  new_en_1487            whiffs            whiffs            whiffs
# 1489  new_en_1489               wii               wii               wii
# 1495  new_en_1495               wow               wow               wow
# 1497  new_en_1497              xbox              xbox              xbox
#
# [390 rows x 4 columns]

# %%
for row in df_untranslated.itertuples(index=False, name=None):
    print(row)
# Out:
# ('new_en_10', 'action-adventure', 'action-adventure', 'action-adventure')
# ('new_en_15', 'adaptabiliti', 'adaptabiliti', 'adaptabiliti')
# ('new_en_17', 'adaptasi', 'adaptasi', 'adaptasi')
# ('new_en_25', 'adegan', 'adegan', 'adegan')
# ('new_en_26', 'adil', 'adil', 'adil')
# ('new_en_30', 'adrenalin', 'adrenalin', 'adrenalin')
# ('new_en_40', 'agresif', 'agresif', 'agresif')
# ('new_en_43', 'aktif', 'aktif', 'aktif')
# ('new_en_44', 'alami', 'alami', 'alami')
# ('new_en_45', 'alat', 'alat', 'alat')
# ('new_en_48', 'aliran', 'aliran', 'aliran')
# ('new_en_52', 'alternatif', 'alternatif', 'alternatif')
# ('new_en_57', 'analisis', 'analisis', 'analisis')
# ('new_en_58', 'analog', 'analog', 'analog')
# ('new_en_60', 'animasi', 'animasi', 'animasi')
# ('new_en_63', 'antara', 'antara', 'antara')
# ('new_en_64', 'anti-cheat', 'anti-cheat', 'anti-cheat')
# ('new_en_66', 'antisipasi', 'antisipasi', 'antisipasi')
# ('new_en_69', 'apresiasi', 'apresiasi', 'apresiasi')
# ('new_en_75', 'asal', 'asal', 'asal')
# ('new_en_77', 'aspek', 'aspek', 'aspek')
# ('new_en_79', 'atmosfera', 'atmosfera', 'atmosfera')
# ('new_en_86', 'audiens', 'audiens', 'audiens')
# ('new_en_87', 'audio', 'audio', 'audio')
# ('new_en_88', 'audio-visual', 'audio-visual', 'audio-visual')
# ('new_en_89', 'audiovisual', 'audiovisual', 'audiovisual')
# ('new_en_90', 'auto', 'auto', 'auto')
# ('new_en_92', 'automatik', 'automatik', 'automatik')
# ('new_en_94', 'ave', 'ave', 'ave')
# ('new_en_97', 'baca', 'baca', 'baca')
# ('new_en_99', 'bahan', 'bahan', 'bahan')
# ('new_en_100', 'bahan-bahan', 'bahan-bahan', 'bahan-bahan')
# ('new_en_101', 'bahasa', 'bahasa', 'bahasa')
# ('new_en_103', 'bang', 'bang', 'bang')
# ('new_en_105', 'batas', 'batas', 'batas')
# ('new_en_108', 'bawa', 'bawa', 'bawa')
# ('new_en_109', 'beban', 'beban', 'beban')
# ('new_en_110', 'bendera', 'bendera', 'bendera')
# ('new_en_112', 'bergerombol', 'bergerombol', 'bergerombol')
# ('new_en_114', 'beta', 'beta', 'beta')
# ('new_en_117', 'biasa', 'biasa', 'biasa')
# ('new_en_119', 'bila', 'bila', 'bila')
# ('new_en_120', 'bila-bila', 'bila-bila', 'bila-bila')
# ('new_en_122', 'bob', 'bob', 'bob')
# ('new_en_135', 'buang', 'buang', 'buang')
# ('new_en_143', 'cabang', 'cabang', 'cabang')
# ('new_en_172', 'ciri', 'ciri', 'ciri')
# ('new_en_173', 'ciri-ciri', 'ciri-ciri', 'ciri-ciri')
# ('new_en_187', 'comebacks', 'comebacks', 'comebacks')
# ('new_en_252', 'data', 'data', 'data')
# ('new_en_272', 'demi', 'demi', 'demi')
# ('new_en_273', 'demo', 'demo', 'demo')
# ('new_en_284', 'detektif', 'detektif', 'detektif')
# ('new_en_285', 'detik', 'detik', 'detik')
# ('new_en_289', 'diakui', 'diakui', 'diakui')
# ('new_en_290', 'didorong', 'didorong', 'didorong')
# ('new_en_291', 'diedit', 'diedit', 'diedit')
# ('new_en_293', 'digital', 'digital', 'digital')
# ('new_en_294', 'diimplementasikan', 'diimplementasikan', 'diimplementasikan')
# ('new_en_295', 'dijaga', 'dijaga', 'dijaga')
# ('new_en_296', 'dikurangkan', 'dikurangkan', 'dikurangkan')
# ('new_en_297', 'dimainkan', 'dimainkan', 'dimainkan')
# ('new_en_298', 'dimensi', 'dimensi', 'dimensi')
# ('new_en_299', 'dinamika', 'dinamika', 'dinamika')
# ('new_en_300', 'dipercayai', 'dipercayai', 'dipercayai')
# ('new_en_301', 'dipersonalisasi', 'dipersonalisasi', 'dipersonalisasi')
# ('new_en_302', 'diplomasi', 'diplomasi', 'diplomasi')
# ('new_en_311', 'disesali', 'disesali', 'disesali')
# ('new_en_312', 'diskusi', 'diskusi', 'diskusi')
# ('new_en_316', 'distraksi', 'distraksi', 'distraksi')
# ('new_en_320', 'diuji', 'diuji', 'diuji')
# ('new_en_321', 'diurus', 'diurus', 'diurus')
# ('new_en_323', 'dominasi', 'dominasi', 'dominasi')
# ('new_en_326', 'dorongan', 'dorongan', 'dorongan')
# ('new_en_329', 'dramatik', 'dramatik', 'dramatik')
# ('new_en_333', 'durasi', 'durasi', 'durasi')
# ('new_en_343', 'efektif', 'efektif', 'efektif')
# ('new_en_344', 'efektivitas', 'efektivitas', 'efektivitas')
# ('new_en_345', 'efektiviti', 'efektiviti', 'efektiviti')
# ('new_en_353', 'ekonomi', 'ekonomi', 'ekonomi')
# ('new_en_354', 'eksklusif', 'eksklusif', 'eksklusif')
# ('new_en_355', 'eksklusivitas', 'eksklusivitas', 'eksklusivitas')
# ('new_en_356', 'eksklusiviti', 'eksklusiviti', 'eksklusiviti')
# ('new_en_357', 'eksperimen', 'eksperimen', 'eksperimen')
# ('new_en_358', 'eksperimental', 'eksperimental', 'eksperimental')
# ('new_en_359', 'eksplorasi', 'eksplorasi', 'eksplorasi')
# ('new_en_362', 'elemen-elemen', 'elemen-elemen', 'elemen-elemen')
# ('new_en_367', 'emosi', 'emosi', 'emosi')
# ('new_en_368', 'emosional', 'emosional', 'emosional')
# ('new_en_391', 'epik', 'epik', 'epik')
# ('new_en_398', 'etika', 'etika', 'etika')
# ('new_en_399', 'euforia', 'euforia', 'euforia')
# ('new_en_403', 'evolusi', 'evolusi', 'evolusi')
# ('new_en_404', 'evolusioner', 'evolusioner', 'evolusioner')
# ('new_en_430', 'faktor', 'faktor', 'faktor')
# ('new_en_441', 'fenomena', 'fenomena', 'fenomena')
# ('new_en_460', 'fleksibel', 'fleksibel', 'fleksibel')
# ('new_en_463', 'fokus', 'fokus', 'fokus')
# ('new_en_468', 'formasi', 'formasi', 'formasi')
# ('new_en_480', 'frustrasi', 'frustrasi', 'frustrasi')
# ('new_en_486', 'futuristik', 'futuristik', 'futuristik')
# ('new_en_487', 'gagal', 'gagal', 'gagal')
# ('new_en_492', 'gameplay-nya', 'gameplay-nya', 'gameplay-nya')
# ('new_en_494', 'ganjaran', 'ganjaran', 'ganjaran')
# ('new_en_497', 'gear', 'gear', 'gear')
# ('new_en_498', 'gelaran', 'gelaran', 'gelaran')
# ('new_en_499', 'generasi', 'generasi', 'generasi')
# ('new_en_503', 'genre', 'genre', 'genre')
# ('new_en_505', 'geocaching', 'geocaching', 'geocaching')
# ('new_en_506', 'gerakan', 'gerakan', 'gerakan')
# ('new_en_510', 'glitch', 'glitch', 'glitch')
# ('new_en_511', 'glitches', 'glitches', 'glitches')
# ('new_en_512', 'global', 'global', 'global')
# ('new_en_515', 'golongan', 'golongan', 'golongan')
# ('new_en_528', 'grup', 'grup', 'grup')
# ('new_en_532', 'hack', 'hack', 'hack')
# ('new_en_535', 'haha', 'haha', 'haha')
# ('new_en_540', 'haram', 'haram', 'haram')
# ('new_en_543', 'harmoni', 'harmoni', 'harmoni')
# ('new_en_565', 'hype', 'hype', 'hype')
# ('new_en_566', 'i/o', 'i/o', 'i/o')
# ('new_en_567', 'ibu', 'ibu', 'ibu')
# ('new_en_570', 'idea', 'idea', 'idea')
# ('new_en_572', 'identitas', 'identitas', 'identitas')
# ('new_en_589', 'impulsif', 'impulsif', 'impulsif')
# ('new_en_596', 'indah', 'indah', 'indah')
# ('new_en_597', 'industri', 'industri', 'industri')
# ('new_en_600', 'inflasi', 'inflasi', 'inflasi')
# ('new_en_606', 'inspirasi', 'inspirasi', 'inspirasi')
# ('new_en_613', 'integritas', 'integritas', 'integritas')
# ('new_en_614', 'integriti', 'integriti', 'integriti')
# ('new_en_615', 'intelektual', 'intelektual', 'intelektual')
# ('new_en_619', 'intensif', 'intensif', 'intensif')
# ('new_en_623', 'interaksi', 'interaksi', 'interaksi')
# ('new_en_624', 'interaktif', 'interaktif', 'interaktif')
# ('new_en_625', 'interaktiviti', 'interaktiviti', 'interaktiviti')
# ('new_en_627', 'internet', 'internet', 'internet')
# ('new_en_628', 'intervensi', 'intervensi', 'intervensi')
# ('new_en_631', 'intuitif', 'intuitif', 'intuitif')
# ('new_en_633', 'inventori', 'inventori', 'inventori')
# ('new_en_643', 'jahat', 'jahat', 'jahat')
# ('new_en_645', 'jantung', 'jantung', 'jantung')
# ('new_en_648', 'jaya', 'jaya', 'jaya')
# ('new_en_649', 'jenis', 'jenis', 'jenis')
# ('new_en_650', 'jimat', 'jimat', 'jimat')
# ('new_en_653', 'joker', 'joker', 'joker')
# ('new_en_658', 'k/d', 'k/d', 'k/d')
# ('new_en_659', 'kadar', 'kadar', 'kadar')
# ('new_en_660', 'kalangan', 'kalangan', 'kalangan')
# ('new_en_661', 'kalendar', 'kalendar', 'kalendar')
# ('new_en_662', 'kamera', 'kamera', 'kamera')
# ('new_en_663', 'kan', 'kan', 'kan')
# ('new_en_664', 'kategori', 'kategori', 'kategori')
# ('new_en_665', 'keaslian', 'keaslian', 'keaslian')
# ('new_en_667', 'kelestarian', 'kelestarian', 'kelestarian')
# ('new_en_677', 'kira', 'kira', 'kira')
# ('new_en_678', 'kisah', 'kisah', 'kisah')
# ('new_en_679', 'klik', 'klik', 'klik')
# ('new_en_680', 'kolektif', 'kolektif', 'kolektif')
# ('new_en_681', 'kompatibilitas', 'kompatibilitas', 'kompatibilitas')
# ('new_en_682', 'kompetisi', 'kompetisi', 'kompetisi')
# ('new_en_683', 'kompetitif', 'kompetitif', 'kompetitif')
# ('new_en_684', 'komponen', 'komponen', 'komponen')
# ('new_en_685', 'komputer', 'komputer', 'komputer')
# ('new_en_686', 'konflik', 'konflik', 'konflik')
# ('new_en_687', 'kontinuitas', 'kontinuitas', 'kontinuitas')
# ('new_en_688', 'kontrol', 'kontrol', 'kontrol')
# ('new_en_689', 'kontroversial', 'kontroversial', 'kontroversial')
# ('new_en_690', 'korban', 'korban', 'korban')
# ('new_en_691', 'kreativitas', 'kreativitas', 'kreativitas')
# ('new_en_692', 'kreativiti', 'kreativiti', 'kreativiti')
# ('new_en_693', 'kredit', 'kredit', 'kredit')
# ('new_en_694', 'kritikal', 'kritikal', 'kritikal')
# ('new_en_696', 'kustomisasi', 'kustomisasi', 'kustomisasi')
# ('new_en_697', 'laku', 'laku', 'laku')
# ('new_en_698', 'lambang', 'lambang', 'lambang')
# ('new_en_699', 'lambat', 'lambat', 'lambat')
# ('new_en_700', 'lancar', 'lancar', 'lancar')
# ('new_en_702', 'langganan', 'langganan', 'langganan')
# ('new_en_707', 'latar', 'latar', 'latar')
# ('new_en_709', 'latihan', 'latihan', 'latihan')
# ('new_en_712', 'lawan', 'lawan', 'lawan')
# ('new_en_723', 'liga', 'liga', 'liga')
# ('new_en_729', 'linear', 'linear', 'linear')
# ('new_en_742', 'lore', 'lore', 'lore')
# ('new_en_750', 'malu', 'malu', 'malu')
# ('new_en_754', 'mantera', 'mantera', 'mantera')
# ('new_en_756', 'manual', 'manual', 'manual')
# ('new_en_761', 'master', 'master', 'master')
# ('new_en_762', 'matang', 'matang', 'matang')
# ('new_en_767', 'mati', 'mati', 'mati')
# ('new_en_769', 'maya', 'maya', 'maya')
# ('new_en_775', 'media', 'media', 'media')
# ('new_en_778', 'mekanisme', 'mekanisme', 'mekanisme')
# ('new_en_779', 'memainkan', 'memainkan', 'memainkan')
# ('new_en_780', 'membanggakan', 'membanggakan', 'membanggakan')
# ('new_en_783', 'mempublish', 'mempublish', 'mempublish')
# ('new_en_784', 'mencengangkan', 'mencengangkan', 'mencengangkan')
# ('new_en_785', 'mendarat', 'mendarat', 'mendarat')
# ('new_en_786', 'mendeskripsikan', 'mendeskripsikan', 'mendeskripsikan')
# ('new_en_787', 'mendominasi', 'mendominasi', 'mendominasi')
# ('new_en_788', 'menendang', 'menendang', 'menendang')
# ('new_en_789', 'mental', 'mental', 'mental')
# ('new_en_790', 'menu', 'menu', 'menu')
# ('new_en_791', 'merampingkan', 'merampingkan', 'merampingkan')
# ('new_en_792', 'merangkak', 'merangkak', 'merangkak')
# ('new_en_795', 'mesti', 'mesti', 'mesti')
# ('new_en_799', 'mikro', 'mikro', 'mikro')
# ('new_en_800', 'miliki', 'miliki', 'miliki')
# ('new_en_803', 'misi', 'misi', 'misi')
# ('new_en_807', 'misteri', 'misteri', 'misteri')
# ('new_en_808', 'mistik', 'mistik', 'mistik')
# ('new_en_810', 'mobilitas', 'mobilitas', 'mobilitas')
# ('new_en_812', 'modding', 'modding', 'modding')
# ('new_en_813', 'model', 'model', 'model')
# ('new_en_816', 'modifikasi', 'modifikasi', 'modifikasi')
# ('new_en_819', 'momen', 'momen', 'momen')
# ('new_en_820', 'momen-momen', 'momen-momen', 'momen-momen')
# ('new_en_823', 'monetisasi', 'monetisasi', 'monetisasi')
# ('new_en_826', 'mood', 'mood', 'mood')
# ('new_en_827', 'moral', 'moral', 'moral')
# ('new_en_840', 'multimedia', 'multimedia', 'multimedia')
# ('new_en_842', 'multitasking', 'multitasking', 'multitasking')
# ('new_en_848', 'nasib', 'nasib', 'nasib')
# ('new_en_849', 'negatif', 'negatif', 'negatif')
# ('new_en_856', 'nostalgik', 'nostalgik', 'nostalgik')
# ('new_en_858', 'novel', 'novel', 'novel')
# ('new_en_861', 'nyata', 'nyata', 'nyata')
# ('new_en_864', 'objektif', 'objektif', 'objektif')
# ('new_en_869', 'okay', 'okay', 'okay')
# ('new_en_870', 'okey', 'okey', 'okey')
# ('new_en_872', 'on-disc', 'on-disc', 'on-disc')
# ('new_en_881', 'optimum', 'optimum', 'optimum')
# ('new_en_895', 'pacing', 'pacing', 'pacing')
# ('new_en_898', 'paling', 'paling', 'paling')
# ('new_en_899', 'pandang', 'pandang', 'pandang')
# ('new_en_901', 'papan', 'papan', 'papan')
# ('new_en_902', 'paranormal', 'paranormal', 'paranormal')
# ('new_en_903', 'parkour', 'parkour', 'parkour')
# ('new_en_911', 'penalti', 'penalti', 'penalti')
# ('new_en_912', 'penantang', 'penantang', 'penantang')
# ('new_en_913', 'penimbangan', 'penimbangan', 'penimbangan')
# ('new_en_914', 'pening', 'pening', 'pening')
# ('new_en_915', 'peperangan', 'peperangan', 'peperangan')
# ('new_en_916', 'per', 'per', 'per')
# ('new_en_917', 'percakapan', 'percakapan', 'percakapan')
# ('new_en_918', 'percaya', 'percaya', 'percaya')
# ('new_en_920', 'perdebatan', 'perdebatan', 'perdebatan')
# ('new_en_923', 'pergerakan', 'pergerakan', 'pergerakan')
# ('new_en_924', 'perhatian', 'perhatian', 'perhatian')
# ('new_en_925', 'peringatan', 'peringatan', 'peringatan')
# ('new_en_927', 'perisai', 'perisai', 'perisai')
# ('new_en_929', 'persenjataan', 'persenjataan', 'persenjataan')
# ('new_en_930', 'persiapan', 'persiapan', 'persiapan')
# ('new_en_932', 'personalisasi', 'personalisasi', 'personalisasi')
# ('new_en_936', 'perspektif', 'perspektif', 'perspektif')
# ('new_en_938', 'pertempuran', 'pertempuran', 'pertempuran')
# ('new_en_939', 'pertimbangan', 'pertimbangan', 'pertimbangan')
# ('new_en_940', 'peta', 'peta', 'peta')
# ('new_en_941', 'petualangan', 'petualangan', 'petualangan')
# ('new_en_945', 'pilih', 'pilih', 'pilih')
# ('new_en_948', 'pintar', 'pintar', 'pintar')
# ('new_en_949', 'pintas', 'pintas', 'pintas')
# ('new_en_954', 'platformer', 'platformer', 'platformer')
# ('new_en_955', 'platformers', 'platformers', 'platformers')
# ('new_en_967', 'plot', 'plot', 'plot')
# ('new_en_971', 'pokemon', 'pokemon', 'pokemon')
# ('new_en_972', 'politik', 'politik', 'politik')
# ('new_en_973', 'pop', 'pop', 'pop')
# ('new_en_975', 'popular', 'popular', 'popular')
# ('new_en_977', 'positif', 'positif', 'positif')
# ('new_en_991', 'presisi', 'presisi', 'presisi')
# ('new_en_993', 'prestasi', 'prestasi', 'prestasi')
# ('new_en_996', 'privasi', 'privasi', 'privasi')
# ('new_en_1005', 'progresinya', 'progresinya', 'progresinya')
# ('new_en_1009', 'promosi', 'promosi', 'promosi')
# ('new_en_1011', 'proses', 'proses', 'proses')
# ('new_en_1012', 'protes', 'protes', 'protes')
# ('new_en_1013', 'provokatif', 'provokatif', 'provokatif')
# ('new_en_1045', 'realisme', 'realisme', 'realisme')
# ('new_en_1046', 'realistik', 'realistik', 'realistik')
# ('new_en_1047', 'realistis', 'realistis', 'realistis')
# ('new_en_1063', 'rehat', 'rehat', 'rehat')
# ('new_en_1077', 'representasi', 'representasi', 'representasi')
# ('new_en_1078', 'reputasi', 'reputasi', 'reputasi')
# ('new_en_1086', 'resort', 'resort', 'resort')
# ('new_en_1092', 'responsif', 'responsif', 'responsif')
# ('new_en_1095', 'responsivitas', 'responsivitas', 'responsivitas')
# ('new_en_1096', 'responsiviti', 'responsiviti', 'responsiviti')
# ('new_en_1099', 'retro', 'retro', 'retro')
# ('new_en_1109', 'risiko', 'risiko', 'risiko')
# ('new_en_1116', 'rom', 'rom', 'rom')
# ('new_en_1117', 'ronda', 'ronda', 'ronda')
# ('new_en_1119', 'royale', 'royale', 'royale')
# ('new_en_1121', 'rumit', 'rumit', 'rumit')
# ('new_en_1125', 'saingan', 'saingan', 'saingan')
# ('new_en_1126', 'sains', 'sains', 'sains')
# ('new_en_1127', 'salinan', 'salinan', 'salinan')
# ('new_en_1128', 'saling', 'saling', 'saling')
# ('new_en_1129', 'sama', 'sama', 'sama')
# ('new_en_1130', 'sama-sama', 'sama-sama', 'sama-sama')
# ('new_en_1131', 'samping', 'samping', 'samping')
# ('new_en_1132', 'sampingan', 'sampingan', 'sampingan')
# ('new_en_1133', 'sana', 'sana', 'sana')
# ('new_en_1135', 'santai', 'santai', 'santai')
# ('new_en_1136', 'santun', 'santun', 'santun')
# ('new_en_1138', 'sasaran', 'sasaran', 'sasaran')
# ('new_en_1147', 'sci-fi', 'sci-fi', 'sci-fi')
# ('new_en_1149', 'scoped', 'scoped', 'scoped')
# ('new_en_1162', 'segmen', 'segmen', 'segmen')
# ('new_en_1164', 'selera', 'selera', 'selera')
# ('new_en_1167', 'sengit', 'sengit', 'sengit')
# ('new_en_1168', 'seni', 'seni', 'seni')
# ('new_en_1169', 'senjata', 'senjata', 'senjata')
# ('new_en_1171', 'sensitiviti', 'sensitiviti', 'sensitiviti')
# ('new_en_1175', 'serba', 'serba', 'serba')
# ('new_en_1176', 'sering', 'sering', 'sering')
# ('new_en_1180', 'sesi', 'sesi', 'sesi')
# ('new_en_1194', 'siber', 'siber', 'siber')
# ('new_en_1200', 'sihir', 'sihir', 'sihir')
# ('new_en_1201', 'simbol', 'simbol', 'simbol')
# ('new_en_1205', 'simulator', 'simulator', 'simulator')
# ('new_en_1209', 'sistem', 'sistem', 'sistem')
# ('new_en_1217', 'skor', 'skor', 'skor')
# ('new_en_1219', 'slot', 'slot', 'slot')
# ('new_en_1234', 'sopan', 'sopan', 'sopan')
# ('new_en_1235', 'sorotan', 'sorotan', 'sorotan')
# ('new_en_1236', 'sosial', 'sosial', 'sosial')
# ('new_en_1252', 'spon', 'spon', 'spon')
# ('new_en_1253', 'spontan', 'spontan', 'spontan')
# ('new_en_1255', 'spontaniti', 'spontaniti', 'spontaniti')
# ('new_en_1267', 'stat', 'stat', 'stat')
# ('new_en_1269', 'statistik', 'statistik', 'statistik')
# ('new_en_1286', 'strategi', 'strategi', 'strategi')
# ('new_en_1289', 'strategik', 'strategik', 'strategik')
# ('new_en_1297', 'struktur', 'struktur', 'struktur')
# ('new_en_1303', 'suasana', 'suasana', 'suasana')
# ('new_en_1304', 'sub-genre', 'sub-genre', 'sub-genre')
# ('new_en_1305', 'subjek', 'subjek', 'subjek')
# ('new_en_1307', 'sudut', 'sudut', 'sudut')
# ('new_en_1320', 'susah', 'susah', 'susah')
# ('new_en_1330', 'tak', 'tak', 'tak')
# ('new_en_1333', 'tamat', 'tamat', 'tamat')
# ('new_en_1334', 'tambah', 'tambah', 'tambah')
# ('new_en_1335', 'tanda', 'tanda', 'tanda')
# ('new_en_1336', 'tangan', 'tangan', 'tangan')
# ('new_en_1337', 'tangga', 'tangga', 'tangga')
# ('new_en_1338', 'tanya', 'tanya', 'tanya')
# ('new_en_1339', 'taraf', 'taraf', 'taraf')
# ('new_en_1340', 'tarian', 'tarian', 'tarian')
# ('new_en_1342', 'taruhan', 'taruhan', 'taruhan')
# ('new_en_1351', 'tegang', 'tegang', 'tegang')
# ('new_en_1352', 'tekanan', 'tekanan', 'tekanan')
# ('new_en_1354', 'teknikal', 'teknikal', 'teknikal')
# ('new_en_1355', 'teknologi', 'teknologi', 'teknologi')
# ('new_en_1357', 'teleport', 'teleport', 'teleport')
# ('new_en_1358', 'tema', 'tema', 'tema')
# ('new_en_1360', 'tendangan', 'tendangan', 'tendangan')
# ('new_en_1365', 'tertinggal', 'tertinggal', 'tertinggal')
# ('new_en_1383', 'time-to-kill', 'time-to-kill', 'time-to-kill')
# ('new_en_1388', 'tolok', 'tolok', 'tolok')
# ('new_en_1397', 'tps', 'tps', 'tps')
# ('new_en_1398', 'trade-off', 'trade-off', 'trade-off')
# ('new_en_1400', 'tradisional', 'tradisional', 'tradisional')
# ('new_en_1406', 'traverse', 'traverse', 'traverse')
# ('new_en_1408', 'tren', 'tren', 'tren')
# ('new_en_1409', 'trend', 'trend', 'trend')
# ('new_en_1410', 'trending', 'trending', 'trending')
# ('new_en_1415', 'tumbang', 'tumbang', 'tumbang')
# ('new_en_1416', 'tump', 'tump', 'tump')
# ('new_en_1417', 'tunggal', 'tunggal', 'tunggal')
# ('new_en_1420', 'turun', 'turun', 'turun')
# ('new_en_1421', 'tutorial', 'tutorial', 'tutorial')
# ('new_en_1422', 'tweak', 'tweak', 'tweak')
# ('new_en_1426', 'udara', 'udara', 'udara')
# ('new_en_1427', 'ukuran', 'ukuran', 'ukuran')
# ('new_en_1428', 'umur', 'umur', 'umur')
# ('new_en_1431', 'unik', 'unik', 'unik')
# ('new_en_1434', 'unit', 'unit', 'unit')
# ('new_en_1443', 'urutan', 'urutan', 'urutan')
# ('new_en_1454', 'variasi', 'variasi', 'variasi')
# ('new_en_1460', 'video', 'video', 'video')
# ('new_en_1465', 'visual', 'visual', 'visual')
# ('new_en_1473', 'wang', 'wang', 'wang')
# ('new_en_1476', 'warna', 'warna', 'warna')
# ('new_en_1478', 'wasd', 'wasd', 'wasd')
# ('new_en_1487', 'whiffs', 'whiffs', 'whiffs')
# ('new_en_1489', 'wii', 'wii', 'wii')
# ('new_en_1495', 'wow', 'wow', 'wow')
# ('new_en_1497', 'xbox', 'xbox', 'xbox')

# %% [markdown]
# ## 4. &nbsp;&nbsp; [Generate gpt_mapping](#home) <a id='gen_gpt_mapping'></a>
#
# Objective is to generate a mapping (i.e. `gpt_mapping`) that map unique English words to words whose characters are modified to replicate desired pronunciation. Unique English words refer to English words found in GPT corpus that are not found in gaming terms and existing `mapping` for gaming terms in `gaming.yaml`.
#
# Detailed steps are as follows:
#
# <style>
#     table {
#         width: 70%;
#         table-layout:fixed;
#     }
#     th:nth-child(1),
#     td:nth-child(1) {
#         width: 3%;
#     }
#     th:nth-child(2),
#     td:nth-child(2) {
#         width: 17%;
#     }
#     th:nth-child(3),
#     td:nth-child(3) {
#         width: 80%;
#     }
# </style>
#
# | S/N | Step | Description |
# | -- | -- | -- |
# | 1. | [Generate Audio for Unique English Words](#gen_audio_unique) | &bull; Generate audio for all 1515 English words. <br>&bull; Rationale is to be able to assess the quality of English words that are inferred by Malay VITS model easily. |
# | 2. | [Map to Malay Words](#map_to_malay) | &bull; Determine appropriate translated malay word. <br>&bull; Update `gpt_mapping` to map English words to selected translated Malay word. |
# | 3. | [Map to Modified](#map_to_modified) | &bull; Performed language detection on `malay_word` column via polyglot. <br>&bull; Identify English words detected by polyglot having confidence of more than 90%. <br>&bull; Update `gpt_mapping` to map English words to their modified equivalent. |
#
# Our considerations:
#
# 1. We assume Malaya dictionary is a better translation source than Malaya transformer. Therefore, we will translate 1515 unique English words first by Malaya dictionary then followed by Malaya transformer if Malaya dictionary is not able to translate the English word. This is to ensure that the GPT corpus is still predominantly Malay words.
# 2. Gaming terms will not be translated since Malay gaming community use gaming terms in their native English forms.
# 3. Modified words refer to words that can't be translated either by Malay dictionary or Malay transformer will have to be modified character-wise and combine multiple English words accordingly in order to generate appropriate pronounciation e.g. 'insertion' -> 'innsirshion'.
# 4. Sentence may not be gramatically correct after translation. However, the focus is to obtain the correct sound. User can correct the grammar on their own and use the same mapping to generate the audio files.
# 5. We noticed that malay word translation differ between Malaya dictionary, Malaya transformer and google translate (on web page). Hence, we are unsure whether the correct Malay word are used for translation since we are not native Malay speakers.
# 6. Malay words, which were initially generated by ChatGPT and are translated by Malaya dictionary or transformer, are retained.

# %% [markdown]
# ## 4.1 &nbsp;&nbsp; [Generate Audio for Unique English Words](#home) <a id='gen_audio_unique'></a>
#
# We went through all 1515 unique English words and identified 381 words that required either translation or character modification. Kindly refer to `gaming.yaml` under `notebooks/src_gaming` folder for the full list.

# %%
gen_audio(df_en_word_new, "words", cfg.paths.gpt_en_new_dir)
# Out:
#   0%|          | 0/1511 [00:00<?, ?it/s]
# 100%|██████████| 1511/1511 [22:01<00:00,  1.14it/s]

# %% [markdown]
# ## 4.2 &nbsp;&nbsp; [Map to Malay words](#home) <a id='map_to_malay'></a>
#
# Determine appropriate translated Malay word by selecting translated word from Malaya dictionary first. If not available, then select from Malaya transformer. Update `gpt_mapping` to map English word to appropriate translated Malay word.

# %% [markdown]
# ##### Determine appropriate translated Malay words

# %%
# Select from `dictionary`, followed by `transformer`
df_en_word_new["malay_word"] = df_en_word_new.parallel_apply(
    lambda row: select_malay_word(row[1], row[2], row[3]), axis=1
)
df_en_word_new.to_csv(cfg.paths.gpt_en_new_path, index=False)
df_en_word_new
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=189), Label(value='0 / 189'))), HB…
#                id          words    dictionary  \
# 0        new_en_0      abilities     abilities
# 1        new_en_1        ability     kebolehan
# 2        new_en_2         abrupt        abrupt
# 3        new_en_3         access         akses
# 4        new_en_4  accessibility  aksesibiliti
# ...           ...            ...           ...
# 1505  new_en_1505         zipper           zip
# 1506  new_en_1506         zombie        zombie
# 1507  new_en_1507           zona          zona
# 1508  new_en_1508          zones         zones
# 1509  new_en_1509           zoom          zoom
#
#                               transformer  words_len  dictionary_len  \
# 0                               kebolehan          9               9
# 1                               keupayaan          7               9
# 2                               Tiba-tiba          6               6
# 3                                 capaian          6               5
# 4                          kebolehcapaian         13              12
# ...                                   ...        ...             ...
# 1505                           ritsleting          6               3
# 1506                                zombi          6               6
# 1507  zonaCity in Illinois, United States          4               4
# 1508                                  zon          5               5
# 1509                                  zum          4               4
#
#       transformer_len    malay_word
# 0                   9     kebolehan
# 1                   9     kebolehan
# 2                   9     Tiba-tiba
# 3                   7         akses
# 4                  14  aksesibiliti
# ...               ...           ...
# 1505               10           zip
# 1506                5         zombi
# 1507               35          zona
# 1508                3           zon
# 1509                3           zum
#
# [1510 rows x 8 columns]

# %% [markdown]
# ##### Update `gpt_mapping` to map English word to selected translated Malay word
#
# We made adjustment to below selected Malay words (in yaml format) by removing the following from `gpt_mapping`:
#
# 1. Malay words that were generated by ChatGPT (i.e. ekspres, kepintarank, kritikan, periode, perjalanan, pulih, respons) from mapping.
# 2. Malay Words that are deemed to be more appropriate in English form are retained (i.e. e sports, kill death assist, sniper, top, top-down, x axis, y axis, z axis, zipper).
#
# Total of 747 key-value pairs created for `gpt_mapping`

# %%
# Display inital English to Malay words mapping in yaml format
display_yaml(cfg, df_en_word_new)
# Out:
#   abilities: kebolehan
#   abrupt: tiba tiba
#   accessibility: aksesibiliti
#   accessible: boleh diakses
#   accomplished: dicapai
#   accomplishment: pencapaian
#   accountable: bertanggungjawab
#   actions: tindakan
#   activate: aktifkan
#   active: aktif
#   adaptability: kebolehsuaian
#   adaptation: adaptasi
#   addicted: ketagihan
#   addicting: ketagihan
#   addictive: ketagihan
#   additional: tambahan
#   address: alamat
#   adjust: melaraskan
#   adjustment: pelarasan
#   admit: mengaku
#   advanced: maju
#   advancement: kemajuan
#   advantage: kelebihannya
#   aesthetic: estetik
#   affected: terjejas
#   after: selepas
#   aggressive: agresif
#   agreed: bersetuju
#   alert: amaran
#   alienate: mengasingkan diri
#   allocation: peruntukan
#   alternative: alternatif
#   amazement: kagum
#   ambush: serangan hendap
#   annoying: menjengkelkan
#   anti fair: anti adil
#   appreciated: dihargai
#   approaches: pendekatan
#   area of effect: kawasan kesan
#   areas: kawasan
#   artbook: buku seni
#   aspect: aspek
#   atmosphere: atmosfera
#   attacks: serangan
#   attention: perhatian
#   audience: penonton
#   auto targeting: penyasaran sendiri
#   available: boleh didapati
#   avoid: elakkan
#   awareness: kesedaran
#   balanced: seimbang
#   banter: kelakar
#   battles: pertempuran
#   benefits: manfaat
#   better: lebih baik
#   between: antara
#   big: besar
#   blame: menyalahkan
#   bosses: bos
#   bounce: lantunan
#   brainstorm: sumbang saran
#   branches: cabang
#   breaches: pelanggaran
#   breaks: pecah
#   bring: bawa
#   bugs: pepijat
#   build: membina
#   builds: binaan
#   buku: buku
#   bulanan: bulan
#   calm: tenang
#   carefully: teliti
#   cast: pelakon
#   casualties: korban
#   catchy: menarik
#   cautious: berhati hati
#   ceiling: siling
#   celebrate: raikan
#   center: pusat
#   certain: tertentu
#   chair: kerusi
#   challenges: cabaran
#   challenging: mencabar
#   chance: peluang
#   chances: peluang
#   characters: aksara
#   charm: pesona
#   chat: sembang
#   chill: sejuk
#   choices: pilihan
#   clear: jelas
#   clever: pandai
#   clock/clocked: jam/jam
#   code: kod
#   codes: kod
#   collect: kumpulkan
#   collection: koleksi
#   collectors: pengumpul
#   combat: pertempuran
#   come: datang
#   comedic: komedik
#   comfort: keselesaan
#   communication: komunikasi
#   communities: komuniti
#   community: komuniti
#   companion: sahabat
#   compared: dibandingkan
#   compatible: serasi
#   compete: bersaing
#   competition: persaingan
#   competitiveness: daya saing
#   composition: komposisi
#   compromised: dikompromikan
#   concerns: kebimbangan
#   confident: yakin
#   confuse: mengelirukan
#   connect: sambungkan
#   connected: disambungkan
#   connection: sambungan
#   consequences: akibatnya
#   consistent: konsisten
#   context: konteks
#   continuous: berterusan
#   controlled: terkawal
#   controllers: pengawal
#   convenience: kemudahan
#   coordinate: koordinat
#   coordination: penyelarasan
#   corner: bucu
#   cosmetics: kosmetik
#   counter terrorist: pengganas balas
#   crash: kemalangan
#   create: buat
#   creation: ciptaan
#   creative: kreatif
#   creativity: kreativiti
#   criticism: kritikan
#   crowded: sesak
#   crucial: penting
#   culture: budaya
#   currency: mata wang
#   current: semasa
#   custom: adat
#   customization: penyesuaian
#   dark: gelap
#   days: hari
#   debate: perbahasan
#   debugging: penyahpepijatan
#   decide: membuat keputusan
#   decision: keputusan
#   decision making: membuat keputusan
#   decisions: keputusan
#   dedicated: khusus
#   dedication: dedikasi
#   deep: mendalam
#   deeper: lebih dalam
#   defeat: kekalahan
#   defense: pertahanan
#   define: mentakrifkan
#   degrees: darjah
#   demand: permintaan
#   depth: kedalaman
#   describe: terangkan
#   desirable: wajar
#   desk: meja
#   destroy: memusnahkan
#   destroyer: pemusnah
#   detail: terperinci
#   details: perincian
#   developers: pembangun
#   device: peranti
#   different: berbeza
#   disapproval: penolakan
#   discover: temui
#   discovery: penemuan
#   discuss: berbincang
#   discussion: perbincangan
#   discussions: perbincangan
#   distant: jauh
#   distinct: berbeza
#   distribute: mengedarkan
#   distribution: pengedaran
#   distrust: kesangsian
#   dominate: menguasai
#   doom: azab
#   dream: mimpi
#   drive: memandu
#   dynamics: dinamik
#   e sports: e sukan
#   easy: mudah
#   economy: ekonomi
#   edge: hujung
#   edition: edisi
#   effective: berkesan
#   efficient: cekap
#   effort: usaha
#   eggs: telur
#   ekspresi: ungkapan
#   elemen: unsur
#   element: unsur
#   elements: unsur
#   eliminate: menghapuskan
#   emotional: emosi
#   encounters: pertemuan
#   encourage: galakkan
#   encouragement: galakan
#   engage: terlibat
#   engaged: terlibat
#   engagement: pertunangan
#   engaging: menarik
#   engrossing: mengasyikkan
#   enhance: meningkatkan
#   enhancements: penambahan
#   enjoy: nikmati
#   enjoyability: keseronokan
#   enjoyable: menyeronokkan
#   ensure: pastikan
#   enthusiasm: semangat
#   epic: epik
#   equipment: peralatan
#   especially: terutamanya
#   ethical: etika
#   ethics: etika
#   events: peristiwa
#   everyone: semua orang
#   evolve: berkembang
#   exceptional: luar biasa
#   exceptionally: luar biasa
#   excited: teruja
#   excitement: keseronokan
#   exciting: menarik
#   execution: pelaksanaan
#   expansions: pengembangan
#   experienced: berpengalaman
#   experiences: pengalaman
#   experiment: eksperimen
#   expert: pakar
#   exploration: penerokaan
#   explore: meneroka
#   expo: ekspo
#   expression: ungkapan
#   extraordinary: luar biasa
#   factor: faktor
#   fail: gagal
#   fair: adil
#   familiar: biasa
#   fans: peminat
#   favorit: kegemaran
#   feature: ciri
#   features: fitur
#   feeling: perasaan
#   fight: melawan
#   fighting: berjuang
#   fights: pergaduhan
#   file: fail
#   financial: kewangan
#   fire: api
#   firepower: kuasa tembakan
#   fixes: pembaikan
#   flavor: rasa
#   flexibility: fleksibiliti
#   flow: aliran
#   follow: ikuti
#   followed: diikuti
#   forward: ke hadapan
#   franchise: francais
#   franchises: francais
#   frequent: kerap
#   frequently: kerap
#   friendly: mesra
#   friends: kawan
#   friendships: persahabatan
#   frustrating: mengecewakan
#   frustration: kekecewaan
#   functionality: fungsi
#   gain: keuntungan
#   game breaking: pemecahan permainan
#   game changer: penukar permainan
#   gap: jurang
#   gathering: pengumpulan
#   generator: penjana
#   genting: lembut
#   gesture based: berasaskan gerak isyarat
#   girlfriend: teman wanita
#   goal: matlamat
#   grace: rahmat
#   gradual: bertahap
#   grafik intensive: intensif grafik
#   graphical: grafik
#   greatest: terhebat
#   groups: kumpulan
#   guild: gilda
#   had: telah
#   handle: pemegang
#   handy: berguna
#   hang: gantung
#   happy: gembira
#   hardware: perkakasan
#   headset: alat dengar
#   heavy: berat
#   help: membantu
#   hero: wira
#   highlight: sorot
#   highlights: sorotan
#   history: sejarah
#   holder: pemegang
#   honor: penghormatan
#   horizontal: mendatar
#   horror: seram
#   horse: kuda
#   humiliation: penghinaan
#   icon: ikon
#   iconic: ikonik
#   identify: mengenal pasti
#   illusion: ilusi
#   imaginary: khayalan
#   imbalanced: tidak seimbang
#   immediate: segera
#   immerse: tenggelam
#   immersed: terbenam
#   immersion: perendaman
#   impact: impak
#   impactful: memberi impak
#   implement: laksana
#   important: penting
#   impression: kesan
#   impressive: mengagumkan
#   improve: memperbaiki
#   improvement: penambahbaikan
#   improvements: penambahbaikan
#   impulsivity: impulsif
#   in game: dalam permainan
#   incentive: insentif
#   increase: meningkat
#   incredible: luar biasa
#   industry: industri
#   inevitable: tidak dapat dielakkan
#   informal: tidak rasmi
#   informasi: maklumat
#   insertion: penyisipan
#   inside: dalam
#   install: memasang
#   insurance: insurans
#   integral: kamiran
#   integration: integrasi
#   intens: niat
#   intense: tegang
#   intensity: keamatan
#   interactions: interaksi
#   interactive: interaktif
#   interesting: menarik
#   into: ke dalam
#   introduction: pengenalan
#   intuition: intuisi
#   investment: pelaburan
#   involve: melibatkan diri
#   involved: terbabit
#   irreversible: tidak dapat dipulihkan
#   issues: isu
#   its: itu
#   items: item
#   jaga: penjaga
#   japanese: jepun
#   jaw dropping: pengosongan rahang
#   job: kerja
#   join: menyertai
#   jokes: jenaka
#   journey: perjalanan
#   jumps: lompat
#   keep: teruskan
#   kepintaran: buang
#   kill death assist: bunuh bunuh bantu
#   kills: bunuh
#   kritikan: kritikstock label
#   large: besar
#   large scale: skala besar
#   lasting: berpanjangan
#   latest: terkini
#   layout: susun atur
#   lazy: malas
#   learn: belajar
#   leave: cuti
#   left: ditinggalkan
#   legacy: warisan
#   lets: mari
#   leveling: meratakan
#   levels: aras
#   lighting: pencahayaan
#   limit: had
#   limited: terhad
#   limits: had
#   loading: memuatkan
#   location: lokasi
#   locations: lokasi
#   losing: kehilangan
#   lower level: aras bawah
#   main main: main utama
#   maintain: mengekalkan
#   major: utama
#   mantra: mantera
#   marketing: pemasaran
#   match fixing: penetapan padanan
#   matches: padanan
#   maybe: mungkin
#   meaningful: bermakna
#   mechanism: mekanisme
#   medium: sederhana
#   meet: jumpa
#   memorable: tidak dapat dilupakan
#   memory: ingatan
#   merchandise: barang dagangan
#   mice: tikus
#   microtransactions: transaksi mikro
#   middle: tengah
#   mind: fikiran
#   minute: minit
#   mistakes: kesilapan
#   mobile: mudah alih
#   mobility: mobiliti
#   modern: moden
#   modes: mod
#   modify: ubah suai
#   mods: mod
#   moment: momen
#   moments: momen
#   monitor: memantau
#   morally: secara moral
#   motivation: motivasi
#   motto: moto
#   movement: pergerakan
#   moves: bergerak
#   movie: filem
#   multi user: pengguna berbilang
#   mysterious: misteri
#   narrative: naratif
#   narratives: naratif
#   next: seterusnya
#   nights: malam
#   noise: bunyi bising
#   nostalgic: nostalgia
#   now: sekarang
#   number: nombor
#   objectives: objektif
#   obstacles: halangan
#   obvious: jelas
#   official: rasmi
#   on the go: semasa dalam perjalanan
#   opportunities: peluang
#   opportunity: peluang
#   optimal: optimum
#   optimize: mengoptimumkan
#   optimized: dioptimumkan
#   option: pilihan
#   original: asal
#   outcome: hasilnya
#   outcomes: hasil
#   outdoor: luar
#   overall: keseluruhannya
#   overcome: diatasi
#   overwhelming: sangat menggembirakan
#   panic: panik
#   partnerships: perkongsian
#   parts: bahagian
#   passes: hantaran
#   path: jalan
#   peek: mengintip
#   perform: melaksanakan
#   performance: prestasi
#   periode: tempoh
#   perjalanan: perjalanan perjalanan
#   personalization: peribadi
#   personalize: personaliti
#   perspective: perspektif
#   pertandingan: permainan
#   physically: secara fizikal
#   pink colored: berwarna merah jambu
#   pitch: padang
#   place: tempat
#   plan: pelan
#   planning: perancangan
#   platforming: platformulasi
#   platforms: platform
#   played: dimainkan
#   player driven: pemain didorong
#   players: pemain
#   plays: dimainkan
#   playstyle: gaya permainan
#   playstyles: gaya permainan
#   porting: mengalih
#   positioning: penentududukan
#   possibilities: kemungkinan
#   powerful: kuat
#   powerhouse: rumah kuasa
#   practice: amalan
#   precise: tepat
#   precision: ketepatan
#   predictable: boleh diramal
#   prefer: lebih suka
#   preference: pilihan
#   preferensi: keutamaan
#   presses: tekan
#   prevent: mengelakkan
#   problem solving: penyelesaian masalah
#   proceed: meneruskan
#   process: proses
#   processes: proses
#   processing: memproses
#   product: produk
#   progressions: kemajuan
#   propel: sifat
#   pulih: baik
#   pumping: mengepam
#   punishment: hukuman
#   purchases: pembelian
#   purpose: tujuan
#   push: tolak
#   puzzles: teka teki
#   quests: pencarian
#   rapid: pantas
#   rare: jarang berlaku
#   reaction: reaksi
#   reactions: tindak balas
#   read: baca
#   ready: sedia
#   real world: dunia nyata
#   realism: realisme
#   reallocation: perundingan semula
#   realm: alam
#   reason: sebab
#   recommend: mengesyorkan
#   recreate: buat semula
#   reduce: mengurangkan
#   refer: rujuk
#   refine: menyempurnakan
#   reflection: pantulan
#   reflections: pantulan
#   reflexes: refleks
#   refreshing: menyegarkan
#   regretted: dikesali
#   relax: santai
#   relaxing: santai
#   released: dilepaskan
#   relief: pelepasan
#   reminder: peringatan
#   rendering: penerapan
#   repetitif: ulangan
#   replayable: boleh ganti
#   report: laporan
#   reports: laporan
#   reputation: reputasi
#   require: memerlukan
#   required: diperlukan
#   requires: memerlukan
#   resilience: daya tahan
#   resolve: lerai
#   resource: sumber
#   respected: dihormati
#   respons: sambutan
#   response: tindak balas
#   responsibility: tanggungjawab
#   responsive: responsif
#   responsiveness: responsif
#   restart: mula semula
#   result: hasilnya
#   reviews: ulasan
#   reward: ganjaran
#   rewarding: memberi ganjaran
#   rewards: ganjaran
#   rich: kaya
#   roger: penyangak
#   roles: peranan
#   round based: berasaskan bulat
#   satisfying: memuaskan
#   saving: penjimatan
#   scandal: skandal
#   scenes: adegan
#   schedules: jadual
#   scores: skor
#   scripted: berskrip
#   secrets: rahsia
#   sections: seksyen
#   secure: selamat
#   security: keselamatan
#   segments: segmen
#   self reflection: pantulan diri
#   selling: menjual
#   sensitivity: kepekaan
#   sequences: jujukan
#   serious: serius
#   server: pelayan
#   sessions: sesi
#   setting: menetapkan
#   settings: tetapan
#   shine: bersinar
#   shooting: menembak
#   short: pendek
#   shortcut: pintasan
#   showcase: pameran
#   signature: tandatangan
#   significant: penting
#   simple: mudah
#   simplicity: kesederhanaan
#   simultaneous: serentak
#   situational: situasional
#   situations: situasi
#   skilled: mahir
#   skills: kemahiran
#   skip: langkau
#   skrip: skrip
#   slow: lambat
#   slowly: perlahan lahan
#   small: kecil
#   smart: pintar
#   smooth: licin
#   sneak: menyelinap
#   sniper: penembak curi
#   social: sosial
#   socialize: bersosial
#   software: perisian
#   solve: selesaikan
#   some: sesetengah
#   sometimes: kadang kadang
#   soundtrack: runut bunyi
#   soundtracks: runut bunyi
#   space: ruang
#   speaking: bercakap
#   specifications: spesifikasi
#   speechless: bersuara
#   spender: pembeli
#   split second: saat terpisah
#   spontaneous: spontan
#   sportsmanship: kesukanan
#   spot: tempat
#   square: persegi
#   stability: kestabilan
#   standard: piawai
#   staple: ruji
#   start: mulakan
#   stats: statistik
#   stay: tinggal
#   steady: mantap
#   stealth: senyap
#   stimulate: merangsang
#   stock: stok
#   stop: berhenti
#   storage: penyimpanan
#   stories: cerita
#   story driven: didorong cerita
#   storyline: jalan cerita
#   strategic: strategik
#   strategies: strategi
#   strategis: strategi
#   strategize: strategi
#   streamer: tali pinggang
#   strength: kekuatan
#   stress: tekanan
#   structure: struktur
#   stuck: tersangkut
#   study: belajar
#   stylish: bergaya
#   success: kejayaan
#   suggestions: cadangan
#   supernatural: ghaib
#   support: sokongan
#   supportive: menyokong
#   sure: pasti
#   surely: pasti
#   surprise: kejutan
#   surprises: kejutan
#   surrender: menyerahkan diri
#   surroundings: persekitaran
#   survive: bertahan hidup
#   switch: suis
#   switching: bertukar
#   symbol: simbol
#   synchronization: penyegerakan
#   systems: sistem
#   tactical: taktikal
#   tactics: taktik
#   take: ambil
#   talk: bercakap
#   tarik: tarik tarik
#   task: tugas
#   teamwork: kerja berpasukan
#   tearing: merobek
#   technique: teknik
#   tedious: membosankan
#   teknik: teknik
#   teks: teks
#   temporary: sementara
#   tense: tegang
#   tension: ketegangan
#   term: terma
#   terrifying: menakutkan
#   than: daripada
#   that: itu
#   theme: tema
#   themes: tema
#   think: berfikir
#   thinking: berfikir
#   third person: orang ketiga
#   tight: ketat
#   timeless: tiada masa
#   timing: masa
#   tips: tip
#   too: juga
#   tool: alat
#   top: atas
#   top down: atas bawah
#   tough: sukar
#   tournaments: kejohanan
#   towards: ke arah
#   trading: perdagangan
#   traditional: tradisional
#   trailer: treler
#   training: latihan
#   transfer: pemindahan
#   tricky: sukar
#   turnaround: pusing
#   twist: putar
#   twitch: berkedut
#   two handed: dua tangan
#   unbalanced: tidak seimbang
#   unexpected: tidak dijangka
#   uninstall: nyahpasang
#   unique: unik
#   unlocked: membuka kunci
#   unpredictability: ketidaktentuan
#   unpredictable: tidak dapat diramalkan
#   unreliable: tidak boleh dipercayai
#   unstable: tidak stabil
#   unwind: berehatlah
#   update: kemas kini
#   updates: kemaskini
#   used: digunakan
#   user: pengguna
#   user friendly: mesra pengguna
#   utility: utiliti
#   v sync: segerak v
#   valuable: berharga
#   valve: injap
#   variable: pembolehubah
#   variety: pelbagai
#   versatile: serba boleh
#   vertical: menegak
#   victory: kemenangan
#   violence: keganasan
#   vision: penglihatan
#   visuals: visual
#   vital: penting
#   voice: suara
#   waktu: waktu waktu
#   weak: lemah
#   weapon: senjata
#   weapons: senjata
#   weight: berat badan
#   well: baik
#   well designed: direka baik
#   what: apa
#   wider: lebih lebar
#   wins: menang
#   with: dengan
#   world building: bina dunia
#   worth: bernilai
#   x axis: paksi x
#   y axis: paksi y
#   year: tahun
#   z axis: paksi z
#   zipper: zip
#   zombie: zombi
#   zones: zon
#   zoom: zum

# %% [markdown]
# ## 4.3 &nbsp;&nbsp; [Map to Modified Words](#home) <a id='map_to_modified'></a>
#
# We performed language detection on `malay_word` column to assist in identifying actual English words from 390 untranslated words derived earlier.
#
# Our observations:
#
# 1. 97 words in `malay_word` column were classified as English words by polyglot with confidence level of more than 90%.
# 2. Out of 97 words, some words were actual Malay words e.g. adaptabiliti, alternatif, etc. It appears polyglot is not as effective in differentiating between English and Malay words.
# 3. **Sound generated by Malay VITS model may deviate on every separate run**. This is likely due to the generator process which introduces a randomness to the audio output e.g. "on disc" may sometimes emphasize the "c" to sound "on disc c".
#
# As such, we have to go through all 391 untranslated English words and 97 English words identified after translation by polyglot to determine if Malaya VITS model is able to infer the English words properly. In the event of mispronunication, we would modify the word to get appropriate pronunciation.
#
# 1. Combine multiple English words.
# 2. Modify characters in word.
#
#
# We updated `gpt_mapping` with mapping of English words to their modified equivalent:
#
# ```
#   2D: two dee
#   2.5D: two point five dee
#   3D: three dee
#   4K: four kay
#   8K: eg kay
#   audio visual: audiovisual
#   cheat: cheet
#   comebacks: come back
#   digital: d gi tal
#   gear: yeer
#   genre: john ra
#   geocaching: geocashing
#   idea: i dea
#   pacing: paysing
#   sci fi: sigh fie
#   scoped: scope
#   sniper: snightper
#   traverse: travers
#   v sync: vee sync
#   wasd: dubberliu a ass dee
#   whiffs: whiff
#   wow: waoh
#   x axis: ax axis
#   xbox: ax box
#   y axis: wai axis
#   z axis: z axis
# ```

# %% [markdown]
# ##### Apply language detection on `malay_word` column

# %%
df_en_word_new[["lang", "lang_sc"]] = df_en_word_new["malay_word"].parallel_apply(
    lambda x: pd.Series(detect_language(x))
)
df_en_word_new.to_csv(cfg.paths.gpt_en_new_path, index=False)
df_en_word_new
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=189), Label(value='0 / 189'))), HB…
#                id          words    dictionary  \
# 0        new_en_0      abilities     abilities
# 1        new_en_1        ability     kebolehan
# 2        new_en_2         abrupt        abrupt
# 3        new_en_3         access         akses
# 4        new_en_4  accessibility  aksesibiliti
# ...           ...            ...           ...
# 1505  new_en_1505         zipper           zip
# 1506  new_en_1506         zombie        zombie
# 1507  new_en_1507           zona          zona
# 1508  new_en_1508          zones         zones
# 1509  new_en_1509           zoom          zoom
#
#                               transformer  words_len  dictionary_len  \
# 0                               kebolehan          9               9
# 1                               keupayaan          7               9
# 2                               Tiba-tiba          6               6
# 3                                 capaian          6               5
# 4                          kebolehcapaian         13              12
# ...                                   ...        ...             ...
# 1505                           ritsleting          6               3
# 1506                                zombi          6               6
# 1507  zonaCity in Illinois, United States          4               4
# 1508                                  zon          5               5
# 1509                                  zum          4               4
#
#       transformer_len    malay_word lang  lang_sc
# 0                   9     kebolehan   ms     90.0
# 1                   9     kebolehan   ms     90.0
# 2                   9     Tiba-tiba   id     90.0
# 3                   7         akses   no     85.0
# 4                  14  aksesibiliti   no     92.0
# ...               ...           ...  ...      ...
# 1505               10           zip   en     80.0
# 1506                5         zombi   rw     85.0
# 1507               35          zona   en     83.0
# 1508                3           zon   en     80.0
# 1509                3           zum   de     80.0
#
# [1510 rows x 10 columns]

# %% [markdown]
# ##### English words detected

# %%
# Select words that are English and have language confidence more than 90%
df_en_after = df_en_word_new.loc[(df_en_word_new["lang"] == "en") & (df_en_word_new["lang_sc"] > 90), :]
df_en_after
# Out:
#                id             words        dictionary       transformer  \
# 10      new_en_10  action-adventure  action-adventure  action-adventure
# 15      new_en_15      adaptabiliti      adaptabiliti      adaptabiliti
# 52      new_en_52        alternatif        alternatif        alternatif
# 53      new_en_53       alternative        alternatif        alternatif
# 64      new_en_64        anti-cheat        anti-cheat        anti-cheat
# ...           ...               ...               ...               ...
# 1383  new_en_1383      time-to-kill      time-to-kill      time-to-kill
# 1400  new_en_1400       tradisional       tradisional       tradisional
# 1401  new_en_1401       traditional       tradisional       tradisional
# 1405  new_en_1405            travel        perjalanan        perjalanan
# 1469  new_en_1469             waktu             waktu       waktu waktu
#
#       words_len  dictionary_len  transformer_len        malay_word lang  \
# 10           16              16               16  action-adventure   en
# 15           12              12               12      adaptabiliti   en
# 52           10              10               10        alternatif   en
# 53           11              10               10        alternatif   en
# 64           10              10               10        anti-cheat   en
# ...         ...             ...              ...               ...  ...
# 1383         12              12               12      time-to-kill   en
# 1400         11              11               11       tradisional   en
# 1401         11              11               11       tradisional   en
# 1405          6              10               10        perjalanan   en
# 1469          5               5               11       waktu waktu   en
#
#       lang_sc
# 10       94.0
# 15       92.0
# 52       91.0
# 53       91.0
# 64       91.0
# ...       ...
# 1383     92.0
# 1400     92.0
# 1401     92.0
# 1405     91.0
# 1469     92.0
#
# [97 rows x 10 columns]

# %%
for row in df_en_after.loc[:, ["id", "words", "malay_word", "lang", "lang_sc"]].itertuples(index=False, name=None):
    print(row)
# Out:
# ('new_en_10', 'action-adventure', 'action-adventure', 'en', 94.0)
# ('new_en_15', 'adaptabiliti', 'adaptabiliti', 'en', 92.0)
# ('new_en_52', 'alternatif', 'alternatif', 'en', 91.0)
# ('new_en_53', 'alternative', 'alternatif', 'en', 91.0)
# ('new_en_64', 'anti-cheat', 'anti-cheat', 'en', 91.0)
# ('new_en_66', 'antisipasi', 'antisipasi', 'en', 91.0)
# ('new_en_88', 'audio-visual', 'audio-visual', 'en', 92.0)
# ('new_en_89', 'audiovisual', 'audiovisual', 'en', 92.0)
# ('new_en_100', 'bahan-bahan', 'bahan-bahan', 'en', 92.0)
# ('new_en_106', 'battle', 'pertempuran', 'en', 92.0)
# ('new_en_107', 'battles', 'pertempuran', 'en', 92.0)
# ('new_en_112', 'bergerombol', 'bergerombol', 'en', 92.0)
# ('new_en_185', 'combat', 'pertempuran', 'en', 92.0)
# ('new_en_207', 'connected', 'disambungkan', 'en', 92.0)
# ('new_en_238', 'creativity', 'kreativiti', 'en', 91.0)
# ('new_en_294', 'diimplementasikan', 'diimplementasikan', 'en', 94.0)
# ('new_en_296', 'dikurangkan', 'dikurangkan', 'en', 92.0)
# ('new_en_300', 'dipercayai', 'dipercayai', 'en', 91.0)
# ('new_en_301', 'dipersonalisasi', 'dipersonalisasi', 'en', 94.0)
# ('new_en_344', 'efektivitas', 'efektivitas', 'en', 92.0)
# ('new_en_345', 'efektiviti', 'efektiviti', 'en', 91.0)
# ('new_en_355', 'eksklusivitas', 'eksklusivitas', 'en', 93.0)
# ('new_en_356', 'eksklusiviti', 'eksklusiviti', 'en', 92.0)
# ('new_en_357', 'eksperimen', 'eksperimen', 'en', 91.0)
# ('new_en_358', 'eksperimental', 'eksperimental', 'en', 93.0)
# ('new_en_359', 'eksplorasi', 'eksplorasi', 'en', 91.0)
# ('new_en_362', 'elemen-elemen', 'elemen-elemen', 'en', 93.0)
# ('new_en_404', 'evolusioner', 'evolusioner', 'en', 92.0)
# ('new_en_418', 'experiment', 'eksperimen', 'en', 91.0)
# ('new_en_486', 'futuristik', 'futuristik', 'en', 91.0)
# ('new_en_492', 'gameplay-nya', 'gameplay-nya', 'en', 92.0)
# ('new_en_505', 'geocaching', 'geocaching', 'en', 91.0)
# ('new_en_520', 'grafik', 'Grafiksxpart-type', 'en', 94.0)
# ('new_en_521', 'grafik-intensive', 'intensif-grafik', 'en', 94.0)
# ('new_en_579', 'immersion', 'perendaman', 'en', 91.0)
# ('new_en_613', 'integritas', 'integritas', 'en', 91.0)
# ('new_en_615', 'intelektual', 'intelektual', 'en', 92.0)
# ('new_en_622', 'interactive', 'interaktif', 'en', 91.0)
# ('new_en_624', 'interaktif', 'interaktif', 'en', 91.0)
# ('new_en_625', 'interaktiviti', 'interaktiviti', 'en', 93.0)
# ('new_en_628', 'intervensi', 'intervensi', 'en', 91.0)
# ('new_en_655', 'journey', 'perjalanan', 'en', 91.0)
# ('new_en_667', 'kelestarian', 'kelestarian', 'en', 92.0)
# ('new_en_681', 'kompatibilitas', 'kompatibilitas', 'en', 93.0)
# ('new_en_683', 'kompetitif', 'kompetitif', 'en', 91.0)
# ('new_en_687', 'kontinuitas', 'kontinuitas', 'en', 92.0)
# ('new_en_689', 'kontroversial', 'kontroversial', 'en', 93.0)
# ('new_en_691', 'kreativitas', 'kreativitas', 'en', 92.0)
# ('new_en_692', 'kreativiti', 'kreativiti', 'en', 91.0)
# ('new_en_695', 'kritikan', 'kritikStock label', 'en', 94.0)
# ('new_en_696', 'kustomisasi', 'kustomisasi', 'en', 92.0)
# ('new_en_780', 'membanggakan', 'membanggakan', 'en', 92.0)
# ('new_en_783', 'mempublish', 'mempublish', 'en', 91.0)
# ('new_en_784', 'mencengangkan', 'mencengangkan', 'en', 93.0)
# ('new_en_786', 'mendeskripsikan', 'mendeskripsikan', 'en', 94.0)
# ('new_en_787', 'mendominasi', 'mendominasi', 'en', 92.0)
# ('new_en_791', 'merampingkan', 'merampingkan', 'en', 92.0)
# ('new_en_816', 'modifikasi', 'modifikasi', 'en', 91.0)
# ('new_en_820', 'momen-momen', 'momen-momen', 'en', 92.0)
# ('new_en_823', 'monetisasi', 'monetisasi', 'en', 91.0)
# ('new_en_835', 'movement', 'pergerakan', 'en', 91.0)
# ('new_en_840', 'multimedia', 'multimedia', 'en', 91.0)
# ('new_en_842', 'multitasking', 'multitasking', 'en', 92.0)
# ('new_en_902', 'paranormal', 'paranormal', 'en', 91.0)
# ('new_en_913', 'penimbangan', 'penimbangan', 'en', 92.0)
# ('new_en_915', 'peperangan', 'peperangan', 'en', 91.0)
# ('new_en_917', 'percakapan', 'percakapan', 'en', 91.0)
# ('new_en_920', 'perdebatan', 'perdebatan', 'en', 91.0)
# ('new_en_923', 'pergerakan', 'pergerakan', 'en', 91.0)
# ('new_en_925', 'peringatan', 'peringatan', 'en', 91.0)
# ('new_en_928', 'perjalanan', 'perjalanan perjalanan', 'en', 95.0)
# ('new_en_929', 'persenjataan', 'persenjataan', 'en', 92.0)
# ('new_en_932', 'personalisasi', 'personalisasi', 'en', 93.0)
# ('new_en_935', 'perspective', 'perspektif', 'en', 91.0)
# ('new_en_936', 'perspektif', 'perspektif', 'en', 91.0)
# ('new_en_938', 'pertempuran', 'pertempuran', 'en', 92.0)
# ('new_en_939', 'pertimbangan', 'pertimbangan', 'en', 92.0)
# ('new_en_941', 'petualangan', 'petualangan', 'en', 92.0)
# ('new_en_954', 'platformer', 'platformer', 'en', 91.0)
# ('new_en_955', 'platformers', 'platformers', 'en', 92.0)
# ('new_en_956', 'platforming', 'platformulasi', 'en', 93.0)
# ('new_en_1005', 'progresinya', 'progresinya', 'en', 92.0)
# ('new_en_1013', 'provokatif', 'provokatif', 'en', 91.0)
# ('new_en_1069', 'reminder', 'peringatan', 'en', 91.0)
# ('new_en_1077', 'representasi', 'representasi', 'en', 92.0)
# ('new_en_1095', 'responsivitas', 'responsivitas', 'en', 93.0)
# ('new_en_1096', 'responsiviti', 'responsiviti', 'en', 92.0)
# ('new_en_1171', 'sensitiviti', 'sensitiviti', 'en', 92.0)
# ('new_en_1216', 'skirmish', 'pertempuran', 'en', 92.0)
# ('new_en_1255', 'spontaniti', 'spontaniti', 'en', 91.0)
# ('new_en_1341', 'tarik', 'tarik tarik', 'en', 92.0)
# ('new_en_1365', 'tertinggal', 'tertinggal', 'en', 91.0)
# ('new_en_1383', 'time-to-kill', 'time-to-kill', 'en', 92.0)
# ('new_en_1400', 'tradisional', 'tradisional', 'en', 92.0)
# ('new_en_1401', 'traditional', 'tradisional', 'en', 92.0)
# ('new_en_1405', 'travel', 'perjalanan', 'en', 91.0)
# ('new_en_1469', 'waktu', 'waktu waktu', 'en', 92.0)

# %% [markdown]
# # 5. &nbsp;&nbsp; [Normalize GPT Corpus](#home) <a id='normalize_gpt_corpus'></a>
#
# We normalize gaming terms in GPT corpus (via `mapping` dictionary) first followed by normalize remaining terms (via `gpt_mapping`). If we normalize the corpus with `gpt_mapping`, gaming terms may be accidentally be amended.

# %% [markdown]
# ## 5.1 &nbsp;&nbsp; [Normalize Gaming Terms](#home) <a id='norm_gaming'></a>
#
# Normalize gaming terms via `mapping` in `gaming.yaml`.

# %%
df_gpt["norm_gaming"] = df_gpt["text"].parallel_map(normalize_gaming)
df_gpt
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=456), Label(value='0 / 456'))), HB…
#             id                                               text  \
# 0        gpt_0  Dengan mendapat 1-up , saya boleh teruskan per...
# 1        gpt_1  Grafik 16-bit memberikan sentuhan nostalgia ya...
# 2        gpt_2  Saya berjaya melakukan 1CC pada permainan arke...
# 3        gpt_3  Pertarungan 1v1 itu benar-benar mencabar kemah...
# 4        gpt_4  Grafik 2.5D memberikan dimensi yang menarik ke...
# ...        ...                                                ...
# 3641  gpt_3641                          Macam mana gameplay dia ?
# 3642  gpt_3642  Zone dalam game merujuk kepada kawasan atau wi...
# 3643  gpt_3643                       Okey , aku cover left zone .
# 3644  gpt_3644  Zoning dalam game adalah strategi untuk kawal ...
# 3645  gpt_3645     Aku cover flank , kita kena maintain control .
#
#                 gaming                    en_words  \
# 0               [1-up]                          []
# 1             [16-bit]      [Grafik, 16-bit, unik]
# 2                [1CC]                          []
# 3                [1v1]                          []
# 4                   []           [Grafik, dimensi]
# ...                ...                         ...
# 3641  [gameplay, mana]                  [gameplay]
# 3642            [zone]          [Zone, game, peta]
# 3643            [zone]   [Okey, cover, left, zone]
# 3644          [zoning]    [game, strategi, secure]
# 3645                []  [cover, maintain, control]
#
#                                             norm_gaming
# 0     Dengan mendapat one up , saya boleh teruskan p...
# 1     Grafik sixteen beat memberikan sentuhan nostal...
# 2     Saya berjaya melakukan One C C pada permainan ...
# 3     Pertarungan one versus one itu benar benar men...
# 4     Grafik 2.5D memberikan dimensi yang menarik ke...
# ...                                                 ...
# 3641                         Macam mana game play dia ?
# 3642  Zone dalam game merujuk kepada kawasan atau wi...
# 3643                       Okey , aku cover left zone .
# 3644  Zoning dalam game adalah strategi untuk kawal ...
# 3645     Aku cover flank , kita kena maintain control .
#
# [3646 rows x 5 columns]

# %% [markdown]
# ## 5.2 &nbsp;&nbsp; [Normalize English Words](#norm_en)
#
# Normalize remaining English words with `gpt_mapping` in `gaming.yaml`.

# %%
df_gpt["norm_gpt"] = df_gpt["norm_gaming"].parallel_map(normalize_gpt)
df_gpt.to_csv(cfg.paths.gpt_csv_path, index=False)
df_gpt
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=456), Label(value='0 / 456'))), HB…
#             id                                               text  \
# 0        gpt_0  Dengan mendapat 1-up , saya boleh teruskan per...
# 1        gpt_1  Grafik 16-bit memberikan sentuhan nostalgia ya...
# 2        gpt_2  Saya berjaya melakukan 1CC pada permainan arke...
# 3        gpt_3  Pertarungan 1v1 itu benar-benar mencabar kemah...
# 4        gpt_4  Grafik 2.5D memberikan dimensi yang menarik ke...
# ...        ...                                                ...
# 3641  gpt_3641                          Macam mana gameplay dia ?
# 3642  gpt_3642  Zone dalam game merujuk kepada kawasan atau wi...
# 3643  gpt_3643                       Okey , aku cover left zone .
# 3644  gpt_3644  Zoning dalam game adalah strategi untuk kawal ...
# 3645  gpt_3645     Aku cover flank , kita kena maintain control .
#
#                 gaming                    en_words  \
# 0               [1-up]                          []
# 1             [16-bit]      [Grafik, 16-bit, unik]
# 2                [1CC]                          []
# 3                [1v1]                          []
# 4                   []           [Grafik, dimensi]
# ...                ...                         ...
# 3641  [gameplay, mana]                  [gameplay]
# 3642            [zone]          [Zone, game, peta]
# 3643            [zone]   [Okey, cover, left, zone]
# 3644          [zoning]    [game, strategi, secure]
# 3645                []  [cover, maintain, control]
#
#                                             norm_gaming  \
# 0     Dengan mendapat one up , saya boleh teruskan p...
# 1     Grafik sixteen beat memberikan sentuhan nostal...
# 2     Saya berjaya melakukan One C C pada permainan ...
# 3     Pertarungan one versus one itu benar benar men...
# 4     Grafik 2.5D memberikan dimensi yang menarik ke...
# ...                                                 ...
# 3641                         Macam mana game play dia ?
# 3642  Zone dalam game merujuk kepada kawasan atau wi...
# 3643                       Okey , aku cover left zone .
# 3644  Zoning dalam game adalah strategi untuk kawal ...
# 3645     Aku cover flank , kita kena maintain control .
#
#                                                norm_gpt
# 0     Dengan mendapat one up , saya boleh teruskan p...
# 1     Grafik sixteen beat memberikan sentuhan nostal...
# 2     Saya berjaya melakukan One C C pada permainan ...
# 3     Pertarungan one versus one itu benar benar men...
# 4     Grafik two point five dee memberikan dimensi y...
# ...                                                 ...
# 3641                         Macam mana game play dia ?
# 3642  Zone dalam game merujuk kepada kawasan atau wi...
# 3643               Okey , aku cover ditinggalkan zone .
# 3644  Zoning dalam game adalah strategi untuk kawal ...
# 3645  Aku cover flank , kita kena mengekalkan control .
#
# [3646 rows x 6 columns]

# %%
for row in df_gpt.loc[:, ["id", "text", "norm_gpt"]].itertuples(index=False, name=None):
    print(row)
# Out:
# ('gpt_0', 'Dengan mendapat 1-up , saya boleh teruskan permainan ini tanpa kehilangan nyawa .', 'Dengan mendapat one up , saya boleh teruskan permainan ini tanpa kehilangan nyawa .')
# ('gpt_1', 'Grafik 16-bit memberikan sentuhan nostalgia yang unik pada permainan ini .', 'Grafik sixteen beat memberikan sentuhan nostalgia yang unik pada permainan ini .')
# ('gpt_2', 'Saya berjaya melakukan 1CC pada permainan arked lama semalam !', 'Saya berjaya melakukan One C C pada permainan arked lama semalam !')
# ('gpt_3', 'Pertarungan 1v1 itu benar-benar mencabar kemahiran permainan saya .', 'Pertarungan one versus one itu benar benar mencabar kemahiran permainan saya .')
# ('gpt_4', 'Grafik 2.5D memberikan dimensi yang menarik kepada permainan ini .', 'Grafik two point five dee memberikan dimensi yang menarik kepada permainan ini .')
# ('gpt_5', 'Suasana retro terasa apabila bermain dengan grafik 2D yang klasik .', 'Suasana retro terasa apabila bermain dengan grafik two dee yang klasik .')
# ('gpt_6', 'Peningkatan kepada 32-bit membawa permainan ini ke tahap visual yang baru .', 'Peningkatan kepada thirty two beat membawa permainan ini ke tahap visual yang baru .')
# ('gpt_7', 'Gerakan 360 no-scope memerlukan ketepatan dan kecepatan yang tinggi .', 'Gerakan three sixty no scope memerlukan ketepatan dan kecepatan yang tinggi .')
# ('gpt_8', 'Penggunaan grafik 3D memberikan pengalaman permainan yang lebih hidup .', 'Penggunaan grafik three dee memberikan pengalaman permainan yang lebih hidup .')
# ('gpt_9', 'Kesemua butiran jelas terlihat pada resolusi 4K ini .', 'Kesemua butiran jelas terlihat pada resolusi four kay ini .')
# ('gpt_10', 'Saya tidak dapat melepaskan permainan ini dengan grafik 2D yang indah .', 'Saya tidak dapat melepaskan permainan ini dengan grafik two dee yang indah .')
# ('gpt_11', 'Keupayaan untuk bertarung 1v1 dengan rakan membawa keseronokan yang tersendiri .', 'Keupayaan untuk bertarung one versus one dengan rakan membawa keseronokan yang tersendiri .')
# ('gpt_12', 'Pengalaman 2.5D graphics membuatkan permainan ini terasa unik .', 'Pengalaman two point five dee grafik membuatkan permainan ini terasa unik .')
# ('gpt_13', 'Kesemua warna dan animasi pada grafik 16-bit ini sangat memukau .', 'Kesemua warna dan animasi pada grafik sixteen beat ini sangat memukau .')
# ('gpt_14', 'Saya selalu mencuba melakukan 360 no-scope ketika dalam pertempuran sengit .', 'Saya selalu mencuba melakukan three sixty no scope ketika dalam pertempuran sengit .')
# ('gpt_15', 'Dengan teknologi 32-bit , permainan ini kelihatan lebih realistik .', 'Dengan teknologi thirty two beat , permainan ini kelihatan lebih realistik .')
# ('gpt_16', 'Keunikan 2D graphics memberikan rasa nostalgia yang mendalam .', 'Keunikan two dee grafik memberikan rasa nostalgia yang mendalam .')
# ('gpt_17', 'Pertarungan 1v1 selalu menjadi ujian sebenar kemahiran permainan saya .', 'Pertarungan one versus one selalu menjadi ujian sebenar kemahiran permainan saya .')
# ('gpt_18', 'Resolusi 4K memberikan ketajaman visual yang tidak dapat dipercayai .', 'Resolusi four kay memberikan ketajaman visual yang tidak dapat dipercayai .')
# ('gpt_19', 'Saya sentiasa kagum dengan kecantikan grafik 3D dalam permainan ini .', 'Saya sentiasa kagum dengan kecantikan grafik three dee dalam permainan ini .')
# ('gpt_20', 'Peningkatan kepada 16-bit memberikan permainan ini corak yang menarik .', 'Peningkatan kepada sixteen beat memberikan permainan ini corak yang menarik .')
# ('gpt_21', 'Mencapai 1CC bukanlah perkara mudah , tetapi saya berjaya !', 'Mencapai One C C bukanlah perkara mudah , tetapi saya berjaya !')
# ('gpt_22', 'Pertarungan 1v1 ini seakan-akan menguji kebolehan sebenar saya .', 'Pertarungan one versus one ini seakan akan menguji kebolehan sebenar saya .')
# ('gpt_23', 'Grafik 2.5D memberikan kedalaman visual yang hebat pada permainan ini .', 'Grafik two point five dee memberikan kedalaman visual yang hebat pada permainan ini .')
# ('gpt_24', 'Keindahan grafik 2D ini benar-benar menawan hati pemain .', 'Keindahan grafik two dee ini benar benar menawan hati pemain .')
# ('gpt_25', 'Dengan teknologi 32-bit , permainan ini tampak lebih canggih .', 'Dengan teknologi thirty two beat , permainan ini tampak lebih canggih .')
# ('gpt_26', '360 no-scope selalu menjadi jurus kegemaran saya dalam permainan tembak-menembak .', 'three sixty no scope selalu menjadi jurus kegemaran saya dalam permainan tembak menembak .')
# ('gpt_27', 'Grafik 3D membuatkan dunia permainan ini kelihatan hidup .', 'Grafik three dee membuatkan dunia permainan ini kelihatan hidup .')
# ('gpt_28', 'Resolusi 4K memberikan kejelasan yang memukau pada setiap adegan .', 'Resolusi four kay memberikan kejelasan yang memukau pada setiap adegan .')
# ('gpt_29', 'Saya suka permainan ini kerana grafik 2D yang membawa kembali kenangan .', 'Saya suka permainan ini kerana grafik two dee yang membawa kembali kenangan .')
# ('gpt_30', 'Pertarungan 1v1 ini sentiasa mengejutkan dengan strategi yang berbeza .', 'Pertarungan one versus one ini sentiasa mengejutkan dengan strategi yang berbeza .')
# ('gpt_31', 'Grafik 16-bit memberikan sentuhan retro yang tidak dapat dipadankan .', 'Grafik sixteen beat memberikan sentuhan retro yang tidak dapat dipadankan .')
# ('gpt_32', 'Saya ingin mencuba melakukan 360 no-scope dalam pertempuran seterusnya .', 'Saya ingin mencuba melakukan three sixty no scope dalam pertempuran seterusnya .')
# ('gpt_33', 'Penggunaan 3D graphics menjadikan permainan ini lebih menghiburkan .', 'Penggunaan three dee grafik menjadikan permainan ini lebih menghiburkan .')
# ('gpt_34', '2.5D graphics memberikan elemen visual yang menarik dalam permainan .', 'two point five dee grafik memberikan elemen visual yang menarik dalam permainan .')
# ('gpt_35', 'Saya teruja dengan kualiti grafik 2D pada permainan ini .', 'Saya teruja dengan kualiti grafik two dee pada permainan ini .')
# ('gpt_36', '1CC bukanlah perkara mudah , tetapi kepuasan apabila berjaya adalah luar biasa .', 'One C C bukanlah perkara mudah , tetapi kepuasan apabila berjaya adalah luar biasa .')
# ('gpt_37', 'Kejelasan 4K resolution menjadikan setiap butiran tampak lebih hidup .', 'Kejelasan four kay resolution menjadikan setiap butiran tampak lebih hidup .')
# ('gpt_38', 'Saya sentiasa terpesona dengan keunikan grafik 3D dalam permainan ini .', 'Saya sentiasa terpesona dengan keunikan grafik three dee dalam permainan ini .')
# ('gpt_39', 'Pertarungan 1v1 selalu membawa perasaan ketegangan yang menyeronokkan .', 'Pertarungan one versus one selalu membawa perasaan ketegangan yang menyeronokkan .')
# ('gpt_40', 'Saya suka bagaimana grafik 2.5D memberikan dimensi tambahan pada permainan .', 'Saya suka bagaimana grafik two point five dee memberikan dimensi tambahan pada permainan .')
# ('gpt_41', 'Resolusi 16-bit memberikan perasaan klasik yang tidak dapat dilupakan .', 'Resolusi sixteen beat memberikan perasaan klasik yang tidak dapat dilupakan .')
# ('gpt_42', 'Melakukan 360 no-scope memerlukan latihan dan ketepatan yang tinggi .', 'Melakukan three sixty no scope memerlukan latihan dan ketepatan yang tinggi .')
# ('gpt_43', 'Grafik 3D ini membuatkan permainan ini terasa seperti dunia yang nyata .', 'Grafik three dee ini membuatkan permainan ini terasa seperti dunia yang nyata .')
# ('gpt_44', '2D graphics memberikan sentuhan visual yang bersahaja pada permainan .', 'two dee grafik memberikan sentuhan visual yang bersahaja pada permainan .')
# ('gpt_45', 'Kejelasan 32-bit memberikan permainan ini penampilan yang lebih moden .', 'Kejelasan thirty two beat memberikan permainan ini penampilan yang lebih moden .')
# ('gpt_46', 'Saya sentiasa mencuba bertarung 1v1 dengan pemain-pemain terbaik .', 'Saya sentiasa mencuba bertarung one versus one dengan pemain pemain terbaik .')
# ('gpt_47', 'Resolusi 4K ini membuatkan permainan ini kelihatan sungguh mengagumkan .', 'Resolusi four kay ini membuatkan permainan ini kelihatan sungguh mengagumkan .')
# ('gpt_48', 'Pengalaman 3D graphics membawa permainan ini ke tahap seterusnya .', 'Pengalaman three dee grafik membawa permainan ini ke tahap seterusnya .')
# ('gpt_49', 'Grafik 2D yang cantik membuatkan permainan ini begitu menarik .', 'Grafik two dee yang cantik membuatkan permainan ini begitu menarik .')
# ('gpt_50', 'Resolusi 8K memberikan kejelasan visual yang luar biasa pada permainan ini .', 'Resolusi eg kay memberikan kejelasan visual yang luar biasa pada permainan ini .')
# ('gpt_51', 'AAA menunjukkan kualiti permainan yang paling tinggi dan berkualiti tinggi .', 'triple A menunjukkan kualiti permainan yang paling tinggi dan berkualiti tinggi .')
# ('gpt_52', 'Saya terpaksa AFK sebentar , tetapi akan kembali segera untuk terus bermain .', 'Saya terpaksa A F kay sebentar , tetapi akan kembali segera untuk terus bermain .')
# ('gpt_53', 'Pengalaman bermain ARPG ini begitu mendalam dan menarik .', 'Pengalaman bermain action R pee gee ini begitu mendalam dan menarik .')
# ('gpt_54', 'Anti-Aim membantu saya mengelakkan serangan lawan dengan lebih efektif .', 'Anti Aim membantu saya mengelakkan serangan lawan dengan lebih efektif .')
# ('gpt_55', 'Area-of-effect AoE serangan ini benar-benar hebat dalam mengatasi musuh bergerombol .', 'a rea of effect A O E serangan ini benar benar hebat dalam mengatasi musuh bergerombol .')
# ('gpt_56', 'B-hopping memberikan kelebihan mobiliti yang besar dalam permainan ini .', 'bee hopping memberikan kelebihan mobiliti yang besar dalam permainan ini .')
# ('gpt_57', 'Saya suka bagaimana resolusi 8K ini membuatkan setiap butiran terlihat lebih hidup .', 'Saya suka bagaimana resolusi eg kay ini membuatkan setiap butiran terlihat lebih hidup .')
# ('gpt_58', 'Permainan AAA ini benar-benar mengagumkan dengan grafik yang hebat .', 'Permainan triple A ini benar benar mengagumkan dengan grafik yang hebat .')
# ('gpt_59', 'Walaupun AFK sebentar , saya masih mempunyai hasrat untuk memenangi permainan ini .', 'Walaupun A F kay sebentar , saya masih mempunyai hasrat untuk memenangi permainan ini .')
# ('gpt_60', 'Saya suka permainan ARPG kerana berbagai-bagai pilihan strategi .', 'Saya suka permainan action R pee gee kerana berbagai bagai pilihan strategi .')
# ('gpt_61', 'Anti-Aim membantu saya mengelakkan pihak lawan dengan lebih licin .', 'Anti Aim membantu saya mengelakkan pihak lawan dengan lebih licin .')
# ('gpt_62', 'AoE serangan ini membawa kesan yang besar kepada kumpulan musuh .', 'A O E serangan ini membawa kesan yang besar kepada kumpulan musuh .')
# ('gpt_63', 'B-hopping memberikan elemen kejutan dan kecepatan dalam permainan ini .', 'bee hopping memberikan elemen kejutan dan kecepatan dalam permainan ini .')
# ('gpt_64', 'Kualiti grafik AAA ini menjadikan permainan ini berada di tahap tertinggi .', 'Kualiti grafik triple A ini menjadikan permainan ini berada di tahap tertinggi .')
# ('gpt_65', 'Resolusi 8K ini membenamkan saya sepenuhnya dalam dunia permainan .', 'Resolusi eg kay ini membenamkan saya sepenuhnya dalam dunia permainan .')
# ('gpt_66', 'Sementara AFK , saya merancang strategi untuk mendominasi permainan ini .', 'Sementara A F kay , saya merancang strategi untuk mendominasi permainan ini .')
# ('gpt_67', 'ARPG ini benar-benar menguji kemahiran taktikal saya .', 'action R pee gee ini benar benar menguji kemahiran taktikal saya .')
# ('gpt_68', 'Anti-Aim membolehkan saya mengalahkan musuh dengan lebih cekap .', 'Anti Aim membolehkan saya mengalahkan musuh dengan lebih cekap .')
# ('gpt_69', 'AoE serangan ini memberikan impak yang besar pada medan perang .', 'A O E serangan ini memberikan impak yang besar pada medan perang .')
# ('gpt_70', 'B-hopping memberikan kelebihan ketika bergerak dalam medan pertempuran .', 'bee hopping memberikan kelebihan ketika bergerak dalam medan pertempuran .')
# ('gpt_71', 'Saya tidak boleh lepas dari pengalaman permainan dengan resolusi 8K ini .', 'Saya tidak boleh lepas dari pengalaman permainan dengan resolusi eg kay ini .')
# ('gpt_72', 'Permainan AAA ini memenuhi semua jangkaan saya untuk sebuah permainan berkualiti .', 'Permainan triple A ini memenuhi semua jangkaan saya untuk sebuah permainan berkualiti .')
# ('gpt_73', 'Saya kembali selepas AFK dengan semangat yang lebih kuat untuk menang .', 'Saya kembali selepas A F kay dengan semangat yang lebih kuat untuk menang .')
# ('gpt_74', 'ARPG ini menawarkan pengalaman bermain yang sangat seronok .', 'action R pee gee ini menawarkan pengalaman bermain yang sangat seronok .')
# ('gpt_75', 'Teknik Anti-Aim ini benar-benar memenangi pertarungan dengan lebih bijak .', 'Teknik Anti Aim ini benar benar memenangi pertarungan dengan lebih bijak .')
# ('gpt_76', 'AoE serangan ini mencipta kacau dalam barisan musuh .', 'A O E serangan ini mencipta kacau dalam barisan musuh .')
# ('gpt_77', 'B-hopping memberikan perasaan kebebasan dalam pergerakan saya .', 'bee hopping memberikan perasaan kebebasan dalam pergerakan saya .')
# ('gpt_78', 'Resolusi 8K memberikan permainan ini dimensi visual yang hebat .', 'Resolusi eg kay memberikan permainan ini dimensi visual yang hebat .')
# ('gpt_79', 'AAA permainan ini memanggil pemain-pemain terbaik dari seluruh dunia .', 'triple A permainan ini memanggil pemain pemain terbaik dari seluruh dunia .')
# ('gpt_80', 'Saya terpaksa AFK sebentar untuk urusan kecemasan , tetapi akan kembali segera .', 'Saya terpaksa A F kay sebentar untuk urusan kecemasan , tetapi akan kembali segera .')
# ('gpt_81', 'ARPG ini menawarkan peluang untuk meneroka dunia fantastik yang besar .', 'action R pee gee ini menawarkan peluang untuk meneroka dunia fantastik yang besar .')
# ('gpt_82', 'Anti-Aim membantu saya menjadi lebih sulit sasaran dalam pertempuran .', 'Anti Aim membantu saya menjadi lebih sulit sasaran dalam pertempuran .')
# ('gpt_83', 'AoE serangan ini memusnahkan musuh dalam jumlah besar sekaligus .', 'A O E serangan ini memusnahkan musuh dalam jumlah besar sekaligus .')
# ('gpt_84', 'B-hopping memberikan kelebihan taktikal yang besar pada permainan ini .', 'bee hopping memberikan kelebihan taktikal yang besar pada permainan ini .')
# ('gpt_85', 'Resolusi 8K ini menjadikan setiap detik permainan sungguh menakjubkan .', 'Resolusi eg kay ini menjadikan setiap detik permainan sungguh menakjubkan .')
# ('gpt_86', 'Saya selalu terpesona dengan kualiti AAA pada permainan ini .', 'Saya selalu terpesona dengan kualiti triple A pada permainan ini .')
# ('gpt_87', 'Sementara AFK , saya memikirkan strategi untuk menangkap pihak lawan .', 'Sementara A F kay , saya memikirkan strategi untuk menangkap pihak lawan .')
# ('gpt_88', 'ARPG ini benar-benar menguji kemahiran dan kepandaian saya .', 'action R pee gee ini benar benar menguji kemahiran dan kepandaian saya .')
# ('gpt_89', 'Anti-Aim membantu saya keluar dari situasi yang berbahaya dengan lebih cekap .', 'Anti Aim membantu saya keluar dari situasi yang berbahaya dengan lebih cekap .')
# ('gpt_90', 'AoE serangan ini memberikan kemenangan besar dalam pertempuran .', 'A O E serangan ini memberikan kemenangan besar dalam pertempuran .')
# ('gpt_91', 'B-hopping memberikan elemen kejutan yang menyeronokkan dalam permainan .', 'bee hopping memberikan elemen kejutan yang menyeronokkan dalam permainan .')
# ('gpt_92', 'Resolusi 8K ini menjadikan setiap rincian permainan sangat jelas .', 'Resolusi eg kay ini menjadikan setiap rincian permainan sangat jelas .')
# ('gpt_93', 'AAA permainan ini benar-benar memikat hati pemain dengan kualiti terbaik .', 'triple A permainan ini benar benar memikat hati pemain dengan kualiti terbaik .')
# ('gpt_94', 'AFK sebentar untuk membuat persiapan sebelum perlawanan yang sengit .', 'A F kay sebentar untuk membuat persiapan sebelum perlawanan yang sengit .')
# ('gpt_95', 'ARPG ini membawa saya ke dalam dunia fantasi yang tidak dapat dipercayai .', 'action R pee gee ini membawa saya ke dalam dunia fantasi yang tidak dapat dipercayai .')
# ('gpt_96', 'Anti-Aim membolehkan saya menguasai kawalan pertempuran dengan lebih baik .', 'Anti Aim membolehkan saya menguasai kawalan pertempuran dengan lebih baik .')
# ('gpt_97', 'AoE serangan ini memberikan kelebihan strategik dalam permainan .', 'A O E serangan ini memberikan kelebihan strategik dalam permainan .')
# ('gpt_98', 'B-hopping membuat pergerakan saya lebih pantas dan taktikal .', 'bee hopping membuat pergerakan saya lebih pantas dan taktikal .')
# ('gpt_99', 'Resolusi 8K ini menjadikan setiap momen dalam permainan ini sangat menarik .', 'Resolusi eg kay ini menjadikan setiap momen dalam permainan ini sangat menarik .')
# ('gpt_100', 'Pembelian satu kali B2P memberikan akses sepenuhnya ke permainan ini tanpa sebarang langganan bulanan .', 'Pembelian satu kali bee to pee memberikan akses sepenuhnya ke permainan ini tanpa sebarang langganan bulan .')
# ('gpt_101', 'BM atau badan menggulung memberikan kelebihan taktikal dalam permainan ini .', 'bad manners atau badan menggulung memberikan kelebihan taktikal dalam permainan ini .')
# ('gpt_102', 'Sistem Pengurusan Konten CMS membolehkan pemain berkongsi dan mencipta kandungan mereka sendiri .', 'Sistem Pengurusan Konten C em ass membolehkan pemain berkongsi dan mencipta kandungan mereka sendiri .')
# ('gpt_103', 'CPU atau unit pemprosesan pusat adalah jantung utama dalam sistem komputer gaming .', 'C pee you atau unit pemprosesan pusat adalah jantung utama dalam sistem komputer gaming .')
# ('gpt_104', 'Pertarungan antara CPU versus CPU menunjukkan kebolehan kecerdasan buatan dalam permainan .', 'Pertarungan antara C pee you versus C pee you menunjukkan kebolehan kecerdasan buatan dalam permainan .')
# ('gpt_105', 'CRPG atau permainan peranan bergaya klasik memberikan pengalaman bermain yang mendalam .', 'C R pee gee atau permainan peranan bergaya klasik memberikan pengalaman bermain yang mendalam .')
# ('gpt_106', 'Capture the Flag CTF merupakan satu mode permainan yang menguji taktikal dan kerjasama pasukan .', 'kapchur the Flag kapchur the flag merupakan satu mode permainan yang menguji taktikal dan kerjasama pasukan .')
# ('gpt_107', 'D-pad atau directional pad memudahkan pemain untuk menggerakkan watak dalam permainan .', 'dee pad atau dai rectional pad memudahkan pemain untuk menggerakkan watak dalam permainan .')
# ('gpt_108', 'Kandungan Muat Turun DLC memberikan pengalaman permainan yang diperbaharui dengan kandungan baru .', 'Kandungan Muat Turun dee el C memberikan pengalaman permainan yang diperbaharui dengan kandungan baru .')
# ('gpt_109', 'DPM atau damage per minute mengukur jumlah kerosakan yang boleh dihasilkan oleh pemain dalam satu minit .', 'der mage per mi nit atau darmeage per minit mengukur jumlah kerosakan yang boleh dihasilkan oleh pemain dalam satu minit .')
# ('gpt_110', 'Sistem B2P memberikan keadilan kepada semua pemain tanpa perlu berlangganan bulanan .', 'Sistem bee to pee memberikan keadilan kepada semua pemain tanpa perlu berlangganan bulan .')
# ('gpt_111', 'BM adalah strategi yang berguna untuk menangani keadaan tertentu dalam permainan .', 'bad manners adalah strategi yang berguna untuk menangani keadaan tertentu dalam permainan .')
# ('gpt_112', 'CMS membolehkan pemain menjadi pencipta kandungan dalam dunia permainan .', 'C em ass membolehkan pemain menjadi pencipta kandungan dalam dunia permainan .')
# ('gpt_113', 'CPU yang cekap memberikan prestasi yang tinggi dalam permainan grafik-intensive .', 'C pee you yang cekap memberikan prestasi yang tinggi dalam permainan intensif grafik .')
# ('gpt_114', 'Pertarungan CPU versus CPU memberikan pandangan kepada kecerdasan buatan dalam permainan .', 'Pertarungan C pee you versus C pee you memberikan pandangan kepada kecerdasan buatan dalam permainan .')
# ('gpt_115', 'CRPG menyajikan cerita dan pengalaman bermain yang mendalam kepada pemain .', 'C R pee gee menyajikan cerita dan pengalaman bermain yang mendalam kepada pemain .')
# ('gpt_116', 'CTF memerlukan kerjasama pasukan untuk mencapai objektif permainan .', 'kapchur the flag memerlukan kerjasama pasukan untuk mencapai objektif permainan .')
# ('gpt_117', 'Penggunaan D-pad memudahkan navigasi dalam dunia permainan .', 'Penggunaan dee pad memudahkan navigasi dalam dunia permainan .')
# ('gpt_118', 'DLC memberikan kepelbagaian kandungan untuk mengekalkan keseronokan permainan .', 'dee el C memberikan kepelbagaian kandungan untuk mengekalkan keseronokan permainan .')
# ('gpt_119', 'DPM adalah ukuran keberkesanan pemain dalam menyebabkan kerosakan kepada musuh .', 'der mage per mi nit adalah ukuran keberkesanan pemain dalam menyebabkan kerosakan kepada musuh .')
# ('gpt_120', 'Sistem B2P menjadikan permainan lebih mudah diakses oleh semua pemain .', 'Sistem bee to pee menjadikan permainan lebih mudah diakses oleh semua pemain .')
# ('gpt_121', 'BM menjadi strategi yang penting dalam pertempuran sengit .', 'bad manners menjadi strategi yang penting dalam pertempuran sengit .')
# ('gpt_122', 'CMS memberikan kebebasan kepada pemain untuk berkreasi dalam permainan .', 'C em ass memberikan kebebasan kepada pemain untuk berkreasi dalam permainan .')
# ('gpt_123', 'CPU yang cepat meningkatkan prestasi permainan secara keseluruhan .', 'C pee you yang cepat meningkatkan prestasi permainan secara keseluruhan .')
# ('gpt_124', 'Pertarungan CPU versus CPU memberikan simulasi yang menarik untuk ditonton .', 'Pertarungan C pee you versus C pee you memberikan simulasi yang menarik untuk ditonton .')
# ('gpt_125', 'CRPG memadukan unsur permainan peranan klasik dengan teknologi terkini .', 'C R pee gee memadukan unsur permainan peranan klasik dengan teknologi terkini .')
# ('gpt_126', 'CTF menguji kepantasan taktikal dan kerjasama antara pemain .', 'kapchur the flag menguji kepantasan taktikal dan kerjasama antara pemain .')
# ('gpt_127', 'Penggunaan D-pad memudahkan pemain untuk membuat keputusan dalam permainan .', 'Penggunaan dee pad memudahkan pemain untuk membuat keputusan dalam permainan .')
# ('gpt_128', 'DLC memberikan nilai tambah kepada pengalaman permainan yang sedia ada .', 'dee el C memberikan nilai tambah kepada pengalaman permainan yang sedia ada .')
# ('gpt_129', 'DPM adalah faktor penting dalam menentukan keberkesanan serangan pemain .', 'der mage per mi nit adalah faktor penting dalam menentukan keberkesanan serangan pemain .')
# ('gpt_130', 'Sistem B2P memberikan alternatif yang adil untuk pemain .', 'Sistem bee to pee memberikan alternatif yang adil untuk pemain .')
# ('gpt_131', 'BM menjadi kelebihan tersendiri untuk pemain yang bijak menggunakannya .', 'bad manners menjadi kelebihan tersendiri untuk pemain yang bijak menggunakannya .')
# ('gpt_132', 'CMS membuka ruang kreativiti pemain dalam mencipta kandungan permainan .', 'C em ass membuka ruang kreativiti pemain dalam mencipta kandungan permainan .')
# ('gpt_133', 'CPU yang canggih memberikan prestasi grafik yang memukau .', 'C pee you yang canggih memberikan prestasi grafik yang memukau .')
# ('gpt_134', 'Pertarungan CPU versus CPU menarik untuk ditonton dalam permainan sukan elektronik .', 'Pertarungan C pee you versus C pee you menarik untuk ditonton dalam permainan sukan elektronik .')
# ('gpt_135', 'CRPG memberikan nostalgia kepada pemain yang menggemari permainan peranan tradisional .', 'C R pee gee memberikan nostalgia kepada pemain yang menggemari permainan peranan tradisional .')
# ('gpt_136', 'CTF menuntut kerjasama pasukan dan strategi yang baik .', 'kapchur the flag menuntut kerjasama pasukan dan strategi yang baik .')
# ('gpt_137', 'Penggunaan D-pad mempercepatkan respon pemain dalam permainan .', 'Penggunaan dee pad mempercepatkan respon pemain dalam permainan .')
# ('gpt_138', 'DLC mengembangkan kisah dan dunia permainan dengan kandungan baru .', 'dee el C mengembangkan kisah dan dunia permainan dengan kandungan baru .')
# ('gpt_139', 'DPM memainkan peranan penting dalam kejayaan pasukan dalam permainan berpasukan .', 'der mage per mi nit memainkan peranan penting dalam kejayaan pasukan dalam permainan berpasukan .')
# ('gpt_140', 'Sistem B2P adalah model perniagaan yang adil untuk industri permainan .', 'Sistem bee to pee adalah model perniagaan yang adil untuk industri permainan .')
# ('gpt_141', 'BM boleh menjadi penentu kemenangan dalam situasi terdesak .', 'bad manners boleh menjadi penentu kemenangan dalam situasi terdesak .')
# ('gpt_142', 'CMS membuka pintu untuk kreativiti pemain dalam mencipta dunia permainan .', 'C em ass membuka pintu untuk kreativiti pemain dalam mencipta dunia permainan .')
# ('gpt_143', 'CPU yang kuat memberikan pengalaman permainan yang lancar dan menarik .', 'C pee you yang kuat memberikan pengalaman permainan yang lancar dan menarik .')
# ('gpt_144', 'Pertarungan CPU versus CPU memberikan pemandangan yang menarik dalam mode penonton .', 'Pertarungan C pee you versus C pee you memberikan pemandangan yang menarik dalam mode penonton .')
# ('gpt_145', 'CRPG memberikan kedalaman emosi dan strategi kepada pemain .', 'C R pee gee memberikan kedalaman emosi dan strategi kepada pemain .')
# ('gpt_146', 'CTF adalah mode permainan yang menguji kepantasan dan koordinasi pasukan .', 'kapchur the flag adalah mode permainan yang menguji kepantasan dan koordinasi pasukan .')
# ('gpt_147', 'Penggunaan D-pad memastikan pergerakan watak berlaku dengan tepat .', 'Penggunaan dee pad memastikan pergerakan watak berlaku dengan tepat .')
# ('gpt_148', 'DLC membuka peluang untuk pengalaman permainan yang berterusan .', 'dee el C membuka peluang untuk pengalaman permainan yang berterusan .')
# ('gpt_149', 'DPM adalah ukuran prestasi pemain dalam menghadapi musuh dalam permainan .', 'der mage per mi nit adalah ukuran prestasi pemain dalam menghadapi musuh dalam permainan .')
# ('gpt_150', 'DPS atau damage per second adalah ukuran keberkesanan pemain dalam menyebabkan kerosakan kepada musuh .', 'dee pee ass atau darmeage per second adalah ukuran keberkesanan pemain dalam menyebabkan kerosakan kepada musuh .')
# ('gpt_151', 'DRM atau digital rights management melindungi hak cipta dan ketersediaan permainan dalam talian .', 'd gi tal right management atau d gi tal right management melindungi hak cipta dan ketersediaan permainan dalam talian .')
# ('gpt_152', 'Degrees of freedom merujuk kepada kebebasan pergerakan pemain dalam permainan .', 'darjah of freedom merujuk kepada kebebasan pergerakan pemain dalam permainan .')
# ('gpt_153', 'Doom clone adalah permainan yang terinspirasi daripada permainan video Doom yang terkenal .', 'azab klone adalah permainan yang terinspirasi daripada permainan video azab yang terkenal .')
# ('gpt_154', 'ESP cheats extra-sensory perception cheats membolehkan pemain melihat musuh atau objek tersembunyi .', 'E ass pee cheats E ass pee cheats membolehkan pemain melihat musuh atau objek tersembunyi .')
# ('gpt_155', 'Elo hell adalah tahap permainan yang dianggap sukar untuk dinaikkan dalam sistem penarafan permainan .', 'E low hell adalah tahap permainan yang dianggap sukar untuk dinaikkan dalam sistem penarafan permainan .')
# ('gpt_156', 'F sering digunakan sebagai penghormatan kepada pemain yang telah mati dalam permainan .', 'F sering digunakan sebagai penghormatan kepada pemain yang telah mati dalam permainan .')
# ('gpt_157', 'FOV atau field of view adalah sudut yang dapat dilihat oleh pemain dalam permainan .', 'F O vee atau feel of view adalah sudut yang dapat dilihat oleh pemain dalam permainan .')
# ('gpt_158', 'FPS atau frames per second merujuk kepada kadar gambar yang dipaparkan dalam satu saat .', 'F pee ass atau frayme per second merujuk kepada kadar gambar yang dipaparkan dalam satu saat .')
# ('gpt_159', 'FotM atau flavor of the month merujuk kepada strategi atau perkara yang popular pada masa tersebut .', 'flayver of the month atau rasa of the month merujuk kepada strategi atau perkara yang popular pada masa tersebut .')
# ('gpt_160', 'DPS menjadi kritikal dalam mengatasi musuh dengan secepat mungkin .', 'dee pee ass menjadi kritikal dalam mengatasi musuh dengan secepat mungkin .')
# ('gpt_161', 'DRM melindungi hak cipta dan ketersediaan permainan dalam talian .', 'd gi tal right management melindungi hak cipta dan ketersediaan permainan dalam talian .')
# ('gpt_162', 'Degrees of freedom memberikan kebebasan kepada pemain untuk menjelajah dunia permainan .', 'darjah of freedom memberikan kebebasan kepada pemain untuk menjelajah dunia permainan .')
# ('gpt_163', 'Doom clone membawa kembali nostalgia permainan tembak-menembak klasik .', 'azab klone membawa kembali nostalgia permainan tembak menembak klasik .')
# ('gpt_164', 'ESP cheats memberikan kelebihan yang tidak adil kepada pemain yang menggunakannya .', 'E ass pee cheats memberikan kelebihan yang tidak adil kepada pemain yang menggunakannya .')
# ('gpt_165', 'Elo hell boleh menjadi cabaran besar untuk pemain yang ingin meningkatkan taraf mereka .', 'E low hell boleh menjadi cabaran besar untuk pemain yang ingin meningkatkan taraf mereka .')
# ('gpt_166', 'F sebagai tanda penghormatan kepada pemain yang telah menemui nasib malang dalam permainan .', 'F sebagai tanda penghormatan kepada pemain yang telah menemui nasib malang dalam permainan .')
# ('gpt_167', 'FOV mempengaruhi pengalaman visual dan persepsi pemain dalam permainan .', 'F O vee mempengaruhi pengalaman visual dan persepsi pemain dalam permainan .')
# ('gpt_168', 'FPS adalah faktor penting dalam kebolehan reaksi pemain dalam permainan tembak-menembak .', 'F pee ass adalah faktor penting dalam kebolehan reaksi pemain dalam permainan tembak menembak .')
# ('gpt_169', 'FotM sering berubah mengikut perubahan dalam keseimbangan permainan .', 'flayver of the month sering berubah mengikut perubahan dalam keseimbangan permainan .')
# ('gpt_170', 'DPM menjadi kritikal dalam menentukan keberkesanan pasukan dalam pertempuran .', 'der mage per mi nit menjadi kritikal dalam menentukan keberkesanan pasukan dalam pertempuran .')
# ('gpt_171', 'DPS adalah ukuran keberkesanan serangan pemain dalam jangka masa yang singkat .', 'dee pee ass adalah ukuran keberkesanan serangan pemain dalam jangka masa yang singkat .')
# ('gpt_172', 'DRM membantu mencegah penyalinan dan pengedaran haram permainan .', 'd gi tal right management membantu mencegah penyalinan dan pengedaran haram permainan .')
# ('gpt_173', 'Degrees of freedom mempengaruhi kepelbagaian permainan dan kebebasan pemain .', 'darjah of freedom mempengaruhi kepelbagaian permainan dan kebebasan pemain .')
# ('gpt_174', 'Doom clone membawa semangat permainan tembak-menembak klasik ke dalam era moden .', 'azab klone membawa semangat permainan tembak menembak klasik ke dalam era moden .')
# ('gpt_175', 'Elo hell boleh menjadi ujian kesabaran dan kebolehan pemain .', 'E low hell boleh menjadi ujian kesabaran dan kebolehan pemain .')
# ('gpt_176', 'F menjadi simbol penghormatan kepada pemain yang terbunuh dalam permainan .', 'F menjadi simbol penghormatan kepada pemain yang terbunuh dalam permainan .')
# ('gpt_177', 'FOV mempengaruhi cara pemain melihat dan bertindak dalam persekitaran permainan .', 'F O vee mempengaruhi cara pemain melihat dan bertindak dalam persekitaran permainan .')
# ('gpt_178', 'FPS memberikan pengalaman bermain yang lebih lancar dan responsif .', 'F pee ass memberikan pengalaman bermain yang lebih lancar dan responsif .')
# ('gpt_179', 'FotM mencerminkan populariti strategi atau perkara tertentu dalam komuniti permainan .', 'flayver of the month mencerminkan populariti strategi atau perkara tertentu dalam komuniti permainan .')
# ('gpt_180', 'DPM adalah ukuran keberkesanan dalam menyebabkan kerosakan kepada musuh .', 'der mage per mi nit adalah ukuran keberkesanan dalam menyebabkan kerosakan kepada musuh .')
# ('gpt_181', 'DPS menjadi faktor utama dalam keberkesanan pasukan dalam pertempuran .', 'dee pee ass menjadi faktor utama dalam keberkesanan pasukan dalam pertempuran .')
# ('gpt_182', 'DRM melindungi hak cipta dan pendapatan pencipta permainan .', 'd gi tal right management melindungi hak cipta dan pendapatan pencipta permainan .')
# ('gpt_183', 'Degrees of freedom memberikan pengalaman bermain yang lebih dinamik dan serba boleh .', 'darjah of freedom memberikan pengalaman bermain yang lebih dinamik dan serba boleh .')
# ('gpt_184', 'Doom clone membawa kembali rasa nostalgia kepada pemain yang menggemari permainan tembak-menembak klasik .', 'azab klone membawa kembali rasa nostalgia kepada pemain yang menggemari permainan tembak menembak klasik .')
# ('gpt_185', 'ESP cheats memberikan kelebihan tidak adil kepada pemain yang menggunakannya .', 'E ass pee cheats memberikan kelebihan tidak adil kepada pemain yang menggunakannya .')
# ('gpt_186', 'Elo hell boleh menjadi cabaran untuk meningkatkan tahap permainan .', 'E low hell boleh menjadi cabaran untuk meningkatkan tahap permainan .')
# ('gpt_187', 'F sebagai simbol penghormatan dan pengakuan kepada pemain yang terbunuh .', 'F sebagai simbol penghormatan dan pengakuan kepada pemain yang terbunuh .')
# ('gpt_188', 'FOV mempengaruhi persepsi visual dan strategi pemain dalam permainan .', 'F O vee mempengaruhi persepsi visual dan strategi pemain dalam permainan .')
# ('gpt_189', 'FPS adalah faktor utama dalam pengalaman bermain permainan tembak-menembak .', 'F pee ass adalah faktor utama dalam pengalaman bermain permainan tembak menembak .')
# ('gpt_190', 'FotM merujuk kepada strategi atau perkara yang paling popular pada masa itu .', 'flayver of the month merujuk kepada strategi atau perkara yang paling popular pada masa itu .')
# ('gpt_191', 'DPM menjadi penentu utama keberkesanan pemain dalam pertempuran berlarutan .', 'der mage per mi nit menjadi penentu utama keberkesanan pemain dalam pertempuran berlarutan .')
# ('gpt_192', 'DPS adalah ukuran sejauh mana pemain dapat memberikan kerosakan kepada musuh .', 'dee pee ass adalah ukuran sejauh mana pemain dapat memberikan kerosakan kepada musuh .')
# ('gpt_193', 'DRM melindungi hak cipta dan kesahan permainan di pasaran .', 'd gi tal right management melindungi hak cipta dan kesahan permainan di pasaran .')
# ('gpt_194', 'Degrees of freedom memberikan kebebasan pemain untuk meneroka dan bertindak .', 'darjah of freedom memberikan kebebasan pemain untuk meneroka dan bertindak .')
# ('gpt_195', 'Doom clone membawa elemen klasik permainan tembak-menembak ke dalam dunia moden .', 'azab klone membawa elemen klasik permainan tembak menembak ke dalam dunia moden .')
# ('gpt_196', 'GG atau good game adalah ucapan penghargaan kepada lawan selepas permainan selesai .', 'good game atau good game adalah ucapan penghargaan kepada lawan selepas permainan selesai .')
# ('gpt_197', 'GLHF atau good luck , have fun adalah ucapan yang digunakan sebelum permainan bermula untuk menghormati lawan .', 'good luck have fun atau good luck , have fun adalah ucapan yang digunakan sebelum permainan bermula untuk menghormati lawan .')
# ('gpt_198', 'GOAT atau greatest of all time merujuk kepada pemain atau elemen permainan yang dianggap terbaik sepanjang masa .', 'GOAT atau terhebat of all time merujuk kepada pemain atau elemen permainan yang dianggap terbaik sepanjang masa .')
# ('gpt_199', 'GOTY atau game of the year adalah permainan yang diiktiraf sebagai yang terbaik dalam tahun tersebut .', 'came of the yer atau game of the tahun adalah permainan yang diiktiraf sebagai yang terbaik dalam tahun tersebut .')
# ('gpt_200', 'GaaS atau Games as a Service adalah model perniagaan yang melibatkan penyediaan permainan dan kandungan tambahan secara berterusan .', 'games as a service atau Games as a Service adalah model perniagaan yang melibatkan penyediaan permainan dan kandungan tambahan secara berterusan .')
# ('gpt_201', 'Games as a Product Games as a Product merujuk kepada model perniagaan di mana permainan dijual sebagai produk yang lengkap .', 'Games as a produk Games as a produk merujuk kepada model perniagaan di mana permainan dijual sebagai produk yang lengkap .')
# ('gpt_202', 'Git gud adalah ungkapan yang digunakan untuk menasihati pemain untuk meningkatkan kemahiran mereka dalam permainan .', 'kitt good adalah ungkapan yang digunakan untuk menasihati pemain untuk meningkatkan kemahiran mereka dalam permainan .')
# ('gpt_203', 'HOPA atau hidden object puzzle adventure adalah jenis permainan yang menggabungkan elemen cari objek tersembunyi dan teka-teki .', 'hold par atau hidden object puzzle adventure adalah jenis permainan yang menggabungkan elemen cari objek tersembunyi dan teka teki .')
# ('gpt_204', 'Hack vs Hack merujuk kepada pertempuran antara penggodam dalam permainan atau sistem komputer .', 'hack versus hack merujuk kepada pertempuran antara penggodam dalam permainan atau sistem komputer .')
# ('gpt_205', 'Git gud adalah nasihat yang memberitahu pemain untuk meningkatkan kemahiran mereka dalam permainan .', 'kitt good adalah nasihat yang memberitahu pemain untuk meningkatkan kemahiran mereka dalam permainan .')
# ('gpt_206', 'GG adalah cara positif untuk mengakui usaha dan kebolehan lawan dalam permainan .', 'good game adalah cara positif untuk mengakui usaha dan kebolehan lawan dalam permainan .')
# ('gpt_207', 'GLHF menunjukkan semangat sukan yang positif sebelum permainan bermula .', 'good luck have fun menunjukkan semangat sukan yang positif sebelum permainan bermula .')
# ('gpt_208', 'GOAT adalah gelaran yang diberikan kepada pemain atau elemen permainan yang dianggap terhebat .', 'GOAT adalah gelaran yang diberikan kepada pemain atau elemen permainan yang dianggap terhebat .')
# ('gpt_209', 'GOTY adalah kehormatan tertinggi untuk permainan yang memenangi anugerah tersebut .', 'came of the yer adalah kehormatan tertinggi untuk permainan yang memenangi anugerah tersebut .')
# ('gpt_210', 'GaaS mengubah cara permainan diterima dan dipertahankan oleh komuniti pemain .', 'games as a service mengubah cara permainan diterima dan dipertahankan oleh komuniti pemain .')
# ('gpt_211', 'Games as a Product adalah model perniagaan tradisional di mana permainan dijual sebagai produk tunggal .', 'Games as a produk adalah model perniagaan tradisional di mana permainan dijual sebagai produk tunggal .')
# ('gpt_212', 'Git gud adalah peringatan kepada pemain untuk terus berlatih dan meningkatkan kemahiran mereka .', 'kitt good adalah peringatan kepada pemain untuk terus berlatih dan meningkatkan kemahiran mereka .')
# ('gpt_213', 'HOPA adalah permainan yang menarik untuk pencinta teka-teki dan cari objek tersembunyi .', 'hold par adalah permainan yang menarik untuk pencinta teka teki dan cari objek tersembunyi .')
# ('gpt_214', 'Hack vs Hack adalah pertarungan antara penggodam yang menambah keunikan kepada permainan .', 'hack versus hack adalah pertarungan antara penggodam yang menambah keunikan kepada permainan .')
# ('gpt_215', 'GG adalah penghargaan untuk kedua-dua pihak yang bertanding dalam permainan .', 'good game adalah penghargaan untuk kedua dua pihak yang bertanding dalam permainan .')
# ('gpt_216', 'GLHF membawa elemen kesopanan dan hiburan sebelum mula permainan .', 'good luck have fun membawa elemen kesopanan dan hiburan sebelum mula permainan .')
# ('gpt_217', 'GOAT adalah gelaran yang tidak dapat dipandang rendah dalam dunia permainan .', 'GOAT adalah gelaran yang tidak dapat dipandang rendah dalam dunia permainan .')
# ('gpt_218', 'GOTY adalah anugerah yang diidamkan oleh setiap pencipta permainan .', 'came of the yer adalah anugerah yang diidamkan oleh setiap pencipta permainan .')
# ('gpt_219', 'GaaS membolehkan permainan untuk berkembang dan berubah sepanjang masa .', 'games as a service membolehkan permainan untuk berkembang dan berubah sepanjang masa .')
# ('gpt_220', 'Games as a Product menekankan kepada penjualan produk permainan dalam bentuk yang sudah matang .', 'Games as a produk menekankan kepada penjualan produk permainan dalam bentuk yang sudah matang .')
# ('gpt_221', 'Git gud adalah nasihat yang memberikan dorongan kepada pemain untuk sentiasa meningkatkan diri .', 'kitt good adalah nasihat yang memberikan dorongan kepada pemain untuk sentiasa meningkatkan diri .')
# ('gpt_222', 'HOPA adalah genre permainan yang menarik dengan cabaran teka-teki .', 'hold par adalah john ra permainan yang menarik dengan cabaran teka teki .')
# ('gpt_223', 'Hack vs Hack adalah pertempuran di antara pemain yang menggunakan pengetahuan penggodam .', 'hack versus hack adalah pertempuran di antara pemain yang menggunakan pengetahuan penggodam .')
# ('gpt_224', 'GG adalah cara yang baik untuk menamatkan permainan dengan rasa hormat .', 'good game adalah cara yang baik untuk menamatkan permainan dengan rasa hormat .')
# ('gpt_225', 'GLHF mencipta atmosfera yang positif dan berseronok sebelum permainan bermula .', 'good luck have fun mencipta atmosfera yang positif dan berseronok sebelum permainan bermula .')
# ('gpt_226', 'GOAT adalah gelaran yang memberikan penghormatan terhadap pencapaian yang luar biasa .', 'GOAT adalah gelaran yang memberikan penghormatan terhadap pencapaian yang luar biasa .')
# ('gpt_227', 'GOTY adalah kepuasan tertinggi untuk pencipta dan peminat permainan .', 'came of the yer adalah kepuasan tertinggi untuk pencipta dan peminat permainan .')
# ('gpt_228', 'GaaS membuka pintu kepada pelbagai kandungan baru dan kemaskini dalam permainan .', 'games as a service membuka pintu kepada pelbagai kandungan baru dan kemaskini dalam permainan .')
# ('gpt_229', 'Games as a Product mengutamakan penjualan produk yang sempurna dari segi kandungan .', 'Games as a produk mengutamakan penjualan produk yang sempurna dari segi kandungan .')
# ('gpt_230', 'Git gud adalah motto yang menggalakkan semangat untuk terus meningkatkan prestasi .', 'kitt good adalah moto yang menggalakkan semangat untuk terus meningkatkan prestasi .')
# ('gpt_231', 'HOPA menyajikan pengalaman permainan yang mencabar dan menarik .', 'hold par menyajikan pengalaman permainan yang mencabar dan menarik .')
# ('gpt_232', 'Hack vs Hack menambah elemen persaingan unik dalam dunia permainan .', 'hack versus hack menambah elemen persaingan unik dalam dunia permainan .')
# ('gpt_233', 'GG adalah ucapan penutup yang bersopan santun setelah permainan selesai .', 'good game adalah ucapan penutup yang bersopan santun setelah permainan selesai .')
# ('gpt_234', 'GLHF membawa semangat positif kepada permainan kompetitif .', 'good luck have fun membawa semangat positif kepada permainan kompetitif .')
# ('gpt_235', 'GOAT adalah pencapaian yang banyak permainan impikan .', 'GOAT adalah pencapaian yang banyak permainan impikan .')
# ('gpt_236', 'GOTY memberikan pengiktirafan tertinggi kepada permainan yang menonjol dalam tahun tersebut .', 'came of the yer memberikan pengiktirafan tertinggi kepada permainan yang menonjol dalam tahun tersebut .')
# ('gpt_237', 'GaaS membawa model perniagaan yang berterusan kepada industri permainan .', 'games as a service membawa model perniagaan yang berterusan kepada industri permainan .')
# ('gpt_238', 'Games as a Product memberikan perhatian kepada hasil akhir produk permainan .', 'Games as a produk memberikan perhatian kepada hasil akhir produk permainan .')
# ('gpt_239', 'Git gud adalah nasihat yang mencerminkan semangat peningkatan diri .', 'kitt good adalah nasihat yang mencerminkan semangat peningkatan diri .')
# ('gpt_240', 'HOPA menyediakan hiburan yang menarik untuk pencinta permainan teka-teki .', 'hold par menyediakan hiburan yang menarik untuk pencinta permainan teka teki .')
# ('gpt_241', 'Hack vs Hack adalah pertempuran intelektual di dalam dunia permainan .', 'hack versus hack adalah pertempuran intelektual di dalam dunia permainan .')
# ('gpt_242', 'GG adalah ungkapan penghargaan dan rasa hormat terhadap lawan .', 'good game adalah ungkapan penghargaan dan rasa hormat terhadap lawan .')
# ('gpt_243', 'GLHF membawa elemen kesopanan dalam dunia permainan siber .', 'good luck have fun membawa elemen kesopanan dalam dunia permainan siber .')
# ('gpt_244', 'GOAT adalah kepuasan yang diimpikan oleh banyak pemain dan pencipta permainan .', 'GOAT adalah kepuasan yang diimpikan oleh banyak pemain dan pencipta permainan .')
# ('gpt_245', 'GOTY adalah gelaran yang membawa kebanggaan kepada pencipta permainan yang menang .', 'came of the yer adalah gelaran yang membawa kebanggaan kepada pencipta permainan yang menang .')
# ('gpt_246', 'JRPG atau Japanese Role-Playing Game merujuk kepada permainan peranan yang berasal dari Jepun .', 'jay R pee gee atau jepun Role Playing Game merujuk kepada permainan peranan yang berasal dari Jepun .')
# ('gpt_247', 'KDA atau Kill-Death-Assist adalah statistik yang mengukur bilangan pembunuhan , kematian , dan pertolongan pemain dalam permainan .', 'kay dee A atau Kill Death Assist adalah statistik yang mengukur bilangan pembunuhan , kematian , dan pertolongan pemain dalam permainan .')
# ('gpt_248', 'King of the Hill KOTH adalah mod permainan di mana pemain berusaha untuk menguasai kawasan tertentu untuk mendapatkan mata .', 'King of the Hill king of the hill adalah mod permainan di mana pemain berusaha untuk menguasai kawasan tertentu untuk mendapatkan mata .')
# ('gpt_249', 'Konami Code adalah kombinasi pad butang konsol yang terkenal , sering digunakan untuk mendapatkan kelebihan dalam permainan Konami .', 'Konami kod adalah kombinasi pad butang konsol yang terkenal , sering digunakan untuk mendapatkan kelebihan dalam permainan Konami .')
# ('gpt_250', 'LAN party adalah perhimpunan pemain di mana mereka berkumpul secara fizikal untuk bermain permainan video melalui rangkaian tempatan .', 'LAN party adalah perhimpunan pemain di mana mereka berkumpul secara fizikal untuk bermain permainan video melalui rangkaian tempatan .')
# ('gpt_251', 'LFG atau Looking for Group adalah singkatan yang digunakan oleh pemain yang mencari rakan bermain untuk sesi tertentu .', 'looking for group atau Looking for Group adalah singkatan yang digunakan oleh pemain yang mencari rakan bermain untuk sesi tertentu .')
# ('gpt_252', 'LFM atau Looking for More digunakan untuk mencari lebih banyak pemain untuk menyertai sesi permainan atau aktiviti tertentu .', 'looking for more atau Looking for More digunakan untuk mencari lebih banyak pemain untuk menyertai sesi permainan atau aktiviti tertentu .')
# ('gpt_253', "Let's Play LP adalah video atau siri video di mana pemain bermain dan berkongsi pengalaman mereka dengan penonton .", 'letz Play letz play adalah video atau siri video di mana pemain bermain dan berkongsi pengalaman mereka dengan penonton .')
# ('gpt_254', 'MMO atau Massively Multiplayer Online merujuk kepada permainan yang boleh dimainkan secara dalam talian dengan ribuan pemain serentak .', 'em em O atau Massively multi player Online merujuk kepada permainan yang boleh dimainkan secara dalam talian dengan ribuan pemain serentak .')
# ('gpt_255', 'MMORPG atau Massively Multiplayer Online Role-Playing Game adalah permainan peranan dalam talian dengan jumlah pemain yang besar .', 'em em O R pee gee atau Massively multi player Online Role Playing Game adalah permainan peranan dalam talian dengan jumlah pemain yang besar .')
# ('gpt_256', 'JRPG menonjolkan elemen seni dan naratif yang kuat dalam permainan peranan .', 'jay R pee gee menonjolkan elemen seni dan naratif yang kuat dalam permainan peranan .')
# ('gpt_257', 'KDA memberikan pandangan tentang keberkesanan seorang pemain dalam membantu pasukannya atau menentang musuh .', 'kay dee A memberikan pandangan tentang keberkesanan seorang pemain dalam membantu pasukannya atau menentang musuh .')
# ('gpt_258', 'King of the Hill KOTH adalah mod permainan yang menguji taktikal dan kerjasama pasukan .', 'King of the Hill king of the hill adalah mod permainan yang menguji taktikal dan kerjasama pasukan .')
# ('gpt_259', 'Konami Code menjadi ikonik dalam sejarah permainan video dan banyak digunakan dalam permainan Konami .', 'Konami kod menjadi ikonik dalam sejarah permainan video dan banyak digunakan dalam permainan Konami .')
# ('gpt_260', 'LAN party membawa pengalaman sosial dan komuniti kepada pemain dalam talian .', 'LAN party membawa pengalaman sosial dan komuniti kepada pemain dalam talian .')
# ('gpt_261', 'LFG adalah panggilan bagi pemain yang ingin bersama-sama dengan rakan bermain baru .', 'looking for group adalah panggilan bagi pemain yang ingin bersama sama dengan rakan bermain baru .')
# ('gpt_262', 'LFM membolehkan pemain mencari lebih banyak ahli untuk menyertai kelompok permainan .', 'looking for more membolehkan pemain mencari lebih banyak ahli untuk menyertai kelompok permainan .')
# ...
# ('gpt_3510', 'Aku main VR game , macam masuk dalam dunia lain .', 'Aku mein vee R game , macam masuk dalam dunia lain .')
# ('gpt_3511', 'Visual dan bunyi dalam VR memang realistik .', 'Visual dan bunyi dalam vee R memang realistik .')
# ('gpt_3512', 'Aku suka main visual novel , banyak pilihan .', 'Aku suka mein visual novel , banyak pilihan .')
# ('gpt_3513', 'Storytelling dia unik dan menarik .', 'story telling dia unik dan menarik .')
# ('gpt_3514', 'Monitor aku support VRR , takde tearing .', 'memantau aku sokongan verabel refresh rate , takde merobek .')
# ('gpt_3515', 'Lag takde , gameplay jadi lancar .', 'Lag takde , game play jadi lancar .')
# ('gpt_3516', 'Aku suka controls waggle , lebih interaktif .', 'Aku suka controls waggle , lebih interaktif .')
# ('gpt_3517', 'Terasa lebih involved dalam game .', 'Terasa lebih terbabit dalam game .')
# ('gpt_3518', 'Waifu aku dalam game ni comel gila .', 'Waifu aku dalam game ni comel gila .')
# ('gpt_3519', 'Best , design dia memang menawan hati .', 'Best , design dia memang menawan hati .')
# ('gpt_3520', 'Walking sim ni game yang fokus pada exploration dan storytelling .', 'Walking sim ni game yang fokus pada penerokaan dan story telling .')
# ('gpt_3521', 'Aku suka main walking sim , experience immersive .', 'Aku suka mein walking sim , experience immersive .')
# ('gpt_3522', 'Atmosphere dia sangat tenang .', 'atmosfera dia sangat tenang .')
# ('gpt_3523', 'Walking simulator ni game yang menekankan pada pengalaman berjalan dalam cerita .', 'Walking simulator ni game yang menekankan pada pengalaman berjalan dalam cerita .')
# ('gpt_3524', 'Aku tengah main walking simulator , cerita dia deep gila .', 'Aku tengah mein walking simulator , cerita dia mendalam gila .')
# ('gpt_3525', 'Bukan main game biasa , lebih kepada experience .', 'Bukan mein game biasa , lebih kepada experience .')
# ('gpt_3526', 'Walkthrough ni panduan langkah demi langkah untuk complete game .', 'walk true ni panduan langkah demi langkah untuk complete game .')
# ('gpt_3527', 'Aku selalu refer walkthrough kalau stuck dalam game .', 'Aku selalu rujuk walk true kalau tersangkut dalam game .')
# ('gpt_3528', 'Taknak miss apa-apa detail .', 'Taknak miss apa apa terperinci .')
# ('gpt_3529', 'Wall bang ni strategy menembak melalui dinding untuk eliminate lawan .', 'wall ban ni strategy menembak melalui dinding untuk menghapuskan lawan .')
# ('gpt_3530', 'Aku guna wall bang strategy tadi .', 'Aku guna wall ban strategy tadi .')
# ('gpt_3531', 'Bagus tu , unexpected .', 'Bagus tu , tidak dijangka .')
# ('gpt_3532', 'Wall climb dalam game buat gameplay jadi lebih dynamic .', 'wall clam dalam game buat game play jadi lebih dai namic .')
# ('gpt_3533', 'Aku suka game yang ada wall climb , buat explore lebih seru .', 'Aku suka game yang ada wall clam , buat meneroka lebih seru .')
# ('gpt_3534', 'Vertical movement penting .', 'menegak pergerakan penting .')
# ('gpt_3535', 'Wall jump ni skill yang berguna untuk traverse terrain .', 'Wall jum ni skill yang berguna untuk travers terrain .')
# ('gpt_3536', 'Wall jump ni saving grace aku .', 'Wall jum ni penjimatan rahmat aku .')
# ('gpt_3537', 'Aku pun , berguna dalam platformers .', 'Aku pun , berguna dalam platformers .')
# ('gpt_3538', 'Wall run dalam game memberikan feeling parkour yang best .', 'Wall run dalam game memberikan perasaan parkour yang best .')
# ('gpt_3539', 'Wall run dalam game ni addictive gila .', 'Wall run dalam game ni ketagihan gila .')
# ('gpt_3540', 'Macam jadi parkour master .', 'Macam jadi parkour master .')
# ('gpt_3541', 'Wallhack ni cheating tool untuk melihat lawan melalui dinding .', 'war hack ni cheeting alat untuk melihat lawan melalui dinding .')
# ('gpt_3542', 'Aku rasa dia pakai wallhack .', 'Aku rasa dia pakai war hack .')
# ('gpt_3543', 'Report dia lah , tak fair .', 'laporan dia lah , tak feir .')
# ('gpt_3544', 'Wanted level ni level keinginan polis untuk tangkap player dalam game .', 'Wanted level ni level keinginan polis untuk tangkap player dalam game .')
# ('gpt_3545', 'Aku dah naik wanted level .', 'Aku dah naik wanted level .')
# ('gpt_3546', 'Kena elak polis la ni .', 'Kena elak polis la ni .')
# ('gpt_3547', 'Warp zone dalam game adalah shortcut untuk skip ke level lain .', 'Warp zone dalam game adalah pintasan untuk langkau ke level lain .')
# ('gpt_3548', 'Aku jumpa warp zone tadi , skip beberapa level .', 'Aku jumpa warp zone tadi , langkau beberapa level .')
# ('gpt_3549', 'Bestnya , save time .', 'Bestnya , save time .')
# ('gpt_3550', 'Walking sim ni jenis game yang lebih tump focus pada pengembaraan dan cerita .', 'Walking sim ni jenis game yang lebih tump focus pada pengembaraan dan cerita .')
# ('gpt_3551', 'Aku enjoy main walking sim , rasa macam tengah terlibat dalam cerita .', 'Aku nikmati mein walking sim , rasa macam tengah terlibat dalam cerita .')
# ('gpt_3552', 'Atmosfera dia sangat menyentuh hati .', 'Atmosfera dia sangat menyentuh hati .')
# ('gpt_3553', 'Walking simulator ni game yang menekankan betapa pentingnya perjalanan dalam cerita .', 'Walking simulator ni game yang menekankan betapa pentingnya perjalanan dalam cerita .')
# ('gpt_3554', 'Aku tengah main walking simulator , storyline dia buat aku terfikir banyak .', 'Aku tengah mein walking simulator , jalan cerita dia buat aku terfikir banyak .')
# ('gpt_3555', 'Bukan game biasa , tapi pengalaman yang mendalam .', 'Bukan game biasa , tapi pengalaman yang mendalam .')
# ('gpt_3556', 'Walkthrough ni panduan langkah demi langkah untuk habiskan game .', 'walk true ni panduan langkah demi langkah untuk habiskan game .')
# ('gpt_3557', 'Aku selalu baca walkthrough kalau tak tahu nak buat apa dalam game .', 'Aku selalu baca walk true kalau tak tahu nak buat apa dalam game .')
# ('gpt_3558', 'Tak nak lepaskan sebarang rahsia atau detik penting .', 'Tak nak lepaskan sebarang rahsia atau detik penting .')
# ('gpt_3559', 'Wall bang ni cara strategik menembak melalui dinding untuk buang musuh .', 'wall ban ni cara strategik menembak melalui dinding untuk buang musuh .')
# ('gpt_3560', 'Aku guna strategi wall bang tadi .', 'Aku guna strategi wall ban tadi .')
# ('gpt_3561', 'Menarik , lawan tak tahu apa yang hit them .', 'Menarik , lawan tak tahu apa yang hit them .')
# ('gpt_3562', 'Wall climb dalam game buat pergerakan jadi lebih menarik .', 'wall clam dalam game buat pergerakan jadi lebih menarik .')
# ('gpt_3563', 'Aku suka game yang ada kemampuan wall climb , membuatkan game lebih dinamik .', 'Aku suka game yang ada kemampuan wall clam , membuatkan game lebih dinamik .')
# ('gpt_3564', 'Pergerakan vertical memang membuka peluang yang menarik .', 'Pergerakan menegak memang membuka peluang yang menarik .')
# ('gpt_3565', 'Wall jump ni kemahiran yang berguna untuk melompat dari satu dinding ke dinding lain .', 'Wall jum ni kemahiran yang berguna untuk melompat dari satu dinding ke dinding lain .')
# ('gpt_3566', 'Kemahiran wall jump sangat membantu .', 'Kemahiran wall jum sangat membantu .')
# ('gpt_3567', 'Terutamanya dalam game platformer .', 'Terutamanya dalam game platformer .')
# ('gpt_3568', 'Wall run dalam game memberikan perasaan seperti sedang melakukan parkour .', 'Wall run dalam game memberikan perasaan seperti sedang melakukan parkour .')
# ('gpt_3569', 'Rasa macam jadi pakar parkour pulak .', 'Rasa macam jadi pakar parkour pulak .')
# ('gpt_3570', 'Wallhack ni alat penipuan yang digunakan untuk melihat musuh melalui dinding .', 'war hack ni alat penipuan yang digunakan untuk melihat musuh melalui dinding .')
# ('gpt_3571', 'Aku rasa dia guna wallhack .', 'Aku rasa dia guna war hack .')
# ('gpt_3572', 'Report dia , kita nak game yang fair .', 'laporan dia , kita nak game yang feir .')
# ('gpt_3573', 'Wanted level ni tahap keinginan polis untuk menangkap pemain dalam game .', 'Wanted level ni tahap keinginan polis untuk menangkap pemain dalam game .')
# ('gpt_3574', 'Kena pandai elak polis la ni .', 'Kena pandai elak polis la ni .')
# ('gpt_3575', 'Warp zone dalam game adalah pintas untuk terus ke level seterusnya .', 'Warp zone dalam game adalah pintas untuk terus ke level seterusnya .')
# ('gpt_3576', 'Wah , jimat masa betul .', 'Wah , jimat masa betul .')
# ('gpt_3577', 'Ave ni biasanya digunakan sebagai panggilan untuk celebrate achievement dalam game .', 'Ave ni biasanya digunakan sebagai panggilan untuk raikan acheev ment dalam game .')
# ('gpt_3578', 'Ave !', 'Ave !')
# ('gpt_3579', 'Kita menang !', 'Kita menang !')
# ('gpt_3580', 'Best teamwork !', 'Best kerja berpasukan !')
# ('gpt_3581', 'Whale dalam game ni merujuk kepada player yang belanja banyak dalam microtransactions .', 'wheyel dalam game ni merujuk kepada player yang belanja banyak dalam transaksi mikro .')
# ('gpt_3582', 'Dia ni whale , beli skin mahal je .', 'Dia ni wheyel , beli skin mahal je .')
# ('gpt_3583', 'Wow , serious spender .', 'waoh , serius pembeli .')
# ('gpt_3584', 'Whiff ni bila player gagal hit target dalam game .', 'Whiff ni bila player gagal hit target dalam game .')
# ('gpt_3585', 'Aku whiff shot tadi , malu gila .', 'Aku whiff shot tadi , malu gila .')
# ('gpt_3586', 'Relax , everyone whiffs sometimes .', 'santai , semua orang whiff kadang kadang .')
# ('gpt_3587', 'Wipe ni bila seluruh team mati dalam satu round atau encounter .', 'Wipe ni bila seluruh team mati dalam satu round atau encounter .')
# ('gpt_3588', 'Aku tak boleh terima , wipe habis team .', 'Aku tak boleh terima , wipe habis team .')
# ('gpt_3589', "It's okay , next round kita come back .", 'itu okay , seterusnya round kita datang back .')
# ('gpt_3590', 'World dalam game merujuk kepada seluruh environment atau realm dalam game .', 'World dalam game merujuk kepada seluruh environment atau alam dalam game .')
# ('gpt_3591', 'World dalam game ni sangat immersive .', 'World dalam game ni sangat immersive .')
# ('gpt_3592', 'Graphics dia power .', 'Graphics dia power .')
# ('gpt_3593', 'WP ni singkatan untuk Well Played , digunakan sebagai ucapan penghargaan dalam game .', 'dubberliu pee ni singkatan untuk baik dimainkan , digunakan sebagai ucapan penghargaan dalam game .')
# ('gpt_3594', 'WP semua !', 'dubberliu pee semua !')
# ('gpt_3595', 'GG , well played !', 'good game , baik dimainkan !')
# ('gpt_3596', 'Wrapping dalam game merujuk kepada wrapping up atau menyelesaikan sesuatu .', 'Wrapping dalam game merujuk kepada wrapping up atau menyelesaikan sesuatu .')
# ('gpt_3597', 'Aku tengah wrapping up quest ni .', 'Aku tengah wrapping up quest ni .')
# ('gpt_3598', 'Okay , kita nak proceed ke next area .', 'Okay , kita nak meneruskan ke seterusnya a rea .')
# ('gpt_3599', 'Zerging ni strategi di mana player menyerang dengan jumlah besar secara serentak .', 'Zerging ni strategi di mana player menyerang dengan jumlah besar secara serentak .')
# ('gpt_3600', 'Lawan kita zerging , kena prepare .', 'Lawan kita zerging , kena prepare .')
# ('gpt_3601', 'Focus fire satu-satu .', 'Focus api satu satu .')
# ('gpt_3602', 'Zero-day patch ni patch yang dikeluarkan segera untuk resolve security issues .', 'Zero day patch ni patch yang dikeluarkan segera untuk lerai keselamatan isu .')
# ('gpt_3603', 'Ada zero-day patch keluar , kena update cepat .', 'Ada zero day patch keluar , kena kemas kini cepat .')
# ('gpt_3604', 'Security first , better safe than sorry .', 'keselamatan first , lebih baik safe daripada sorry .')
# ('gpt_3605', 'Zero-player game ni game yang berjalan sendiri tanpa interaksi player .', 'Zero player game ni game yang berjalan sendiri tanpa interaksi player .')
# ('gpt_3606', 'Aku tengah main zero-player game .', 'Aku tengah mein zero player game .')
# ('gpt_3607', 'Serious ?', 'serius ?')
# ('gpt_3608', 'Macam mana game tu berjalan ?', 'Macam mana game tu berjalan ?')
# ('gpt_3609', 'Zone dalam game merujuk kepada kawasan atau wilayah tertentu dalam map .', 'Zone dalam game merujuk kepada kawasan atau wilayah tertentu dalam map .')
# ('gpt_3610', 'Kita nak control middle zone .', 'Kita nak control tengah zone .')
# ('gpt_3611', 'Okay , aku cover left zone .', 'Okay , aku cover ditinggalkan zone .')
# ('gpt_3612', 'Zoning dalam game adalah strategy untuk control dan secure kawasan tertentu .', 'Zoning dalam game adalah strategy untuk control dan selamat kawasan tertentu .')
# ('gpt_3613', 'Aku tengah zoning , jaga mid point .', 'Aku tengah zoning , penjaga mid point .')
# ('gpt_3614', 'Roger , aku cover flank .', 'penyangak , aku cover flank .')
# ('gpt_3615', 'Ave ni selalunya digunakan sebagai sorakan untuk menyambut pencapaian hebat dalam game .', 'Ave ni selalunya digunakan sebagai sorakan untuk menyambut pencapaian hebat dalam game .')
# ('gpt_3616', 'Kita menang lagi !', 'Kita menang lagi !')
# ('gpt_3617', 'Team kita memang hebat !', 'Team kita memang hebat !')
# ('gpt_3618', 'Whale dalam game ni player yang suka menghabiskan banyak wang dalam microtransactions .', 'wheyel dalam game ni player yang suka menghabiskan banyak wang dalam transaksi mikro .')
# ('gpt_3619', 'Dia ni whale , beli item mahal je .', 'Dia ni wheyel , beli i tem mahal je .')
# ('gpt_3620', 'Serious spender , tak main-main .', 'serius pembeli , tak mein main .')
# ('gpt_3621', 'Whiff ni bila player gagal mengenai musuh dalam game .', 'Whiff ni bila player gagal mengenai musuh dalam game .')
# ('gpt_3622', 'Aku whiff tadi , malu betul .', 'Aku whiff tadi , malu betul .')
# ('gpt_3623', 'Chill , semua orang ada off days .', 'sejuk , semua orang ada off hari .')
# ('gpt_3624', 'Wipe ni bila seluruh pasukan mati dalam satu ronda atau misi .', 'Wipe ni bila seluruh pasukan mati dalam satu ronda atau misi .')
# ('gpt_3625', "It's okay , kita bounce back next round .", 'itu okay , kita lantunan back seterusnya round .')
# ('gpt_3626', 'World dalam game merujuk kepada seluruh persekitaran atau dunia dalam game .', 'World dalam game merujuk kepada seluruh persekitaran atau dunia dalam game .')
# ('gpt_3627', 'World dalam game ni sangat realistik .', 'World dalam game ni sangat realistik .')
# ('gpt_3628', 'Grafik dia memang impressive .', 'Grafik dia memang mengagumkan .')
# ('gpt_3629', 'WP ni singkatan untuk Well Played , digunakan sebagai tanda penghargaan dalam game .', 'dubberliu pee ni singkatan untuk baik dimainkan , digunakan sebagai tanda penghargaan dalam game .')
# ('gpt_3630', 'Wrapping dalam game merujuk kepada menyelesaikan sesuatu atau menutup sesuatu .', 'Wrapping dalam game merujuk kepada menyelesaikan sesuatu atau menutup sesuatu .')
# ('gpt_3631', 'Aku tengah wrapping up misi ni .', 'Aku tengah wrapping up misi ni .')
# ('gpt_3632', 'Okay , kita proceed ke stage seterusnya .', 'Okay , kita meneruskan ke stage seterusnya .')
# ('gpt_3633', 'Zerging ni strategi di mana player menyerang dengan jumlah yang besar serentak .', 'Zerging ni strategi di mana player menyerang dengan jumlah yang besar serentak .')
# ('gpt_3634', 'Lawan kita zerging , kena bersiap .', 'Lawan kita zerging , kena bersiap .')
# ('gpt_3635', 'Focus fire satu-satu , jangan panic .', 'Focus api satu satu , jangan panik .')
# ('gpt_3636', 'Zero-day patch ni patch yang dikeluarkan segera untuk atasi masalah keselamatan .', 'Zero day patch ni patch yang dikeluarkan segera untuk atasi masalah keselamatan .')
# ('gpt_3637', 'Ada zero-day patch baru , kena update cepat .', 'Ada zero day patch baru , kena kemas kini cepat .')
# ('gpt_3638', 'Zero-player game ni game yang berjalan sendiri tanpa campur tangan player .', 'Zero player game ni game yang berjalan sendiri tanpa campur tangan player .')
# ('gpt_3639', 'Aku main zero-player game ni .', 'Aku mein zero player game ni .')
# ('gpt_3640', 'Serius ?', 'Serius ?')
# ('gpt_3641', 'Macam mana gameplay dia ?', 'Macam mana game play dia ?')
# ('gpt_3642', 'Zone dalam game merujuk kepada kawasan atau wilayah tertentu dalam peta .', 'Zone dalam game merujuk kepada kawasan atau wilayah tertentu dalam peta .')
# ('gpt_3643', 'Okey , aku cover left zone .', 'Okey , aku cover ditinggalkan zone .')
# ('gpt_3644', 'Zoning dalam game adalah strategi untuk kawal dan secure kawasan tertentu .', 'Zoning dalam game adalah strategi untuk kawal dan selamat kawasan tertentu .')
# ('gpt_3645', 'Aku cover flank , kita kena maintain control .', 'Aku cover flank , kita kena mengekalkan control .')

# %% [markdown]
# # 6. &nbsp;&nbsp; [Generate Audio for GPT Corpus](#home) <a id='gen_audio_gpt'></a>
#
# Generate audio for 3646 Malay gaming transcripts that are generated by ChatGPT via Malaya VITS model. Note that:
#
# 1. Batch processing is implemented to prevent memory overflow.
# 2. Audio are saved in `gpt/wav` folder under `gaming` folder.
# 2. Text manifest `gpt.txt` is generated and saved in `gpt` folder.

# %%
# Generate audio for GPT corpus in batches
df_gpt = pd.read_csv(cfg.paths.gpt_csv_path)
gen_gpt_audio(df_gpt, "norm_gpt", cfg.paths.gpt_dir, batch_size=100)

# %% [markdown]
# # 6.1 &nbsp;&nbsp; [Generate Text Manifest](#home) <a id='gen_gpt_txt'></a>

# %%
# Generate text manifest for all phoneme sets
# df_gpt = pd.read_csv(cfg.paths.gpt_csv_path)
gen_filelist(df_gpt, cfg.paths.gaming_dir, "gpt", "norm_gpt")
# Out:
# [['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_0.wav',
#   'Dengan mendapat one up , saya boleh teruskan permainan ini tanpa kehilangan nyawa .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_1.wav',
#   'Grafik sixteen beat memberikan sentuhan nostalgia yang unik pada permainan ini .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_2.wav',
#   'Saya berjaya melakukan One C C pada permainan arked lama semalam !'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_3.wav',
#   'Pertarungan one versus one itu benar benar mencabar kemahiran permainan saya .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_4.wav',
#   'Grafik two point five dee memberikan dimensi yang menarik kepada permainan ini .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_5.wav',
#   'Suasana retro terasa apabila bermain dengan grafik two dee yang klasik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_6.wav',
#   'Peningkatan kepada thirty two beat membawa permainan ini ke tahap visual yang baru .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_7.wav',
#   'Gerakan three sixty no scope memerlukan ketepatan dan kecepatan yang tinggi .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_8.wav',
#   'Penggunaan grafik three dee memberikan pengalaman permainan yang lebih hidup .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_9.wav',
#   'Kesemua butiran jelas terlihat pada resolusi four kay ini .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_10.wav',
#   'Saya tidak dapat melepaskan permainan ini dengan grafik two dee yang indah .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_11.wav',
#   'Keupayaan untuk bertarung one versus one dengan rakan membawa keseronokan yang tersendiri .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_12.wav',
#   'Pengalaman two point five dee grafik membuatkan permainan ini terasa unik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_13.wav',
#   'Kesemua warna dan animasi pada grafik sixteen beat ini sangat memukau .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_14.wav',
#   'Saya selalu mencuba melakukan three sixty no scope ketika dalam pertempuran sengit .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_15.wav',
#   'Dengan teknologi thirty two beat , permainan ini kelihatan lebih realistik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_16.wav',
#   'Keunikan two dee grafik memberikan rasa nostalgia yang mendalam .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_17.wav',
#   'Pertarungan one versus one selalu menjadi ujian sebenar kemahiran permainan saya .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_18.wav',
#   'Resolusi four kay memberikan ketajaman visual yang tidak dapat dipercayai .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_19.wav',
#   'Saya sentiasa kagum dengan kecantikan grafik three dee dalam permainan ini .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_20.wav',
#   'Peningkatan kepada sixteen beat memberikan permainan ini corak yang menarik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_21.wav',
#   'Mencapai One C C bukanlah perkara mudah , tetapi saya berjaya !'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_22.wav',
#   'Pertarungan one versus one ini seakan akan menguji kebolehan sebenar saya .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_23.wav',
#   'Grafik two point five dee memberikan kedalaman visual yang hebat pada permainan ini .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_24.wav',
#   'Keindahan grafik two dee ini benar benar menawan hati pemain .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_25.wav',
#   'Dengan teknologi thirty two beat , permainan ini tampak lebih canggih .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_26.wav',
#   'three sixty no scope selalu menjadi jurus kegemaran saya dalam permainan tembak menembak .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_27.wav',
#   'Grafik three dee membuatkan dunia permainan ini kelihatan hidup .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_28.wav',
#   'Resolusi four kay memberikan kejelasan yang memukau pada setiap adegan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_29.wav',
#   'Saya suka permainan ini kerana grafik two dee yang membawa kembali kenangan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_30.wav',
#   'Pertarungan one versus one ini sentiasa mengejutkan dengan strategi yang berbeza .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_31.wav',
#   'Grafik sixteen beat memberikan sentuhan retro yang tidak dapat dipadankan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_32.wav',
#   'Saya ingin mencuba melakukan three sixty no scope dalam pertempuran seterusnya .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_33.wav',
#   'Penggunaan three dee grafik menjadikan permainan ini lebih menghiburkan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_34.wav',
#   'two point five dee grafik memberikan elemen visual yang menarik dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_35.wav',
#   'Saya teruja dengan kualiti grafik two dee pada permainan ini .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_36.wav',
#   'One C C bukanlah perkara mudah , tetapi kepuasan apabila berjaya adalah luar biasa .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_37.wav',
#   'Kejelasan four kay resolution menjadikan setiap butiran tampak lebih hidup .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_38.wav',
#   'Saya sentiasa terpesona dengan keunikan grafik three dee dalam permainan ini .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_39.wav',
#   'Pertarungan one versus one selalu membawa perasaan ketegangan yang menyeronokkan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_40.wav',
#   'Saya suka bagaimana grafik two point five dee memberikan dimensi tambahan pada permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_41.wav',
#   'Resolusi sixteen beat memberikan perasaan klasik yang tidak dapat dilupakan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_42.wav',
#   'Melakukan three sixty no scope memerlukan latihan dan ketepatan yang tinggi .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_43.wav',
#   'Grafik three dee ini membuatkan permainan ini terasa seperti dunia yang nyata .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_44.wav',
#   'two dee grafik memberikan sentuhan visual yang bersahaja pada permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_45.wav',
#   'Kejelasan thirty two beat memberikan permainan ini penampilan yang lebih moden .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_46.wav',
#   'Saya sentiasa mencuba bertarung one versus one dengan pemain pemain terbaik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_47.wav',
#   'Resolusi four kay ini membuatkan permainan ini kelihatan sungguh mengagumkan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_48.wav',
#   'Pengalaman three dee grafik membawa permainan ini ke tahap seterusnya .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_49.wav',
#   'Grafik two dee yang cantik membuatkan permainan ini begitu menarik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_50.wav',
#   'Resolusi eg kay memberikan kejelasan visual yang luar biasa pada permainan ini .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_51.wav',
#   'triple A menunjukkan kualiti permainan yang paling tinggi dan berkualiti tinggi .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_52.wav',
#   'Saya terpaksa A F kay sebentar , tetapi akan kembali segera untuk terus bermain .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_53.wav',
#   'Pengalaman bermain action R pee gee ini begitu mendalam dan menarik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_54.wav',
#   'Anti Aim membantu saya mengelakkan serangan lawan dengan lebih efektif .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_55.wav',
#   'a rea of effect A O E serangan ini benar benar hebat dalam mengatasi musuh bergerombol .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_56.wav',
#   'bee hopping memberikan kelebihan mobiliti yang besar dalam permainan ini .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_57.wav',
#   'Saya suka bagaimana resolusi eg kay ini membuatkan setiap butiran terlihat lebih hidup .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_58.wav',
#   'Permainan triple A ini benar benar mengagumkan dengan grafik yang hebat .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_59.wav',
#   'Walaupun A F kay sebentar , saya masih mempunyai hasrat untuk memenangi permainan ini .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_60.wav',
#   'Saya suka permainan action R pee gee kerana berbagai bagai pilihan strategi .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_61.wav',
#   'Anti Aim membantu saya mengelakkan pihak lawan dengan lebih licin .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_62.wav',
#   'A O E serangan ini membawa kesan yang besar kepada kumpulan musuh .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_63.wav',
#   'bee hopping memberikan elemen kejutan dan kecepatan dalam permainan ini .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_64.wav',
#   'Kualiti grafik triple A ini menjadikan permainan ini berada di tahap tertinggi .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_65.wav',
#   'Resolusi eg kay ini membenamkan saya sepenuhnya dalam dunia permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_66.wav',
#   'Sementara A F kay , saya merancang strategi untuk mendominasi permainan ini .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_67.wav',
#   'action R pee gee ini benar benar menguji kemahiran taktikal saya .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_68.wav',
#   'Anti Aim membolehkan saya mengalahkan musuh dengan lebih cekap .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_69.wav',
#   'A O E serangan ini memberikan impak yang besar pada medan perang .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_70.wav',
#   'bee hopping memberikan kelebihan ketika bergerak dalam medan pertempuran .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_71.wav',
#   'Saya tidak boleh lepas dari pengalaman permainan dengan resolusi eg kay ini .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_72.wav',
#   'Permainan triple A ini memenuhi semua jangkaan saya untuk sebuah permainan berkualiti .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_73.wav',
#   'Saya kembali selepas A F kay dengan semangat yang lebih kuat untuk menang .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_74.wav',
#   'action R pee gee ini menawarkan pengalaman bermain yang sangat seronok .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_75.wav',
#   'Teknik Anti Aim ini benar benar memenangi pertarungan dengan lebih bijak .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_76.wav',
#   'A O E serangan ini mencipta kacau dalam barisan musuh .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_77.wav',
#   'bee hopping memberikan perasaan kebebasan dalam pergerakan saya .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_78.wav',
#   'Resolusi eg kay memberikan permainan ini dimensi visual yang hebat .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_79.wav',
#   'triple A permainan ini memanggil pemain pemain terbaik dari seluruh dunia .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_80.wav',
#   'Saya terpaksa A F kay sebentar untuk urusan kecemasan , tetapi akan kembali segera .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_81.wav',
#   'action R pee gee ini menawarkan peluang untuk meneroka dunia fantastik yang besar .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_82.wav',
#   'Anti Aim membantu saya menjadi lebih sulit sasaran dalam pertempuran .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_83.wav',
#   'A O E serangan ini memusnahkan musuh dalam jumlah besar sekaligus .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_84.wav',
#   'bee hopping memberikan kelebihan taktikal yang besar pada permainan ini .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_85.wav',
#   'Resolusi eg kay ini menjadikan setiap detik permainan sungguh menakjubkan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_86.wav',
#   'Saya selalu terpesona dengan kualiti triple A pada permainan ini .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_87.wav',
#   'Sementara A F kay , saya memikirkan strategi untuk menangkap pihak lawan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_88.wav',
#   'action R pee gee ini benar benar menguji kemahiran dan kepandaian saya .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_89.wav',
#   'Anti Aim membantu saya keluar dari situasi yang berbahaya dengan lebih cekap .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_90.wav',
#   'A O E serangan ini memberikan kemenangan besar dalam pertempuran .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_91.wav',
#   'bee hopping memberikan elemen kejutan yang menyeronokkan dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_92.wav',
#   'Resolusi eg kay ini menjadikan setiap rincian permainan sangat jelas .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_93.wav',
#   'triple A permainan ini benar benar memikat hati pemain dengan kualiti terbaik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_94.wav',
#   'A F kay sebentar untuk membuat persiapan sebelum perlawanan yang sengit .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_95.wav',
#   'action R pee gee ini membawa saya ke dalam dunia fantasi yang tidak dapat dipercayai .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_96.wav',
#   'Anti Aim membolehkan saya menguasai kawalan pertempuran dengan lebih baik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_97.wav',
#   'A O E serangan ini memberikan kelebihan strategik dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_98.wav',
#   'bee hopping membuat pergerakan saya lebih pantas dan taktikal .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_99.wav',
#   'Resolusi eg kay ini menjadikan setiap momen dalam permainan ini sangat menarik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_100.wav',
#   'Pembelian satu kali bee to pee memberikan akses sepenuhnya ke permainan ini tanpa sebarang langganan bulan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_101.wav',
#   'bad manners atau badan menggulung memberikan kelebihan taktikal dalam permainan ini .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_102.wav',
#   'Sistem Pengurusan Konten C em ass membolehkan pemain berkongsi dan mencipta kandungan mereka sendiri .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_103.wav',
#   'C pee you atau unit pemprosesan pusat adalah jantung utama dalam sistem komputer gaming .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_104.wav',
#   'Pertarungan antara C pee you versus C pee you menunjukkan kebolehan kecerdasan buatan dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_105.wav',
#   'C R pee gee atau permainan peranan bergaya klasik memberikan pengalaman bermain yang mendalam .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_106.wav',
#   'kapchur the Flag kapchur the flag merupakan satu mode permainan yang menguji taktikal dan kerjasama pasukan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_107.wav',
#   'dee pad atau dai rectional pad memudahkan pemain untuk menggerakkan watak dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_108.wav',
#   'Kandungan Muat Turun dee el C memberikan pengalaman permainan yang diperbaharui dengan kandungan baru .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_109.wav',
#   'der mage per mi nit atau darmeage per minit mengukur jumlah kerosakan yang boleh dihasilkan oleh pemain dalam satu minit .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_110.wav',
#   'Sistem bee to pee memberikan keadilan kepada semua pemain tanpa perlu berlangganan bulan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_111.wav',
#   'bad manners adalah strategi yang berguna untuk menangani keadaan tertentu dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_112.wav',
#   'C em ass membolehkan pemain menjadi pencipta kandungan dalam dunia permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_113.wav',
#   'C pee you yang cekap memberikan prestasi yang tinggi dalam permainan intensif grafik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_114.wav',
#   'Pertarungan C pee you versus C pee you memberikan pandangan kepada kecerdasan buatan dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_115.wav',
#   'C R pee gee menyajikan cerita dan pengalaman bermain yang mendalam kepada pemain .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_116.wav',
#   'kapchur the flag memerlukan kerjasama pasukan untuk mencapai objektif permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_117.wav',
#   'Penggunaan dee pad memudahkan navigasi dalam dunia permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_118.wav',
#   'dee el C memberikan kepelbagaian kandungan untuk mengekalkan keseronokan permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_119.wav',
#   'der mage per mi nit adalah ukuran keberkesanan pemain dalam menyebabkan kerosakan kepada musuh .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_120.wav',
#   'Sistem bee to pee menjadikan permainan lebih mudah diakses oleh semua pemain .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_121.wav',
#   'bad manners menjadi strategi yang penting dalam pertempuran sengit .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_122.wav',
#   'C em ass memberikan kebebasan kepada pemain untuk berkreasi dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_123.wav',
#   'C pee you yang cepat meningkatkan prestasi permainan secara keseluruhan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_124.wav',
#   'Pertarungan C pee you versus C pee you memberikan simulasi yang menarik untuk ditonton .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_125.wav',
#   'C R pee gee memadukan unsur permainan peranan klasik dengan teknologi terkini .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_126.wav',
#   'kapchur the flag menguji kepantasan taktikal dan kerjasama antara pemain .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_127.wav',
#   'Penggunaan dee pad memudahkan pemain untuk membuat keputusan dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_128.wav',
#   'dee el C memberikan nilai tambah kepada pengalaman permainan yang sedia ada .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_129.wav',
#   'der mage per mi nit adalah faktor penting dalam menentukan keberkesanan serangan pemain .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_130.wav',
#   'Sistem bee to pee memberikan alternatif yang adil untuk pemain .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_131.wav',
#   'bad manners menjadi kelebihan tersendiri untuk pemain yang bijak menggunakannya .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_132.wav',
#   'C em ass membuka ruang kreativiti pemain dalam mencipta kandungan permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_133.wav',
#   'C pee you yang canggih memberikan prestasi grafik yang memukau .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_134.wav',
#   'Pertarungan C pee you versus C pee you menarik untuk ditonton dalam permainan sukan elektronik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_135.wav',
#   'C R pee gee memberikan nostalgia kepada pemain yang menggemari permainan peranan tradisional .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_136.wav',
#   'kapchur the flag menuntut kerjasama pasukan dan strategi yang baik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_137.wav',
#   'Penggunaan dee pad mempercepatkan respon pemain dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_138.wav',
#   'dee el C mengembangkan kisah dan dunia permainan dengan kandungan baru .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_139.wav',
#   'der mage per mi nit memainkan peranan penting dalam kejayaan pasukan dalam permainan berpasukan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_140.wav',
#   'Sistem bee to pee adalah model perniagaan yang adil untuk industri permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_141.wav',
#   'bad manners boleh menjadi penentu kemenangan dalam situasi terdesak .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_142.wav',
#   'C em ass membuka pintu untuk kreativiti pemain dalam mencipta dunia permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_143.wav',
#   'C pee you yang kuat memberikan pengalaman permainan yang lancar dan menarik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_144.wav',
#   'Pertarungan C pee you versus C pee you memberikan pemandangan yang menarik dalam mode penonton .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_145.wav',
#   'C R pee gee memberikan kedalaman emosi dan strategi kepada pemain .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_146.wav',
#   'kapchur the flag adalah mode permainan yang menguji kepantasan dan koordinasi pasukan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_147.wav',
#   'Penggunaan dee pad memastikan pergerakan watak berlaku dengan tepat .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_148.wav',
#   'dee el C membuka peluang untuk pengalaman permainan yang berterusan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_149.wav',
#   'der mage per mi nit adalah ukuran prestasi pemain dalam menghadapi musuh dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_150.wav',
#   'dee pee ass atau darmeage per second adalah ukuran keberkesanan pemain dalam menyebabkan kerosakan kepada musuh .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_151.wav',
#   'd gi tal right management atau d gi tal right management melindungi hak cipta dan ketersediaan permainan dalam talian .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_152.wav',
#   'darjah of freedom merujuk kepada kebebasan pergerakan pemain dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_153.wav',
#   'azab klone adalah permainan yang terinspirasi daripada permainan video azab yang terkenal .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_154.wav',
#   'E ass pee cheats E ass pee cheats membolehkan pemain melihat musuh atau objek tersembunyi .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_155.wav',
#   'E low hell adalah tahap permainan yang dianggap sukar untuk dinaikkan dalam sistem penarafan permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_156.wav',
#   'F sering digunakan sebagai penghormatan kepada pemain yang telah mati dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_157.wav',
#   'F O vee atau feel of view adalah sudut yang dapat dilihat oleh pemain dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_158.wav',
#   'F pee ass atau frayme per second merujuk kepada kadar gambar yang dipaparkan dalam satu saat .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_159.wav',
#   'flayver of the month atau rasa of the month merujuk kepada strategi atau perkara yang popular pada masa tersebut .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_160.wav',
#   'dee pee ass menjadi kritikal dalam mengatasi musuh dengan secepat mungkin .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_161.wav',
#   'd gi tal right management melindungi hak cipta dan ketersediaan permainan dalam talian .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_162.wav',
#   'darjah of freedom memberikan kebebasan kepada pemain untuk menjelajah dunia permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_163.wav',
#   'azab klone membawa kembali nostalgia permainan tembak menembak klasik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_164.wav',
#   'E ass pee cheats memberikan kelebihan yang tidak adil kepada pemain yang menggunakannya .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_165.wav',
#   'E low hell boleh menjadi cabaran besar untuk pemain yang ingin meningkatkan taraf mereka .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_166.wav',
#   'F sebagai tanda penghormatan kepada pemain yang telah menemui nasib malang dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_167.wav',
#   'F O vee mempengaruhi pengalaman visual dan persepsi pemain dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_168.wav',
#   'F pee ass adalah faktor penting dalam kebolehan reaksi pemain dalam permainan tembak menembak .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_169.wav',
#   'flayver of the month sering berubah mengikut perubahan dalam keseimbangan permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_170.wav',
#   'der mage per mi nit menjadi kritikal dalam menentukan keberkesanan pasukan dalam pertempuran .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_171.wav',
#   'dee pee ass adalah ukuran keberkesanan serangan pemain dalam jangka masa yang singkat .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_172.wav',
#   'd gi tal right management membantu mencegah penyalinan dan pengedaran haram permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_173.wav',
#   'darjah of freedom mempengaruhi kepelbagaian permainan dan kebebasan pemain .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_174.wav',
#   'azab klone membawa semangat permainan tembak menembak klasik ke dalam era moden .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_175.wav',
#   'E low hell boleh menjadi ujian kesabaran dan kebolehan pemain .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_176.wav',
#   'F menjadi simbol penghormatan kepada pemain yang terbunuh dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_177.wav',
#   'F O vee mempengaruhi cara pemain melihat dan bertindak dalam persekitaran permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_178.wav',
#   'F pee ass memberikan pengalaman bermain yang lebih lancar dan responsif .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_179.wav',
#   'flayver of the month mencerminkan populariti strategi atau perkara tertentu dalam komuniti permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_180.wav',
#   'der mage per mi nit adalah ukuran keberkesanan dalam menyebabkan kerosakan kepada musuh .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_181.wav',
#   'dee pee ass menjadi faktor utama dalam keberkesanan pasukan dalam pertempuran .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_182.wav',
#   'd gi tal right management melindungi hak cipta dan pendapatan pencipta permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_183.wav',
#   'darjah of freedom memberikan pengalaman bermain yang lebih dinamik dan serba boleh .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_184.wav',
#   'azab klone membawa kembali rasa nostalgia kepada pemain yang menggemari permainan tembak menembak klasik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_185.wav',
#   'E ass pee cheats memberikan kelebihan tidak adil kepada pemain yang menggunakannya .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_186.wav',
#   'E low hell boleh menjadi cabaran untuk meningkatkan tahap permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_187.wav',
#   'F sebagai simbol penghormatan dan pengakuan kepada pemain yang terbunuh .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_188.wav',
#   'F O vee mempengaruhi persepsi visual dan strategi pemain dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_189.wav',
#   'F pee ass adalah faktor utama dalam pengalaman bermain permainan tembak menembak .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_190.wav',
#   'flayver of the month merujuk kepada strategi atau perkara yang paling popular pada masa itu .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_191.wav',
#   'der mage per mi nit menjadi penentu utama keberkesanan pemain dalam pertempuran berlarutan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_192.wav',
#   'dee pee ass adalah ukuran sejauh mana pemain dapat memberikan kerosakan kepada musuh .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_193.wav',
#   'd gi tal right management melindungi hak cipta dan kesahan permainan di pasaran .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_194.wav',
#   'darjah of freedom memberikan kebebasan pemain untuk meneroka dan bertindak .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_195.wav',
#   'azab klone membawa elemen klasik permainan tembak menembak ke dalam dunia moden .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_196.wav',
#   'good game atau good game adalah ucapan penghargaan kepada lawan selepas permainan selesai .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_197.wav',
#   'good luck have fun atau good luck , have fun adalah ucapan yang digunakan sebelum permainan bermula untuk menghormati lawan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_198.wav',
#   'GOAT atau terhebat of all time merujuk kepada pemain atau elemen permainan yang dianggap terbaik sepanjang masa .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_199.wav',
#   'came of the yer atau game of the tahun adalah permainan yang diiktiraf sebagai yang terbaik dalam tahun tersebut .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_200.wav',
#   'games as a service atau Games as a Service adalah model perniagaan yang melibatkan penyediaan permainan dan kandungan tambahan secara berterusan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_201.wav',
#   'Games as a produk Games as a produk merujuk kepada model perniagaan di mana permainan dijual sebagai produk yang lengkap .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_202.wav',
#   'kitt good adalah ungkapan yang digunakan untuk menasihati pemain untuk meningkatkan kemahiran mereka dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_203.wav',
#   'hold par atau hidden object puzzle adventure adalah jenis permainan yang menggabungkan elemen cari objek tersembunyi dan teka teki .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_204.wav',
#   'hack versus hack merujuk kepada pertempuran antara penggodam dalam permainan atau sistem komputer .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_205.wav',
#   'kitt good adalah nasihat yang memberitahu pemain untuk meningkatkan kemahiran mereka dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_206.wav',
#   'good game adalah cara positif untuk mengakui usaha dan kebolehan lawan dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_207.wav',
#   'good luck have fun menunjukkan semangat sukan yang positif sebelum permainan bermula .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_208.wav',
#   'GOAT adalah gelaran yang diberikan kepada pemain atau elemen permainan yang dianggap terhebat .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_209.wav',
#   'came of the yer adalah kehormatan tertinggi untuk permainan yang memenangi anugerah tersebut .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_210.wav',
#   'games as a service mengubah cara permainan diterima dan dipertahankan oleh komuniti pemain .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_211.wav',
#   'Games as a produk adalah model perniagaan tradisional di mana permainan dijual sebagai produk tunggal .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_212.wav',
#   'kitt good adalah peringatan kepada pemain untuk terus berlatih dan meningkatkan kemahiran mereka .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_213.wav',
#   'hold par adalah permainan yang menarik untuk pencinta teka teki dan cari objek tersembunyi .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_214.wav',
#   'hack versus hack adalah pertarungan antara penggodam yang menambah keunikan kepada permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_215.wav',
#   'good game adalah penghargaan untuk kedua dua pihak yang bertanding dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_216.wav',
#   'good luck have fun membawa elemen kesopanan dan hiburan sebelum mula permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_217.wav',
#   'GOAT adalah gelaran yang tidak dapat dipandang rendah dalam dunia permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_218.wav',
#   'came of the yer adalah anugerah yang diidamkan oleh setiap pencipta permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_219.wav',
#   'games as a service membolehkan permainan untuk berkembang dan berubah sepanjang masa .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_220.wav',
#   'Games as a produk menekankan kepada penjualan produk permainan dalam bentuk yang sudah matang .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_221.wav',
#   'kitt good adalah nasihat yang memberikan dorongan kepada pemain untuk sentiasa meningkatkan diri .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_222.wav',
#   'hold par adalah john ra permainan yang menarik dengan cabaran teka teki .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_223.wav',
#   'hack versus hack adalah pertempuran di antara pemain yang menggunakan pengetahuan penggodam .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_224.wav',
#   'good game adalah cara yang baik untuk menamatkan permainan dengan rasa hormat .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_225.wav',
#   'good luck have fun mencipta atmosfera yang positif dan berseronok sebelum permainan bermula .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_226.wav',
#   'GOAT adalah gelaran yang memberikan penghormatan terhadap pencapaian yang luar biasa .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_227.wav',
#   'came of the yer adalah kepuasan tertinggi untuk pencipta dan peminat permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_228.wav',
#   'games as a service membuka pintu kepada pelbagai kandungan baru dan kemaskini dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_229.wav',
#   'Games as a produk mengutamakan penjualan produk yang sempurna dari segi kandungan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_230.wav',
#   'kitt good adalah moto yang menggalakkan semangat untuk terus meningkatkan prestasi .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_231.wav',
#   'hold par menyajikan pengalaman permainan yang mencabar dan menarik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_232.wav',
#   'hack versus hack menambah elemen persaingan unik dalam dunia permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_233.wav',
#   'good game adalah ucapan penutup yang bersopan santun setelah permainan selesai .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_234.wav',
#   'good luck have fun membawa semangat positif kepada permainan kompetitif .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_235.wav',
#   'GOAT adalah pencapaian yang banyak permainan impikan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_236.wav',
#   'came of the yer memberikan pengiktirafan tertinggi kepada permainan yang menonjol dalam tahun tersebut .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_237.wav',
#   'games as a service membawa model perniagaan yang berterusan kepada industri permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_238.wav',
#   'Games as a produk memberikan perhatian kepada hasil akhir produk permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_239.wav',
#   'kitt good adalah nasihat yang mencerminkan semangat peningkatan diri .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_240.wav',
#   'hold par menyediakan hiburan yang menarik untuk pencinta permainan teka teki .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_241.wav',
#   'hack versus hack adalah pertempuran intelektual di dalam dunia permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_242.wav',
#   'good game adalah ungkapan penghargaan dan rasa hormat terhadap lawan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_243.wav',
#   'good luck have fun membawa elemen kesopanan dalam dunia permainan siber .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_244.wav',
#   'GOAT adalah kepuasan yang diimpikan oleh banyak pemain dan pencipta permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_245.wav',
#   'came of the yer adalah gelaran yang membawa kebanggaan kepada pencipta permainan yang menang .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_246.wav',
#   'jay R pee gee atau jepun Role Playing Game merujuk kepada permainan peranan yang berasal dari Jepun .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_247.wav',
#   'kay dee A atau Kill Death Assist adalah statistik yang mengukur bilangan pembunuhan , kematian , dan pertolongan pemain dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_248.wav',
#   'King of the Hill king of the hill adalah mod permainan di mana pemain berusaha untuk menguasai kawasan tertentu untuk mendapatkan mata .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_249.wav',
#   'Konami kod adalah kombinasi pad butang konsol yang terkenal , sering digunakan untuk mendapatkan kelebihan dalam permainan Konami .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_250.wav',
#   'LAN party adalah perhimpunan pemain di mana mereka berkumpul secara fizikal untuk bermain permainan video melalui rangkaian tempatan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_251.wav',
#   'looking for group atau Looking for Group adalah singkatan yang digunakan oleh pemain yang mencari rakan bermain untuk sesi tertentu .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_252.wav',
#   'looking for more atau Looking for More digunakan untuk mencari lebih banyak pemain untuk menyertai sesi permainan atau aktiviti tertentu .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_253.wav',
#   'letz Play letz play adalah video atau siri video di mana pemain bermain dan berkongsi pengalaman mereka dengan penonton .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_254.wav',
#   'em em O atau Massively multi player Online merujuk kepada permainan yang boleh dimainkan secara dalam talian dengan ribuan pemain serentak .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_255.wav',
#   'em em O R pee gee atau Massively multi player Online Role Playing Game adalah permainan peranan dalam talian dengan jumlah pemain yang besar .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_256.wav',
#   'jay R pee gee menonjolkan elemen seni dan naratif yang kuat dalam permainan peranan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_257.wav',
#   'kay dee A memberikan pandangan tentang keberkesanan seorang pemain dalam membantu pasukannya atau menentang musuh .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_258.wav',
#   'King of the Hill king of the hill adalah mod permainan yang menguji taktikal dan kerjasama pasukan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_259.wav',
#   'Konami kod menjadi ikonik dalam sejarah permainan video dan banyak digunakan dalam permainan Konami .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_260.wav',
#   'LAN party membawa pengalaman sosial dan komuniti kepada pemain dalam talian .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_261.wav',
#   'looking for group adalah panggilan bagi pemain yang ingin bersama sama dengan rakan bermain baru .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_262.wav',
#   'looking for more membolehkan pemain mencari lebih banyak ahli untuk menyertai kelompok permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_263.wav',
#   'letz Play letz play memberikan pandangan dan hiburan kepada penonton yang ingin melihat pemain bermain .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_264.wav',
#   'em em O membuka dunia yang luas dan terbuka untuk pemain dari seluruh dunia .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_265.wav',
#   'em em O R pee gee menyajikan pengalaman permainan peranan yang mendalam dan serentak dalam talian .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_266.wav',
#   'jay R pee gee sering dikenali dengan rekaan seni yang indah dan sistem permainan peranan yang mendalam .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_267.wav',
#   'kay dee A menjadi penunjuk kekuatan dan sumbangan seorang pemain dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_268.wav',
#   'King of the Hill king of the hill adalah mod permainan yang menarik dan penuh adrenalin .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_269.wav',
#   'Konami kod menjadi ikon budaya pop dan sering muncul dalam pelbagai permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_270.wav',
#   'LAN party memupuk komuniti permainan dan interaksi sosial antara pemain .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_271.wav',
#   'looking for group memudahkan pemain untuk mencari kumpulan permainan yang sesuai .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_272.wav',
#   'looking for more membantu pemain dalam membina pasukan yang kuat untuk mencapai matlamat permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_273.wav',
#   'letz Play letz play memberikan platform untuk pemain berkongsi pengalaman dan kecekapan permainan mereka .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_274.wav',
#   'em em O menyediakan persekitaran yang dinamik dan terus berkembang untuk pengembaraan dalam talian .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_275.wav',
#   'em em O R pee gee membawa pemain ke dalam dunia fantasi yang serba mungkin dan serentak .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_276.wav',
#   'jay R pee gee menonjolkan ciri khas Jepun dalam seni dan naratif permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_277.wav',
#   'kay dee A memberikan pemain gambaran tentang peranannya dalam kejayaan pasukannya .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_278.wav',
#   'King of the Hill king of the hill adalah mod permainan yang melibatkan peperangan untuk menguasai lokasi strategik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_279.wav',
#   'Konami kod mengukuhkan kedudukan sebagai kod rahsia yang terkenal dalam sejarah permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_280.wav',
#   'LAN party menguatkan hubungan sosial di antara pemain yang berkongsi minat yang sama .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_281.wav',
#   'looking for group memudahkan pemain untuk menyertai kelompok yang sesuai dengan minat mereka .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_282.wav',
#   'looking for more memberikan pemain peluang untuk membina pasukan yang seimbang dan kuat .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_283.wav',
#   'letz Play letz play membolehkan pemain berkongsi kegembiraan dan cabaran permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_284.wav',
#   'em em O membuka pintu kepada pengalaman bermain yang berskala besar dan terbuka .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_285.wav',
#   'em em O R pee gee mengajak pemain untuk menyertai pengembaraan dalam dunia permainan yang kaya .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_286.wav',
#   'jay R pee gee menampilkan elemen budaya Jepun yang unik dalam setiap permainannya .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_287.wav',
#   'kay dee A adalah ukuran penting untuk menilai keberkesanan pemain dalam permainan .'],
# ...
#   'Cloud Gaming membuka pintu kepada akses mudah kepada permainan tanpa keperluan memori yang besar .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_918.wav',
#   'Cloud Save memudahkan pemain dalam menyimpan kemajuan mereka dan bermain pada berbagai peranti .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_919.wav',
#   'klutch boleh menjadi titik puncak dalam pengalaman permainan , memberikan pemain kepuasan ketika mengatasi cabaran berat .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_920.wav',
#   'cooperative came play membawa dinamika sosial dalam permainan , memupuk kerjasama dan interaksi antara pemain .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_921.wav',
#   'Class i dentity membolehkan pemain menyusun strategi berdasarkan kekuatan dan kelemahan setiap kelas .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_922.wav',
#   'klicker Game menyediakan pengalaman santai dengan tindakan klik yang berulang .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_923.wav',
#   'klipping boleh mencipta situasi tidak terduga yang menambah keseronokan dan kejutan dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_924.wav',
#   'klock klock menekankan pada pengurusan waktu waktu yang efektif untuk mencapai objektif permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_925.wav',
#   'klone membawa pelbagai pilihan permainan yang memberikan pemain lebih banyak pilihan untuk dinikmati .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_926.wav',
#   'klos Beta memberikan pemain peminat peluang eksklusif untuk menguji permainan sebelum dilancarkan secara meluas .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_927.wav',
#   'Cloud Gaming mengurangkan beban permainan pada peranti dan memberikan akses yang lebih mudah kepada pelbagai permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_928.wav',
#   'Cloud Save memberikan kemudahan dan kecekapan dalam penyimpanan dan akses kepada kemajuan permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_929.wav',
#   'klutch memerlukan ketangkasan dan kecekapan untuk menyelesaikan situasi sulit atau menang dalam keadaan terdesak .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_930.wav',
#   'cooperative came play menyemai semangat kerjasama dan pertalian antara pemain , mencipta pengalaman permainan yang bersosial .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_931.wav',
#   'Coin O pee membawa kembali nostalgia permainan arkade dengan pengalaman yang memerlukan duit syiling .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_932.wav',
#   'Collision Detection adalah aspek teknologi yang penting untuk menghasilkan interaksi yang realistik dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_933.wav',
#   'kombo memberikan pemain peluang untuk melancarkan serangan yang kuat dengan menggabungkan gerakan secara berkesan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_934.wav',
#   'Competitive Gaming memerlukan kemahiran taktikal dan reaksi yang cepat untuk mencapai kejayaan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_935.wav',
#   'Completionist mencari keseronokan dalam menamatkan setiap aspek dan pencapaian dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_936.wav',
#   'Compulsion Loop mempengaruhi pemain dengan sistem ganjaran yang menyebabkan mereka terus bermain untuk mencapai matlamat .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_937.wav',
#   'konsol membawa pengalaman permainan ke dalam ruang bilik dengan pelbagai judul dan prestasi .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_938.wav',
#   'konsol Generations membuktikan kemajuan peranti konsol dari satu generasi ke generasi seterusnya .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_939.wav',
#   'konsol Wars menyajikan pertempuran di antara pembuat konsol untuk mendapatkan hati pemain dan penjualan peranti .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_940.wav',
#   'Construction and Management Simulation C em ass membolehkan pemain mengasah kemahiran pengurusan mereka melalui simulasi pembinaan dan pengurusannya .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_941.wav',
#   'Coin O pee membawa elemen fizikal dengan menuntut pemain memasukkan duit syiling untuk bermain .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_942.wav',
#   'Collision Detection menjadi aspek penting untuk memastikan realisme dalam interaksi antara objek dan watak .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_943.wav',
#   'kombo memberikan pemain perasaan kepuasan dan kejayaan apabila mereka dapat mengekalkan siri gerakan berterusan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_944.wav',
#   'Competitive Gaming menyajikan arena di mana kemahiran dan strategi dituntut untuk mencapai kemenangan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_945.wav',
#   'Completionist menikmati permainan dengan melengkapkan setiap tugas dan pencapaian yang ada .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_946.wav',
#   'Compulsion Loop membentuk siklus permainan yang membuat pemain terus terlibat dan berfokus pada objektif permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_947.wav',
#   'konsol membawa kepelbagaian permainan ke dalam talian dan offline , menawarkan pengalaman yang unik untuk setiap pemain .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_948.wav',
#   'konsol Generations membuktikan evolusi teknologi dalam dunia konsol permainan dari masa ke masa .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_949.wav',
#   'konsol Wars mencetuskan kesetiaan pemain kepada jenama tertentu dan menyaksikan pertempuran pasaran yang sengit .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_950.wav',
#   'Construction and Management Simulation C em ass menantang pemain untuk menjadi ketua pembangunan dan pengurusan dalam dunia simulasi .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_951.wav',
#   'Coin O pee menambah dimensi fizikal dengan memerlukan pemain memasukkan duit syiling untuk mengakses permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_952.wav',
#   'Collision Detection memastikan watak dan objek dalam permainan berinteraksi dengan cara yang logik dan realistik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_953.wav',
#   'kombo membuka peluang untuk pemain mengeksplorasi gabungan gerakan dan taktik yang berbeza .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_954.wav',
#   'Competitive Gaming memberikan arena di mana pemain bersaing untuk membuktikan kemahiran terbaik mereka .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_955.wav',
#   'Completionist mencapai kepuasan dengan menamatkan setiap aspek dan rahsia dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_956.wav',
#   'Compulsion Loop memberikan perasaan pencapaian yang berterusan , menjadikan permainan lebih menarik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_957.wav',
#   'konsol membawa dunia permainan kepada pelbagai lapisan masyarakat dengan akses yang mudah dan pelbagai tawaran .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_958.wav',
#   'konsol Generations mencerminkan kemajuan teknologi dan inovasi dalam rekabentuk peranti konsol .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_959.wav',
#   'konsol Wars mencipta dedikasi dan kesetiaan yang kuat dari peminat terhadap jenama konsol kegemaran mereka .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_960.wav',
#   'Construction and Management Simulation C em ass membolehkan pemain mengasah kemahiran strategi dan pengurusan sumber dalam konteks pembinaan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_961.wav',
#   'Coin O pee memberikan pengalaman fizikal yang seronok dan mengingatkan kepada zaman arkade yang lama .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_962.wav',
#   'Collision Detection memastikan setiap interaksi dalam permainan memberikan respons yang realistik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_963.wav',
#   'kombo memberikan kepuasan tersendiri apabila pemain dapat menjalankan siri gerakan dengan lancar dan berkesan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_964.wav',
#   'Competitive Gaming membentuk komuniti yang kompetitif dan memerlukan kesabaran dan latihan yang berterusan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_965.wav',
#   'Completionist menikmati proses pencapaian dan penuh kepuasan apabila setiap objektif dicapai .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_966.wav',
#   'Compulsion Loop mencipta pengalaman permainan yang mengasyikkan dan menyeronokkan dengan sistem ganjaran yang efektif .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_967.wav',
#   'konsol membawa pelbagai jenis permainan ke dalam talian dan offline , menawarkan pilihan yang tidak terhad untuk pemain .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_968.wav',
#   'konsol Generations menggambarkan evolusi dan kemajuan yang luar biasa dalam industri permainan konsol .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_969.wav',
#   'konsol Wars mencetuskan kesetiaan dan perdebatan di kalangan pemain mengenai konsol permainan terbaik .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_970.wav',
#   'Construction and Management Simulation C em ass membolehkan pemain menguji kemahiran pengurusan mereka dalam konteks pembinaan projek .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_971.wav',
#   'Content Rating adalah penilaian yang diberikan kepada permainan untuk memberi amaran mengenai kandungan yang mungkin tidak sesuai untuk golongan tertentu .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_972.wav',
#   'Continue membolehkan pemain meneruskan permainan mereka dari titik simpanan atau check point selepas mengalami kegagalan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_973.wav',
#   'Control Pad atau dee pad dai rectional pad adalah paparan yang digunakan untuk mengawal pergerakan watak dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_974.wav',
#   'Control Point C pee adalah lokasi dalam permainan yang perlu dikuasai atau dipertahankan oleh pemain atau pasukan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_975.wav',
#   'Control Stick adalah mekanisme kendali yang membolehkan pemain mengawal pergerakan watak atau kamera dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_976.wav',
#   'Controller adalah peranti input yang digunakan oleh pemain untuk mengawal pergerakan atau tindakan dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_977.wav',
#   'Conversation Tree adalah struktur percakapan dalam permainan di mana pemain membuat pilihan untuk membentuk perkembangan naratif .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_978.wav',
#   'Conversion Kit adalah alat atau peranti yang digunakan untuk menukar atau mengubahsuai konsol atau permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_979.wav',
#   'Content Rating membantu ibu bapa dan pemain menyaring permainan yang sesuai dengan tahap kematangan dan nilai keluarga mereka .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_980.wav',
#   'Continue memberikan pemain peluang untuk memperbaiki kesalahan mereka dan melanjutkan pengalaman permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_981.wav',
#   'Control Pad memainkan peranan penting dalam pengawalan permainan konsol , membolehkan pemain bergerak dan bertindak dengan mudah .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_982.wav',
#   'Control Point C pee menyediakan objektif taktikal yang perlu dikuasai untuk mencapai kemenangan dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_983.wav',
#   'Control Stick membolehkan pemain mengalami kawalan yang lebih halus dan presisi dalam pergerakan dan penjelajahan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_984.wav',
#   'Controller memainkan peranan utama dalam menyediakan pengalaman interaktif dalam permainan video .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_985.wav',
#   'Conversation Tree memberikan pemain kebebasan untuk memilih arah cerita dan pengembangan watak dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_986.wav',
#   'Conversion Kit membuka peluang untuk pengubahsuaian peranti keras atau permainan mengikut citarasa dan keperluan pemain .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_987.wav',
#   'kool down memberi elemen strategi dalam permainan dengan menguruskan penggunaan kemahiran dan serangan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_988.wav',
#   'Cooperative game play cooperative came play membawa elemen kerjasama dan komunikasi dalam permainan , memupuk semangat pasukan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_989.wav',
#   'Content Rating membantu pemain membuat keputusan yang bijak mengenai kandungan permainan yang mereka pilih untuk dimainkan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_990.wav',
#   'Continue memberikan pemain peluang untuk mengatasi cabaran dan memperbaiki kesalahan mereka dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_991.wav',
#   'Control Pad memainkan peranan utama dalam permainan konsol , memastikan pemain dapat mengawal pergerakan dengan mudah .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_992.wav',
#   'Control Point C pee mencipta taktik dan strategi yang perlu diperhatikan dalam permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_993.wav',
#   'Control Stick menyediakan pengalaman permainan yang lebih dinamik dengan gerakan presisi dan respons cepat .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_994.wav',
#   'Controller menjadi sederhana penting antara pemain dan permainan , membolehkan interaksi yang efektif .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_995.wav',
#   'Conversation Tree memberikan variasi dan cabaran dalam perjalanan cerita , memberi pemain impak terhadap naratif .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_996.wav',
#   'Conversion Kit mengizinkan pemain menyesuaikan peranti mereka untuk meningkatkan pengalaman permainan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_997.wav',
#   'kool down menyeimbangkan permainan dengan memperkenalkan masa tunggu sebelum pemain dapat menggunakan kemahiran tertentu .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_998.wav',
#   'Cooperative game play cooperative came play menggabungkan usaha pemain untuk mencapai matlamat bersama dan mengatasi rintangan .'],
#  ['/home/ckabundant/Documents/tts-melayu/data/gaming/gpt/wav/gpt_999.wav',
#   'Content Rating membantu memastikan bahawa permainan disesuaikan dengan audiens yang sesuai .'],
#  ...]
